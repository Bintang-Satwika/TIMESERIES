# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
# Parameter windowing
input_width = 48
label_width = 1
shift = label_width
total_window_size = input_width + shift
OUT_STEPS = label_width
# Definisikan irisan untuk input dan label
input_slice = slice(0, input_width)
label_start = total_window_size - label_width
labels_slice = slice(label_start, None)

from A_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive

# %%
data_training= pd.read_excel('D:\\KULIAH S2\\Komputasi Lanjut\\CODE\\ANN\\cuaca_bebanLR5_v2.xlsx', index_col=0)
data_training
# Out:
#                         Beban  Hari_Khus   Jam_sin   Jam_cos  Hari_sin  \
# Date
# 2023-02-12 00:30:00  20312.00          0  0.130526  0.991445 -0.781831
# 2023-02-12 01:00:00  20180.00          0  0.258819  0.965926 -0.781831
# 2023-02-12 01:30:00  20021.00          0  0.382683  0.923880 -0.781831
# 2023-02-12 02:00:00  19906.00          0  0.500000  0.866025 -0.781831
# 2023-02-12 02:30:00  19743.00          0  0.608761  0.793353 -0.781831
# ...                       ...        ...       ...       ...       ...
# 2023-12-31 22:00:00  21241.27          0 -0.500000  0.866025 -0.781831
# 2023-12-31 22:30:00  20800.42          0 -0.382683  0.923880 -0.781831
# 2023-12-31 23:00:00  20450.02          0 -0.258819  0.965926 -0.781831
# 2023-12-31 23:30:00  20175.87          0 -0.130526  0.991445 -0.781831
# 2024-01-01 00:00:00  19802.04          0  0.000000  1.000000  0.000000
#
#                      Hari_cos  Hari_Khus_sin  Hari_Khus_cos   Tanggal_sin  \
# Date
# 2023-02-12 00:30:00   0.62349            0.0            1.0  7.431448e-01
# 2023-02-12 01:00:00   0.62349            0.0            1.0  7.431448e-01
# 2023-02-12 01:30:00   0.62349            0.0            1.0  7.431448e-01
# 2023-02-12 02:00:00   0.62349            0.0            1.0  7.431448e-01
# 2023-02-12 02:30:00   0.62349            0.0            1.0  7.431448e-01
# ...                       ...            ...            ...           ...
# 2023-12-31 22:00:00   0.62349            0.0            1.0 -2.449294e-16
# 2023-12-31 22:30:00   0.62349            0.0            1.0 -2.449294e-16
# 2023-12-31 23:00:00   0.62349            0.0            1.0 -2.449294e-16
# 2023-12-31 23:30:00   0.62349            0.0            1.0 -2.449294e-16
# 2024-01-01 00:00:00   1.00000            0.0            1.0  0.000000e+00
#
#                      Tanggal_cos  Bulan_sin  Bulan_cos
# Date
# 2023-02-12 00:30:00    -0.669131        0.5   0.866025
# 2023-02-12 01:00:00    -0.669131        0.5   0.866025
# 2023-02-12 01:30:00    -0.669131        0.5   0.866025
# 2023-02-12 02:00:00    -0.669131        0.5   0.866025
# 2023-02-12 02:30:00    -0.669131        0.5   0.866025
# ...                          ...        ...        ...
# 2023-12-31 22:00:00     1.000000       -0.5   0.866025
# 2023-12-31 22:30:00     1.000000       -0.5   0.866025
# 2023-12-31 23:00:00     1.000000       -0.5   0.866025
# 2023-12-31 23:30:00     1.000000       -0.5   0.866025
# 2024-01-01 00:00:00     1.000000        0.0   1.000000
#
# [15504 rows x 12 columns]

# %%
data_validation= pd.read_excel('D:\\KULIAH S2\\Komputasi Lanjut\\CODE\\ANN\\cuaca_bebanLR5_v2_validation.xlsx', index_col=0)
data_validation
# Out:
#                         Beban  Hari_Khus   Jam_sin   Jam_cos  Hari_sin  \
# Date
# 2024-01-01 00:30:00  19654.75          0  0.130526  0.991445  0.000000
# 2024-01-01 01:00:00  19495.06          0  0.258819  0.965926  0.000000
# 2024-01-01 01:30:00  19221.50          0  0.382683  0.923880  0.000000
# 2024-01-01 02:00:00  19028.74          0  0.500000  0.866025  0.000000
# 2024-01-01 02:30:00  18785.11          0  0.608761  0.793353  0.000000
# ...                       ...        ...       ...       ...       ...
# 2024-02-11 22:00:00  23109.43          0 -0.500000  0.866025 -0.781831
# 2024-02-11 22:30:00  22627.13          0 -0.382683  0.923880 -0.781831
# 2024-02-11 23:00:00  22035.37          0 -0.258819  0.965926 -0.781831
# 2024-02-11 23:30:00  21696.04          0 -0.130526  0.991445 -0.781831
# 2024-02-12 00:00:00  21313.93          0  0.000000  1.000000  0.000000
#
#                      Hari_cos  Hari_Khus_sin  Hari_Khus_cos  Tanggal_sin  \
# Date
# 2024-01-01 00:30:00   1.00000            0.0            1.0     0.000000
# 2024-01-01 01:00:00   1.00000            0.0            1.0     0.000000
# 2024-01-01 01:30:00   1.00000            0.0            1.0     0.000000
# 2024-01-01 02:00:00   1.00000            0.0            1.0     0.000000
# 2024-01-01 02:30:00   1.00000            0.0            1.0     0.000000
# ...                       ...            ...            ...          ...
# 2024-02-11 22:00:00   0.62349            0.0            1.0     0.866025
# 2024-02-11 22:30:00   0.62349            0.0            1.0     0.866025
# 2024-02-11 23:00:00   0.62349            0.0            1.0     0.866025
# 2024-02-11 23:30:00   0.62349            0.0            1.0     0.866025
# 2024-02-12 00:00:00   1.00000            0.0            1.0     0.743145
#
#                      Tanggal_cos  Bulan_sin  Bulan_cos
# Date
# 2024-01-01 00:30:00     1.000000        0.0   1.000000
# 2024-01-01 01:00:00     1.000000        0.0   1.000000
# 2024-01-01 01:30:00     1.000000        0.0   1.000000
# 2024-01-01 02:00:00     1.000000        0.0   1.000000
# 2024-01-01 02:30:00     1.000000        0.0   1.000000
# ...                          ...        ...        ...
# 2024-02-11 22:00:00    -0.500000        0.5   0.866025
# 2024-02-11 22:30:00    -0.500000        0.5   0.866025
# 2024-02-11 23:00:00    -0.500000        0.5   0.866025
# 2024-02-11 23:30:00    -0.500000        0.5   0.866025
# 2024-02-12 00:00:00    -0.669131        0.5   0.866025
#
# [2016 rows x 12 columns]

# %%
df1_training  = data_training.copy()
beban_scaled, beban_min, beban_max  =scale_array(df1_training['Beban'].values)
df1_training['Beban']   =   beban_scaled


input_make_windows      =   df1_training.drop(columns=["Beban"]).to_numpy()
output_make_windows     =   df1_training['Beban'].to_numpy()
x_train,    y_train     =  make_windows_autoregressive(input_make_windows, output_make_windows, input_width, label_width)

# %%
df_1_validation =   data_validation.copy()
beban_scaled_validation, _, _ = scale_array(df_1_validation['Beban'].values)
df_1_validation['Beban']    =   beban_scaled_validation


input_make_windows_validation   = df_1_validation.drop(columns=["Beban"]).to_numpy()
output_make_windows_validation  = df_1_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows_autoregressive(input_make_windows_validation, output_make_windows_validation, input_width, label_width)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((15456, 48, 11), (15456, 1), (1968, 48, 11), (1968, 1))

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import time

def tensorflow_dense(X_train_scaled, Y_train_scaled, X_validation_scaled, Y_validation_scaled, 
                       learning_rate, target_MAE, jumlah_epochs, jumlah_sampel_batch,
                       jumlah_epoch_terbelakang, save_best_model_path, validation_data=False, load_model=None):
    global model

    class MAEStopCallback(tf.keras.callbacks.Callback):
        def __init__(self, threshold):
            super(MAEStopCallback, self).__init__()
            self.threshold = threshold

        def on_epoch_end(self, epoch, logs=None):
            if logs['mae'] < self.threshold:
                print(f"\nMAE reached below {self.threshold}. Stopping training.")
                self.model.stop_training = True

    # Mendapatkan dimensi input
    input_width = X_train_scaled.shape[1]   #  48 timesteps
    num_features = X_train_scaled.shape[2]    #11 fitur per timestep
    output_width = Y_train_scaled.shape[1]  # 48 timesteps

    model = tf.keras.models.Sequential()
    if load_model is None:
        model.add(tf.keras.layers.Input(shape=(input_width, num_features)))
        model.add(tf.keras.layers.Flatten())  # Mengubah bentuk dari (48, num_features) menjadi (48*num_features,)
        model.add(tf.keras.layers.Dense(256, activation='tanh'))
        model.add(tf.keras.layers.Dense(128, activation='tanh'))
        model.add(tf.keras.layers.Dense(64, activation='tanh'))
        model.add(tf.keras.layers.Dense(1))  # Output prediksi untuk timestep ke-49

    else:
        model = tf.keras.models.load_model(load_model)
    
    model.summary()
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mse', 'mae', 'mape', 
                               tf.keras.metrics.RootMeanSquaredError(name='rmse')])
    mae_stop_callback = MAEStopCallback(threshold=target_MAE)

    checkpoint_callback = ModelCheckpoint(
        save_best_model_path,
        monitor='val_mae',
        mode='min',
        save_best_only=True,
        verbose=1
    )

    early_stopping_callback = EarlyStopping(
        monitor='val_mae',
        mode='min',
        patience=jumlah_epoch_terbelakang,
        restore_best_weights=True,
        verbose=1
    )

    time_start = time.time()
    if validation_data:
        model.fit(X_train_scaled, Y_train_scaled, epochs=jumlah_epochs, batch_size=jumlah_sampel_batch,  
                  callbacks=[mae_stop_callback, checkpoint_callback, early_stopping_callback],
                  validation_data=(X_validation_scaled, Y_validation_scaled), validation_batch_size=jumlah_sampel_batch)
    else:
        model.fit(X_train_scaled, Y_train_scaled, epochs=jumlah_epochs, batch_size=jumlah_sampel_batch, 
                  callbacks=[mae_stop_callback, checkpoint_callback, early_stopping_callback])
    
    print("Time computation seconds: ", time.time() - time_start)
    
    loss, MSE, MAE, RMSE, MAPE = model.evaluate(X_train_scaled, Y_train_scaled)
    print("Loss:", loss, "MSE:", MSE, "MAE:", MAE, "RMSE:", RMSE)
    
    return model, loss, MSE, MAE, RMSE, MAPE

# %%
model, loss, MSE, MAE, RMSE, MAPE= tensorflow_dense(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.01,  jumlah_epochs=30, jumlah_sampel_batch=48*2, 
                                                  jumlah_epoch_terbelakang=10,  save_best_model_path = 'C_lowest_single.hdf5', 
                                                  validation_data=True, load_model=None)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 528)               0
#
#  dense (Dense)               (None, 256)               135424
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 176,641
# Trainable params: 176,641
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 152/161 [===========================>..] - ETA: 0s - loss: 0.0353 - mse: 0.0353 - mae: 0.1333 - mape: 218.9520 - rmse: 0.1880
# Epoch 1: val_mae improved from inf to 0.19236, saving model to C_lowest_single.hdf5
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0342 - mse: 0.0342 - mae: 0.1307 - mape: 212.6343 - rmse: 0.1848 - val_loss: 0.0626 - val_mse: 0.0626 - val_mae: 0.1924 - val_mape: 142.9994 - val_rmse: 0.2502
# Epoch 2/30
# 159/161 [============================>.] - ETA: 0s - loss: 0.0113 - mse: 0.0113 - mae: 0.0794 - mape: 141.8888 - rmse: 0.1062
# Epoch 2: val_mae did not improve from 0.19236
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0793 - mape: 146.7030 - rmse: 0.1060 - val_loss: 0.0623 - val_mse: 0.0623 - val_mae: 0.1985 - val_mape: 164.1701 - val_rmse: 0.2497
# Epoch 3/30
# 159/161 [============================>.] - ETA: 0s - loss: 0.0084 - mse: 0.0084 - mae: 0.0685 - mape: 126.1519 - rmse: 0.0917
# Epoch 3: val_mae improved from 0.19236 to 0.19172, saving model to C_lowest_single.hdf5
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0685 - mape: 126.6312 - rmse: 0.0917 - val_loss: 0.0604 - val_mse: 0.0604 - val_mae: 0.1917 - val_mape: 139.6458 - val_rmse: 0.2457
# Epoch 4/30
# 157/161 [============================>.] - ETA: 0s - loss: 0.0070 - mse: 0.0070 - mae: 0.0628 - mape: 112.6989 - rmse: 0.0838
# Epoch 4: val_mae improved from 0.19172 to 0.18855, saving model to C_lowest_single.hdf5
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0627 - mape: 111.4845 - rmse: 0.0837 - val_loss: 0.0571 - val_mse: 0.0571 - val_mae: 0.1886 - val_mape: 140.6944 - val_rmse: 0.2389
# Epoch 5/30
# 137/161 [========================>.....] - ETA: 0s - loss: 0.0062 - mse: 0.0062 - mae: 0.0592 - mape: 104.8724 - rmse: 0.0790
# Epoch 5: val_mae improved from 0.18855 to 0.17321, saving model to C_lowest_single.hdf5
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0591 - mape: 106.2685 - rmse: 0.0785 - val_loss: 0.0492 - val_mse: 0.0492 - val_mae: 0.1732 - val_mape: 136.5800 - val_rmse: 0.2219
# Epoch 6/30
# 155/161 [===========================>..] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0555 - mape: 101.9130 - rmse: 0.0733
# Epoch 6: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0554 - mape: 100.3809 - rmse: 0.0734 - val_loss: 0.0501 - val_mse: 0.0501 - val_mae: 0.1755 - val_mape: 124.0675 - val_rmse: 0.2238
# Epoch 7/30
# 157/161 [============================>.] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0528 - mape: 93.9111 - rmse: 0.0696
# Epoch 7: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0529 - mape: 92.9149 - rmse: 0.0696 - val_loss: 0.0554 - val_mse: 0.0554 - val_mae: 0.1853 - val_mape: 145.1355 - val_rmse: 0.2353
# Epoch 8/30
# 157/161 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0498 - mape: 90.5811 - rmse: 0.0658
# Epoch 8: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0498 - mape: 90.3604 - rmse: 0.0658 - val_loss: 0.0556 - val_mse: 0.0556 - val_mae: 0.1861 - val_mape: 140.0640 - val_rmse: 0.2359
# Epoch 9/30
# 142/161 [=========================>....] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0485 - mape: 92.6494 - rmse: 0.0636
# Epoch 9: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0484 - mape: 90.6735 - rmse: 0.0637 - val_loss: 0.0523 - val_mse: 0.0523 - val_mae: 0.1786 - val_mape: 164.1495 - val_rmse: 0.2287
# Epoch 10/30
# 136/161 [========================>.....] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0468 - mape: 81.1858 - rmse: 0.0618
# Epoch 10: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0466 - mape: 79.5260 - rmse: 0.0614 - val_loss: 0.0546 - val_mse: 0.0546 - val_mae: 0.1833 - val_mape: 133.1555 - val_rmse: 0.2337
# Epoch 11/30
# 159/161 [============================>.] - ETA: 0s - loss: 0.0034 - mse: 0.0034 - mae: 0.0444 - mape: 80.4122 - rmse: 0.0587
# Epoch 11: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0444 - mape: 80.1080 - rmse: 0.0587 - val_loss: 0.0494 - val_mse: 0.0494 - val_mae: 0.1744 - val_mape: 125.9576 - val_rmse: 0.2222
# Epoch 12/30
# 152/161 [===========================>..] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0438 - mape: 74.4223 - rmse: 0.0578
# Epoch 12: val_mae did not improve from 0.17321
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0436 - mape: 73.8139 - rmse: 0.0576 - val_loss: 0.0511 - val_mse: 0.0511 - val_mae: 0.1768 - val_mape: 124.9859 - val_rmse: 0.2260
# Epoch 13/30
# 155/161 [===========================>..] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - mae: 0.0415 - mape: 74.3390 - rmse: 0.0547
# Epoch 13: val_mae improved from 0.17321 to 0.17252, saving model to C_lowest_single.hdf5
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0415 - mape: 74.2443 - rmse: 0.0547 - val_loss: 0.0488 - val_mse: 0.0488 - val_mae: 0.1725 - val_mape: 122.7079 - val_rmse: 0.2210
# Epoch 14/30
# 154/161 [===========================>..] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0409 - mape: 70.9096 - rmse: 0.0541
# Epoch 14: val_mae did not improve from 0.17252
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0409 - mape: 70.7524 - rmse: 0.0541 - val_loss: 0.0502 - val_mse: 0.0502 - val_mae: 0.1770 - val_mape: 139.0027 - val_rmse: 0.2241
# Epoch 15/30
# 134/161 [=======================>......] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0388 - mape: 73.6577 - rmse: 0.0514
# Epoch 15: val_mae did not improve from 0.17252
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0387 - mape: 70.1897 - rmse: 0.0511 - val_loss: 0.0505 - val_mse: 0.0505 - val_mae: 0.1774 - val_mape: 162.2621 - val_rmse: 0.2248
# Epoch 16/30
# 146/161 [==========================>...] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0384 - mape: 65.1937 - rmse: 0.0512
# Epoch 16: val_mae improved from 0.17252 to 0.16784, saving model to C_lowest_single.hdf5
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0384 - mape: 68.5659 - rmse: 0.0512 - val_loss: 0.0459 - val_mse: 0.0459 - val_mae: 0.1678 - val_mape: 129.8845 - val_rmse: 0.2142
# Epoch 17/30
# 145/161 [==========================>...] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0371 - mape: 66.9210 - rmse: 0.0490
# Epoch 17: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0371 - mape: 64.5028 - rmse: 0.0490 - val_loss: 0.0504 - val_mse: 0.0504 - val_mae: 0.1767 - val_mape: 149.8986 - val_rmse: 0.2246
# Epoch 18/30
# 146/161 [==========================>...] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0372 - mape: 60.2580 - rmse: 0.0490
# Epoch 18: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0369 - mape: 67.2092 - rmse: 0.0486 - val_loss: 0.0483 - val_mse: 0.0483 - val_mae: 0.1728 - val_mape: 124.8672 - val_rmse: 0.2198
# Epoch 19/30
# 152/161 [===========================>..] - ETA: 0s - loss: 0.0022 - mse: 0.0022 - mae: 0.0351 - mape: 60.4509 - rmse: 0.0466
# Epoch 19: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 3ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0351 - mape: 60.2887 - rmse: 0.0467 - val_loss: 0.0478 - val_mse: 0.0478 - val_mae: 0.1728 - val_mape: 139.8559 - val_rmse: 0.2186
# Epoch 20/30
# 140/161 [=========================>....] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0346 - mape: 65.7687 - rmse: 0.0459
# Epoch 20: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0345 - mape: 63.1098 - rmse: 0.0456 - val_loss: 0.0490 - val_mse: 0.0490 - val_mae: 0.1748 - val_mape: 124.0612 - val_rmse: 0.2215
# Epoch 21/30
# 141/161 [=========================>....] - ETA: 0s - loss: 0.0020 - mse: 0.0020 - mae: 0.0340 - mape: 59.9303 - rmse: 0.0450
# Epoch 21: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0338 - mape: 58.6782 - rmse: 0.0447 - val_loss: 0.0496 - val_mse: 0.0496 - val_mae: 0.1751 - val_mape: 137.4725 - val_rmse: 0.2228
# Epoch 22/30
# 145/161 [==========================>...] - ETA: 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0327 - mape: 57.2657 - rmse: 0.0436
# Epoch 22: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0330 - mape: 55.4736 - rmse: 0.0441 - val_loss: 0.0512 - val_mse: 0.0512 - val_mae: 0.1792 - val_mape: 130.6574 - val_rmse: 0.2262
# Epoch 23/30
# 142/161 [=========================>....] - ETA: 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0328 - mape: 63.3196 - rmse: 0.0434
# Epoch 23: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0326 - mape: 60.1592 - rmse: 0.0433 - val_loss: 0.0509 - val_mse: 0.0509 - val_mae: 0.1773 - val_mape: 148.0018 - val_rmse: 0.2255
# Epoch 24/30
# 149/161 [==========================>...] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0314 - mape: 56.1162 - rmse: 0.0415
# Epoch 24: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0314 - mape: 55.6194 - rmse: 0.0415 - val_loss: 0.0536 - val_mse: 0.0536 - val_mae: 0.1824 - val_mape: 163.0101 - val_rmse: 0.2315
# Epoch 25/30
# 148/161 [==========================>...] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0311 - mape: 57.6396 - rmse: 0.0415
# Epoch 25: val_mae did not improve from 0.16784
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0312 - mape: 57.8137 - rmse: 0.0416 - val_loss: 0.0510 - val_mse: 0.0510 - val_mae: 0.1799 - val_mape: 135.8266 - val_rmse: 0.2258
# Epoch 26/30
# 153/161 [===========================>..] - ETA: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0.0298 - mape: 49.0009 - rmse: 0.0397
# Epoch 26: val_mae did not improve from 0.16784
# Restoring model weights from the end of the best epoch: 16.
# 161/161 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0299 - mape: 51.0545 - rmse: 0.0398 - val_loss: 0.0530 - val_mse: 0.0530 - val_mae: 0.1806 - val_mape: 182.8568 - val_rmse: 0.2302
# Epoch 26: early stopping
# Time computation seconds:  11.785371541976929
# 483/483 [==============================] - 1s 2ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0379 - mape: 68.2655 - rmse: 0.0494
# Loss: 0.002441498450934887 MSE: 0.002441498450934887 MAE: 0.03788881003856659 RMSE: 68.2655258178711

# %%
MSE, MAE, RMSE, MAPE
# Out:
# (0.002441498450934887,
#  0.03788881003856659,
#  68.2655258178711,
#  0.04941152036190033)

# %%
predictions = model.predict(x_train[slice(None, None, label_width), :, :])
print(predictions.shape)
predictions_reshaped = predictions.reshape(-1,)
predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=beban_min, orig_max=beban_max)
predictions_unscaled.shape
# Out:
# 483/483 [==============================] - 1s 1ms/step
# (15456, 1)
# (15456,)

# %%
df_pred_act = compute_error(x_train, data_training['Beban'], ['Beban'], model, input_width,label_width, beban_min, beban_max)
df_pred_act
# Out:
# 483/483 [==============================] - 1s 1ms/step
# MAE: 325.35814266102165, MAPE %: 1.329986044098176, MSE: 180035.44926037142, RMSE: 424.30584400921396
#                          Prediksi    Aktual
# Date
# 2023-02-13 00:30:00  19424.117188  19244.00
# 2023-02-13 01:00:00  19434.138672  19141.00
# 2023-02-13 01:30:00  19356.134766  18943.00
# 2023-02-13 02:00:00  19010.130859  18862.00
# 2023-02-13 02:30:00  18797.238281  18639.00
# ...                           ...       ...
# 2023-12-31 22:00:00  22196.048828  21241.27
# 2023-12-31 22:30:00  21793.648438  20800.42
# 2023-12-31 23:00:00  21621.683594  20450.02
# 2023-12-31 23:30:00  21168.404297  20175.87
# 2024-01-01 00:00:00  20838.259766  19802.04
#
# [15456 rows x 2 columns]

# %%
df= df_pred_act.copy()
plt.figure(figsize=(16, 6))

# Plot the "Actual" as a green line with dot markers
plt.plot(
    df.index, 
    df['Aktual'], 
    label='Actual output', 
    marker='.', 
    markersize=5, 
    color='#2ca02c', 
    zorder=-100
)

# Scatter plot for "Prediction" in orange X markers
plt.scatter(
    df.index, 
    df['Prediksi'], 
    marker='x', 
    #edgecolors='k', 
    label='Prediction', 
    c='#ff7f0e', 
    s=10
)


plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=30)
plt.title(' Actual and Predictions Over Time')
plt.tight_layout()
plt.show()

# %%
df_pred_act = compute_error(x_val, data_validation['Beban'], ['Beban'], model, input_width,label_width, beban_min, beban_max)
df_pred_act
# Out:
# 62/62 [==============================] - 0s 1ms/step
# MAE: 1086.094878703792, MAPE %: 4.343012854698728, MSE: 1991424.9326576751, RMSE: 1411.178561578114
#                          Prediksi    Aktual
# Date
# 2024-01-02 00:30:00  21904.199219  20109.84
# 2024-01-02 01:00:00  21921.847656  19904.52
# 2024-01-02 01:30:00  21659.380859  19715.16
# 2024-01-02 02:00:00  21220.289062  19513.55
# 2024-01-02 02:30:00  21403.378906  19368.73
# ...                           ...       ...
# 2024-02-11 22:00:00  22439.812500  23109.43
# 2024-02-11 22:30:00  21911.623047  22627.13
# 2024-02-11 23:00:00  21826.273438  22035.37
# 2024-02-11 23:30:00  21039.521484  21696.04
# 2024-02-12 00:00:00  20002.718750  21313.93
#
# [1968 rows x 2 columns]

# %%
df= df_pred_act.copy()
plt.figure(figsize=(16, 6))

# Plot the "Actual" as a green line with dot markers
plt.plot(
    df.index, 
    df['Aktual'], 
    label='Actual output', 
    marker='.', 
    markersize=5, 
    color='#2ca02c', 
    zorder=-100
)

# Scatter plot for "Prediction" in orange X markers
plt.scatter(
    df.index, 
    df['Prediksi'], 
    marker='x', 
    #edgecolors='k', 
    label='Prediction', 
    c='#ff7f0e', 
    s=15
)


plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=30)
plt.title(' Actual and Predictions Over Time')
plt.tight_layout()
plt.show()
