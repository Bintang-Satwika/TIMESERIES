# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
# Parameter windowing
input_width = 48
label_width = 1
shift = label_width
total_window_size = input_width + shift
OUT_STEPS = label_width
# Definisikan irisan untuk input dan label
input_slice = slice(0, input_width)
label_start = total_window_size - label_width
labels_slice = slice(label_start, None)

from A_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive

# %%
data_training= pd.read_excel('D:\\KULIAH S2\\Komputasi Lanjut\\TIMESERIES_CODE\\ANN\\cuaca_bebanLR5_v2.xlsx', index_col=0)
data_training
# Out:
#                         Beban   Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2023-02-12 00:30:00  20312.00  0.130526  0.991445 -0.781831   0.62349
# 2023-02-12 01:00:00  20180.00  0.258819  0.965926 -0.781831   0.62349
# 2023-02-12 01:30:00  20021.00  0.382683  0.923880 -0.781831   0.62349
# 2023-02-12 02:00:00  19906.00  0.500000  0.866025 -0.781831   0.62349
# 2023-02-12 02:30:00  19743.00  0.608761  0.793353 -0.781831   0.62349
# ...                       ...       ...       ...       ...       ...
# 2023-12-31 22:00:00  21241.27 -0.500000  0.866025 -0.781831   0.62349
# 2023-12-31 22:30:00  20800.42 -0.382683  0.923880 -0.781831   0.62349
# 2023-12-31 23:00:00  20450.02 -0.258819  0.965926 -0.781831   0.62349
# 2023-12-31 23:30:00  20175.87 -0.130526  0.991445 -0.781831   0.62349
# 2024-01-01 00:00:00  19802.04  0.000000  1.000000  0.000000   1.00000
#
#                      Hari_Khus_sin  Hari_Khus_cos   Tanggal_sin  Tanggal_cos  \
# Date
# 2023-02-12 00:30:00            0.0            1.0  7.431448e-01    -0.669131
# 2023-02-12 01:00:00            0.0            1.0  7.431448e-01    -0.669131
# 2023-02-12 01:30:00            0.0            1.0  7.431448e-01    -0.669131
# 2023-02-12 02:00:00            0.0            1.0  7.431448e-01    -0.669131
# 2023-02-12 02:30:00            0.0            1.0  7.431448e-01    -0.669131
# ...                            ...            ...           ...          ...
# 2023-12-31 22:00:00            0.0            1.0 -2.449294e-16     1.000000
# 2023-12-31 22:30:00            0.0            1.0 -2.449294e-16     1.000000
# 2023-12-31 23:00:00            0.0            1.0 -2.449294e-16     1.000000
# 2023-12-31 23:30:00            0.0            1.0 -2.449294e-16     1.000000
# 2024-01-01 00:00:00            0.0            1.0  0.000000e+00     1.000000
#
#                      Bulan_sin  Bulan_cos
# Date
# 2023-02-12 00:30:00        0.5   0.866025
# 2023-02-12 01:00:00        0.5   0.866025
# 2023-02-12 01:30:00        0.5   0.866025
# 2023-02-12 02:00:00        0.5   0.866025
# 2023-02-12 02:30:00        0.5   0.866025
# ...                        ...        ...
# 2023-12-31 22:00:00       -0.5   0.866025
# 2023-12-31 22:30:00       -0.5   0.866025
# 2023-12-31 23:00:00       -0.5   0.866025
# 2023-12-31 23:30:00       -0.5   0.866025
# 2024-01-01 00:00:00        0.0   1.000000
#
# [15504 rows x 11 columns]

# %%
data_validation= pd.read_excel('D:\\KULIAH S2\\Komputasi Lanjut\\TIMESERIES_CODE\\ANN\\cuaca_bebanLR5_v2_validation.xlsx', index_col=0)
data_validation
# Out:
#                         Beban   Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2024-01-01 00:30:00  19654.75  0.130526  0.991445  0.000000   1.00000
# 2024-01-01 01:00:00  19495.06  0.258819  0.965926  0.000000   1.00000
# 2024-01-01 01:30:00  19221.50  0.382683  0.923880  0.000000   1.00000
# 2024-01-01 02:00:00  19028.74  0.500000  0.866025  0.000000   1.00000
# 2024-01-01 02:30:00  18785.11  0.608761  0.793353  0.000000   1.00000
# ...                       ...       ...       ...       ...       ...
# 2024-02-11 22:00:00  23109.43 -0.500000  0.866025 -0.781831   0.62349
# 2024-02-11 22:30:00  22627.13 -0.382683  0.923880 -0.781831   0.62349
# 2024-02-11 23:00:00  22035.37 -0.258819  0.965926 -0.781831   0.62349
# 2024-02-11 23:30:00  21696.04 -0.130526  0.991445 -0.781831   0.62349
# 2024-02-12 00:00:00  21313.93  0.000000  1.000000  0.000000   1.00000
#
#                      Hari_Khus_sin  Hari_Khus_cos  Tanggal_sin  Tanggal_cos  \
# Date
# 2024-01-01 00:30:00            0.0            1.0     0.000000     1.000000
# 2024-01-01 01:00:00            0.0            1.0     0.000000     1.000000
# 2024-01-01 01:30:00            0.0            1.0     0.000000     1.000000
# 2024-01-01 02:00:00            0.0            1.0     0.000000     1.000000
# 2024-01-01 02:30:00            0.0            1.0     0.000000     1.000000
# ...                            ...            ...          ...          ...
# 2024-02-11 22:00:00            0.0            1.0     0.866025    -0.500000
# 2024-02-11 22:30:00            0.0            1.0     0.866025    -0.500000
# 2024-02-11 23:00:00            0.0            1.0     0.866025    -0.500000
# 2024-02-11 23:30:00            0.0            1.0     0.866025    -0.500000
# 2024-02-12 00:00:00            0.0            1.0     0.743145    -0.669131
#
#                      Bulan_sin  Bulan_cos
# Date
# 2024-01-01 00:30:00        0.0   1.000000
# 2024-01-01 01:00:00        0.0   1.000000
# 2024-01-01 01:30:00        0.0   1.000000
# 2024-01-01 02:00:00        0.0   1.000000
# 2024-01-01 02:30:00        0.0   1.000000
# ...                        ...        ...
# 2024-02-11 22:00:00        0.5   0.866025
# 2024-02-11 22:30:00        0.5   0.866025
# 2024-02-11 23:00:00        0.5   0.866025
# 2024-02-11 23:30:00        0.5   0.866025
# 2024-02-12 00:00:00        0.5   0.866025
#
# [2016 rows x 11 columns]

# %%
df1_training  = data_training.copy()
beban_scaled, beban_min, beban_max  =scale_array(df1_training['Beban'].values)
df1_training['Beban']   =   beban_scaled


input_make_windows      =   df1_training.to_numpy()
output_make_windows     =   df1_training['Beban'].to_numpy()
x_train,    y_train     =  make_windows_autoregressive(input_make_windows, output_make_windows, input_width, label_width)

# %%
df_1_validation =   data_validation.copy()
beban_scaled_validation, _, _ = scale_array(df_1_validation['Beban'].values)
df_1_validation['Beban']    =   beban_scaled_validation


input_make_windows_validation   = df_1_validation.to_numpy()
output_make_windows_validation  = df_1_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows_autoregressive(input_make_windows_validation, output_make_windows_validation, input_width, label_width)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((15456, 48, 11), (15456, 1), (1968, 48, 11), (1968, 1))

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import time

def tensorflow_dense(X_train_scaled, Y_train_scaled, X_validation_scaled, Y_validation_scaled, 
                       learning_rate, target_MAE, jumlah_epochs, jumlah_sampel_batch,
                       jumlah_epoch_terbelakang, save_best_model_path, validation_data=False, load_model=None):
    global model

    class MAEStopCallback(tf.keras.callbacks.Callback):
        def __init__(self, threshold):
            super(MAEStopCallback, self).__init__()
            self.threshold = threshold

        def on_epoch_end(self, epoch, logs=None):
            if logs['mae'] < self.threshold:
                print(f"\nMAE reached below {self.threshold}. Stopping training.")
                self.model.stop_training = True

    # Mendapatkan dimensi input
    input_width = X_train_scaled.shape[1]   #  48 timesteps
    num_features = X_train_scaled.shape[2]    #11 fitur per timestep
    output_width = Y_train_scaled.shape[1]  # 48 timesteps

    model = tf.keras.models.Sequential()
    if load_model is None:
        model.add(tf.keras.layers.Input(shape=(input_width, num_features)))
        model.add(tf.keras.layers.Flatten())  # Mengubah bentuk dari (48, num_features) menjadi (48*num_features,)
        model.add(tf.keras.layers.Dense(256, activation='tanh'))
        model.add(tf.keras.layers.Dense(128, activation='tanh'))
        model.add(tf.keras.layers.Dense(64, activation='tanh'))
        model.add(tf.keras.layers.Dense(1))  # Output prediksi untuk timestep ke-49

    else:
        model = tf.keras.models.load_model(load_model)
    
    model.summary()
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mse', 'mae', 'mape', 
                               tf.keras.metrics.RootMeanSquaredError(name='rmse')])
    mae_stop_callback = MAEStopCallback(threshold=target_MAE)

    checkpoint_callback = ModelCheckpoint(
        save_best_model_path,
        monitor='val_mae',
        mode='min',
        save_best_only=True,
        verbose=1
    )

    early_stopping_callback = EarlyStopping(
        monitor='val_mae',
        mode='min',
        patience=jumlah_epoch_terbelakang,
        restore_best_weights=True,
        verbose=1
    )

    time_start = time.time()
    if validation_data:
        model.fit(X_train_scaled, Y_train_scaled, epochs=jumlah_epochs, batch_size=jumlah_sampel_batch,  
                  callbacks=[mae_stop_callback, checkpoint_callback, early_stopping_callback],
                  validation_data=(X_validation_scaled, Y_validation_scaled), validation_batch_size=jumlah_sampel_batch)
    else:
        model.fit(X_train_scaled, Y_train_scaled, epochs=jumlah_epochs, batch_size=jumlah_sampel_batch, 
                  callbacks=[mae_stop_callback, checkpoint_callback, early_stopping_callback])
    
    print("Time computation seconds: ", time.time() - time_start)
    
    loss, MSE, MAE, RMSE, MAPE = model.evaluate(X_train_scaled, Y_train_scaled)
    print("Loss:", loss, "MSE:", MSE, "MAE:", MAE, "RMSE:", RMSE)
    
    return model, loss, MSE, MAE, RMSE, MAPE

# %%
model, loss, MSE, MAE, RMSE, MAPE= tensorflow_dense(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.01,  jumlah_epochs=100, jumlah_sampel_batch=256, 
                                                  jumlah_epoch_terbelakang=10,  save_best_model_path = 'B_lowest_single_flatten.hdf5', 
                                                  validation_data=True, load_model=None)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 528)               0
#
#  dense (Dense)               (None, 256)               135424
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 176,641
# Trainable params: 176,641
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 60/61 [============================>.] - ETA: 0s - loss: 0.0711 - mse: 0.0711 - mae: 0.1870 - mape: 386.4654 - rmse: 0.2667
# Epoch 1: val_mae improved from inf to 0.16019, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 2s 10ms/step - loss: 0.0708 - mse: 0.0708 - mae: 0.1865 - mape: 384.5764 - rmse: 0.2661 - val_loss: 0.0381 - val_mse: 0.0381 - val_mae: 0.1602 - val_mape: 152.4663 - val_rmse: 0.1951
# Epoch 2/100
# 54/61 [=========================>....] - ETA: 0s - loss: 0.0125 - mse: 0.0125 - mae: 0.0859 - mape: 156.7067 - rmse: 0.1116
# Epoch 2: val_mae improved from 0.16019 to 0.13805, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0123 - mse: 0.0123 - mae: 0.0852 - mape: 152.4976 - rmse: 0.1108 - val_loss: 0.0285 - val_mse: 0.0285 - val_mae: 0.1380 - val_mape: 130.6144 - val_rmse: 0.1688
# Epoch 3/100
# 55/61 [==========================>...] - ETA: 0s - loss: 0.0086 - mse: 0.0086 - mae: 0.0719 - mape: 128.3976 - rmse: 0.0927
# Epoch 3: val_mae improved from 0.13805 to 0.12342, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0717 - mape: 132.1625 - rmse: 0.0925 - val_loss: 0.0232 - val_mse: 0.0232 - val_mae: 0.1234 - val_mape: 129.6766 - val_rmse: 0.1522
# Epoch 4/100
# 48/61 [======================>.......] - ETA: 0s - loss: 0.0072 - mse: 0.0072 - mae: 0.0655 - mape: 121.2903 - rmse: 0.0846
# Epoch 4: val_mae improved from 0.12342 to 0.11395, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0649 - mape: 113.3989 - rmse: 0.0837 - val_loss: 0.0197 - val_mse: 0.0197 - val_mae: 0.1140 - val_mape: 125.3180 - val_rmse: 0.1404
# Epoch 5/100
# 50/61 [=======================>......] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0591 - mape: 112.3148 - rmse: 0.0767
# Epoch 5: val_mae improved from 0.11395 to 0.10404, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0588 - mape: 109.0132 - rmse: 0.0762 - val_loss: 0.0166 - val_mse: 0.0166 - val_mae: 0.1040 - val_mape: 102.6914 - val_rmse: 0.1287
# Epoch 6/100
# 52/61 [========================>.....] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0547 - mape: 106.2568 - rmse: 0.0707
# Epoch 6: val_mae did not improve from 0.10404
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0545 - mape: 99.6340 - rmse: 0.0705 - val_loss: 0.0173 - val_mse: 0.0173 - val_mae: 0.1067 - val_mape: 103.0764 - val_rmse: 0.1314
# Epoch 7/100
# 54/61 [=========================>....] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0509 - mape: 92.1963 - rmse: 0.0660
# Epoch 7: val_mae improved from 0.10404 to 0.10167, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0509 - mape: 89.7115 - rmse: 0.0660 - val_loss: 0.0160 - val_mse: 0.0160 - val_mae: 0.1017 - val_mape: 87.6971 - val_rmse: 0.1263
# Epoch 8/100
# 51/61 [========================>.....] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0486 - mape: 86.2051 - rmse: 0.0630
# Epoch 8: val_mae improved from 0.10167 to 0.09592, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0483 - mape: 86.1489 - rmse: 0.0628 - val_loss: 0.0142 - val_mse: 0.0142 - val_mae: 0.0959 - val_mape: 93.6397 - val_rmse: 0.1192
# Epoch 9/100
# 51/61 [========================>.....] - ETA: 0s - loss: 0.0035 - mse: 0.0035 - mae: 0.0455 - mape: 81.8250 - rmse: 0.0591
# Epoch 9: val_mae did not improve from 0.09592
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0454 - mape: 78.4530 - rmse: 0.0589 - val_loss: 0.0143 - val_mse: 0.0143 - val_mae: 0.0968 - val_mape: 85.5956 - val_rmse: 0.1197
# Epoch 10/100
# 48/61 [======================>.......] - ETA: 0s - loss: 0.0031 - mse: 0.0031 - mae: 0.0429 - mape: 82.1928 - rmse: 0.0557
# Epoch 10: val_mae improved from 0.09592 to 0.09409, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0430 - mape: 80.1312 - rmse: 0.0559 - val_loss: 0.0134 - val_mse: 0.0134 - val_mae: 0.0941 - val_mape: 88.5692 - val_rmse: 0.1157
# Epoch 11/100
# 49/61 [=======================>......] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0417 - mape: 77.1893 - rmse: 0.0541
# Epoch 11: val_mae did not improve from 0.09409
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0416 - mape: 76.8364 - rmse: 0.0539 - val_loss: 0.0150 - val_mse: 0.0150 - val_mae: 0.0995 - val_mape: 90.5950 - val_rmse: 0.1225
# Epoch 12/100
# 56/61 [==========================>...] - ETA: 0s - loss: 0.0027 - mse: 0.0027 - mae: 0.0397 - mape: 74.9825 - rmse: 0.0518
# Epoch 12: val_mae did not improve from 0.09409
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0397 - mape: 74.6120 - rmse: 0.0517 - val_loss: 0.0139 - val_mse: 0.0139 - val_mae: 0.0959 - val_mape: 82.9681 - val_rmse: 0.1178
# Epoch 13/100
# 49/61 [=======================>......] - ETA: 0s - loss: 0.0025 - mse: 0.0025 - mae: 0.0390 - mape: 77.2360 - rmse: 0.0505
# Epoch 13: val_mae improved from 0.09409 to 0.08671, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0388 - mape: 73.4501 - rmse: 0.0504 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0867 - val_mape: 78.4838 - val_rmse: 0.1073
# Epoch 14/100
# 53/61 [=========================>....] - ETA: 0s - loss: 0.0023 - mse: 0.0023 - mae: 0.0372 - mape: 75.3327 - rmse: 0.0482
# Epoch 14: val_mae did not improve from 0.08671
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0370 - mape: 71.8195 - rmse: 0.0480 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0873 - val_mape: 76.5649 - val_rmse: 0.1079
# Epoch 15/100
# 57/61 [===========================>..] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0353 - mape: 66.7338 - rmse: 0.0460
# Epoch 15: val_mae improved from 0.08671 to 0.08370, saving model to B_lowest_single_flatten.hdf5
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0352 - mape: 65.5933 - rmse: 0.0459 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0837 - val_mape: 76.1136 - val_rmse: 0.1034
# Epoch 16/100
# 58/61 [===========================>..] - ETA: 0s - loss: 0.0020 - mse: 0.0020 - mae: 0.0346 - mape: 59.8908 - rmse: 0.0450
# Epoch 16: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0345 - mape: 59.0120 - rmse: 0.0450 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0899 - val_mape: 80.1919 - val_rmse: 0.1103
# Epoch 17/100
# 50/61 [=======================>......] - ETA: 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0331 - mape: 51.7035 - rmse: 0.0432
# Epoch 17: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0331 - mape: 59.8673 - rmse: 0.0432 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0844 - val_mape: 72.4992 - val_rmse: 0.1047
# Epoch 18/100
# 47/61 [======================>.......] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0318 - mape: 54.3704 - rmse: 0.0416
# Epoch 18: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0320 - mape: 57.0712 - rmse: 0.0417 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0848 - val_mape: 73.7528 - val_rmse: 0.1045
# Epoch 19/100
# 58/61 [===========================>..] - ETA: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0.0309 - mape: 56.8454 - rmse: 0.0404
# Epoch 19: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0309 - mape: 55.6683 - rmse: 0.0404 - val_loss: 0.0112 - val_mse: 0.0112 - val_mae: 0.0863 - val_mape: 79.0482 - val_rmse: 0.1056
# Epoch 20/100
# 60/61 [============================>.] - ETA: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0.0309 - mape: 54.7445 - rmse: 0.0402
# Epoch 20: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0308 - mape: 54.6268 - rmse: 0.0402 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0857 - val_mape: 76.4790 - val_rmse: 0.1053
# Epoch 21/100
# 55/61 [==========================>...] - ETA: 0s - loss: 0.0015 - mse: 0.0015 - mae: 0.0299 - mape: 53.9366 - rmse: 0.0390
# Epoch 21: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0298 - mape: 54.1898 - rmse: 0.0390 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0849 - val_mape: 82.3987 - val_rmse: 0.1041
# Epoch 22/100
# 47/61 [======================>.......] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0291 - mape: 49.5322 - rmse: 0.0378
# Epoch 22: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0291 - mape: 50.1315 - rmse: 0.0379 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0852 - val_mape: 77.8927 - val_rmse: 0.1041
# Epoch 23/100
# 48/61 [======================>.......] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0284 - mape: 46.7682 - rmse: 0.0369
# Epoch 23: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0284 - mape: 53.2008 - rmse: 0.0369 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0884 - val_mape: 77.9653 - val_rmse: 0.1073
# Epoch 24/100
# 49/61 [=======================>......] - ETA: 0s - loss: 0.0013 - mse: 0.0013 - mae: 0.0282 - mape: 42.1623 - rmse: 0.0365
# Epoch 24: val_mae did not improve from 0.08370
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0282 - mape: 47.1406 - rmse: 0.0365 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0855 - val_mape: 75.5943 - val_rmse: 0.1041
# Epoch 25/100
# 49/61 [=======================>......] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0271 - mape: 47.5997 - rmse: 0.0353
# Epoch 25: val_mae did not improve from 0.08370
# Restoring model weights from the end of the best epoch: 15.
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0272 - mape: 48.2001 - rmse: 0.0354 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0866 - val_mape: 80.7862 - val_rmse: 0.1061
# Epoch 25: early stopping
# Time computation seconds:  8.915448665618896
# 483/483 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0346 - mape: 61.3978 - rmse: 0.0451
# Loss: 0.0020370883867144585 MSE: 0.0020370883867144585 MAE: 0.034647341817617416 RMSE: 61.39779281616211

# %%
MSE, MAE, RMSE, MAPE
# Out:
# (0.0020370883867144585,
#  0.034647341817617416,
#  61.39779281616211,
#  0.04513411596417427)

# %%
predictions = model.predict(x_train[slice(None, None, label_width), :, :])
print(predictions.shape)
predictions_reshaped = predictions.reshape(-1,)
predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=beban_min, orig_max=beban_max)
predictions_unscaled.shape
# Out:
# 483/483 [==============================] - 1s 1ms/step
# (15456, 1)
# (15456,)

# %%
df_pred_act = compute_error(x_train, data_training['Beban'], ['Beban'], model, input_width,label_width, beban_min, beban_max)
df_pred_act
# Out:
# 483/483 [==============================] - 1s 1ms/step
# MAE: 297.5230314127604, MAPE %: 1.2060175575534056, MSE: 150214.34347923653, RMSE: 387.5749520792546
#                          Prediksi    Aktual
# Date
# 2023-02-13 00:30:00  19272.810547  19244.00
# 2023-02-13 01:00:00  19143.314453  19141.00
# 2023-02-13 01:30:00  18774.599609  18943.00
# 2023-02-13 02:00:00  18998.515625  18862.00
# 2023-02-13 02:30:00  19323.636719  18639.00
# ...                           ...       ...
# 2023-12-31 22:00:00  21372.679688  21241.27
# 2023-12-31 22:30:00  20887.021484  20800.42
# 2023-12-31 23:00:00  20450.632812  20450.02
# 2023-12-31 23:30:00  20219.898438  20175.87
# 2024-01-01 00:00:00  20066.000000  19802.04
#
# [15456 rows x 2 columns]

# %%
df= df_pred_act.copy()
plt.figure(figsize=(16, 6))

# Plot the "Actual" as a green line with dot markers
plt.plot(
    df.index, 
    df['Aktual'], 
    label='Actual output', 
    marker='.', 
    markersize=5, 
    color='#2ca02c', 
    zorder=-100
)

# Scatter plot for "Prediction" in orange X markers
plt.scatter(
    df.index, 
    df['Prediksi'], 
    marker='x', 
    #edgecolors='k', 
    label='Prediction', 
    c='#ff7f0e', 
    s=10
)


plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=30)
plt.title(' Actual and Predictions Over Time')
plt.tight_layout()
plt.show()

# %%
df_pred_act = compute_error(x_val, data_validation['Beban'], ['Beban'], model, input_width,label_width, beban_min, beban_max)
df_pred_act
# Out:
# 62/62 [==============================] - 0s 1ms/step
# MAE: 1059.8499954744666, MAPE %: 4.463770142665443, MSE: 1820764.5953719341, RMSE: 1349.3571044656542
#                          Prediksi    Aktual
# Date
# 2024-01-02 00:30:00  17707.449219  20109.84
# 2024-01-02 01:00:00  17540.160156  19904.52
# 2024-01-02 01:30:00  16845.810547  19715.16
# 2024-01-02 02:00:00  16916.884766  19513.55
# 2024-01-02 02:30:00  17112.791016  19368.73
# ...                           ...       ...
# 2024-02-11 22:00:00  20869.421875  23109.43
# 2024-02-11 22:30:00  20674.664062  22627.13
# 2024-02-11 23:00:00  20302.515625  22035.37
# 2024-02-11 23:30:00  20023.144531  21696.04
# 2024-02-12 00:00:00  19527.667969  21313.93
#
# [1968 rows x 2 columns]

# %%
df= df_pred_act.copy()
plt.figure(figsize=(16, 6))

# Plot the "Actual" as a green line with dot markers
plt.plot(
    df.index, 
    df['Aktual'], 
    label='Actual output', 
    marker='.', 
    markersize=5, 
    color='#2ca02c', 
    zorder=-100
)

# Scatter plot for "Prediction" in orange X markers
plt.scatter(
    df.index, 
    df['Prediksi'], 
    marker='x', 
    #edgecolors='k', 
    label='Prediction', 
    c='#ff7f0e', 
    s=15
)


plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=30)
plt.title(' Actual and Predictions Over Time')
plt.tight_layout()
plt.show()
