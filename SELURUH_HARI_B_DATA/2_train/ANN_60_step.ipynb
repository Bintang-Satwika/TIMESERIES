# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
# Parameter windowing
input_width = int(60)
label_width = 1
shift = label_width
total_window_size = input_width + shift
OUT_STEPS = label_width
# Definisikan irisan untuk input dan label
input_slice = slice(0, input_width)
label_start = total_window_size - label_width
labels_slice = slice(label_start, None)

from B_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive, make_windows

# %% [markdown]
# # data training

# %%
data_training_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_train_data.xlsx', index_col=0)
data_training= data_training_awal.astype('float32').copy()
data_training
# Out:
#                             Beban   Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2022-01-01 00:30:00  18402.000000  0.130526  0.991445 -0.974928 -0.222521
# 2022-01-01 01:00:00  18214.000000  0.258819  0.965926 -0.974928 -0.222521
# 2022-01-01 01:30:00  17974.000000  0.382683  0.923880 -0.974928 -0.222521
# 2022-01-01 02:00:00  17729.000000  0.500000  0.866025 -0.974928 -0.222521
# 2022-01-01 02:30:00  17532.000000  0.608761  0.793353 -0.974928 -0.222521
# ...                           ...       ...       ...       ...       ...
# 2024-10-30 22:00:00  29019.070312 -0.500000  0.866025  0.974928 -0.222521
# 2024-10-30 22:30:00  28465.740234 -0.382683  0.923880  0.974928 -0.222521
# 2024-10-30 23:00:00  27755.750000 -0.258819  0.965926  0.974928 -0.222521
# 2024-10-30 23:30:00  27277.500000 -0.130526  0.991445  0.974928 -0.222521
# 2024-10-31 00:00:00  26757.400391  0.000000  1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2022-01-01 00:30:00        0.0  1.000000e+00        0.762049 -4.403535
# 2022-01-01 01:00:00        0.0  1.000000e+00        0.762049 -4.566491
# 2022-01-01 01:30:00        0.0  1.000000e+00        0.762049 -4.811594
# 2022-01-01 02:00:00        0.0  1.000000e+00        0.762049 -5.056697
# 2022-01-01 02:30:00        0.0  1.000000e+00        0.762049 -5.223890
# ...                        ...           ...             ...       ...
# 2024-10-30 22:00:00       -1.0 -1.836970e-16        1.012018  0.447690
# 2024-10-30 22:30:00       -1.0 -1.836970e-16        1.012018  0.134316
# 2024-10-30 23:00:00       -1.0 -1.836970e-16        1.012018 -0.179059
# 2024-10-30 23:30:00       -1.0 -1.836970e-16        1.012018 -0.402285
# 2024-10-31 00:00:00       -1.0 -1.836970e-16        1.012018 -0.625510
#
# [49632 rows x 9 columns]

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean   24933.849609  1.229754e-09  0.000000e+00      0.000028      0.001729
# std     3040.183838  7.071139e-01  7.071139e-01      0.707530      0.706637
# min    13475.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%    22701.939941 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%    24934.724609  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%    27240.225586  7.071068e-01  7.071068e-01      0.781832      0.623490
# max    32758.619141  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        1.000537     -0.297909
# std    7.057171e-01  7.060366e-01        0.047190      4.279032
# min   -1.000000e+00 -1.000000e+00        0.697430    -10.782065
# 25%   -5.000000e-01 -8.660254e-01        1.012018     -3.767943
# 50%    1.224647e-16 -1.836970e-16        1.012018     -1.268959
# 75%    8.660254e-01  5.000000e-01        1.012018      2.886689
# max    1.000000e+00  1.000000e+00        1.012018     13.803565

# %%
data_training['Suhu_PCA'], min_suhu, max_suhu = scale_array(
    data_training['Suhu_PCA'].values, 
    new_min=-1,
    new_max=1)

data_training['Holiday_Impact'], min_holiday, max_holiday = scale_array(
    data_training['Holiday_Impact'].values, 
    new_min=-1, 
    new_max=1
)

data_training['Beban'], min_beban, max_beban = scale_array(
    data_training['Beban'].values, 
    new_min=-1, 
    new_max=1)
# Out:
# Computed orig_min: -10.782065391540527
# Computed orig_max: 13.80356502532959
# Computed orig_min: 0.6974297761917114
# Computed orig_max: 1.0120183229446411
# Computed orig_min: 13475.0
# Computed orig_max: 32758.619140625

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean       0.188454  1.229754e-09  0.000000e+00      0.000028      0.001729
# std        0.315313  7.071139e-01  7.071139e-01      0.707530      0.706637
# min       -1.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%       -0.043028 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.188545  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%        0.427660  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.000000  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        0.927008     -0.147131
# std    7.057171e-01  7.060366e-01        0.300029      0.348093
# min   -1.000000e+00 -1.000000e+00       -1.000000     -1.000000
# 25%   -5.000000e-01 -8.660254e-01        1.000000     -0.429413
# 50%    1.224647e-16 -1.836970e-16        1.000000     -0.226125
# 75%    8.660254e-01  5.000000e-01        1.000000      0.111930
# max    1.000000e+00  1.000000e+00        1.000000      1.000000

# %% [markdown]
# # data validation (testing)

# %%
data_validation_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_test_data.xlsx', index_col=0)
data_validation= data_validation_awal.astype('float32').copy()
data_validation
# Out:
#                             Beban       Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2024-10-31 00:30:00  26460.919922  1.305262e-01  0.991445  0.433884 -0.900969
# 2024-10-31 01:00:00  26184.929688  2.588190e-01  0.965926  0.433884 -0.900969
# 2024-10-31 01:30:00  25976.689453  3.826834e-01  0.923880  0.433884 -0.900969
# 2024-10-31 02:00:00  25745.220703  5.000000e-01  0.866025  0.433884 -0.900969
# 2024-10-31 02:30:00  25441.970703  6.087614e-01  0.793353  0.433884 -0.900969
# ...                           ...           ...       ...       ...       ...
# 2025-10-30 10:00:00  30957.800781  5.000000e-01 -0.866025  0.433884 -0.900969
# 2025-10-30 10:30:00  30580.789062  3.826834e-01 -0.923880  0.433884 -0.900969
# 2025-10-30 11:00:00  31497.359375  2.588190e-01 -0.965926  0.433884 -0.900969
# 2025-10-30 11:30:00  31337.589844  1.305262e-01 -0.991445  0.433884 -0.900969
# 2025-10-30 12:00:00  20014.880859  1.224647e-16 -1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2024-10-31 00:30:00       -1.0 -1.836970e-16        1.012018 -0.829108
# 2024-10-31 01:00:00       -1.0 -1.836970e-16        1.012018 -1.032705
# 2024-10-31 01:30:00       -1.0 -1.836970e-16        1.012018 -1.284443
# 2024-10-31 02:00:00       -1.0 -1.836970e-16        1.012018 -1.536183
# 2024-10-31 02:30:00       -1.0 -1.836970e-16        1.012018 -1.717856
# ...                        ...           ...             ...       ...
# 2025-10-30 10:00:00       -1.0 -1.836970e-16        1.012018  3.765654
# 2025-10-30 10:30:00       -1.0 -1.836970e-16        1.012018  4.427866
# 2025-10-30 11:00:00       -1.0 -1.836970e-16        1.012018  5.090077
# 2025-10-30 11:30:00       -1.0 -1.836970e-16        1.012018  5.516177
# 2025-10-30 12:00:00       -1.0 -1.836970e-16        1.012018  5.942276
#
# [17496 rows x 9 columns]

# %%
data_validation['Suhu_PCA'], _, _ = scale_array(
    data_validation['Suhu_PCA'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_suhu,
    orig_max=max_suhu
)
data_validation['Holiday_Impact'], _, _ = scale_array(
    data_validation['Holiday_Impact'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_holiday,
    orig_max=max_holiday
)
data_validation['Beban'], _, _ = scale_array(
    data_validation['Beban'].values, 
    new_min=-1, 
    new_max=1,
    orig_min=min_beban,
    orig_max=max_beban
)

# %%
data_validation.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  17496.000000  1.749600e+04  1.749600e+04  17496.000000  17496.000000
# mean       0.389520  8.720320e-04 -5.715587e-05      0.000595     -0.001236
# std        0.317044  7.071220e-01  7.071295e-01      0.706819      0.707422
# min       -0.775485 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        0.158968 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.385124  1.224647e-16 -6.123234e-17      0.000000     -0.222521
# 75%        0.668971  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.139628  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17496.000000  1.749600e+04    17496.000000  17496.000000
# mean      -0.002107 -4.751840e-03        0.927556     -0.054150
# std        0.706636  7.075914e-01        0.295125      0.311896
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310872
# 50%        0.000000 -1.836970e-16        1.000000     -0.119035
# 75%        0.866025  5.000000e-01        1.000000      0.207501
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
x_train,    y_train     =   make_windows(input_make_windows, output_make_windows,total_window_size, input_slice, labels_slice)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows(input_make_windows_validation, output_make_windows_validation,total_window_size, input_slice, labels_slice)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((49572, 60, 9), (49572, 1), (17436, 60, 9), (17436, 1))

# %%
x_train.dtype, y_train.dtype, x_val.dtype, y_val.dtype
# Out:
# (dtype('float32'), dtype('float32'), dtype('float32'), dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

seed_value = 20
tf.random.set_seed(seed_value)
import json
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, History
import time


def tensorflow_model(X_train_scaled, Y_train_scaled,
                   X_val_scaled,   Y_val_scaled,
                   learning_rate=1e-3,
                   target_MAE=0.001,
                   jumlah_epochs=50,
                   jumlah_sampel_batch=1,
                   jumlah_epoch_terbelakang=10,
                   save_best_model_path="model.h5",
                   validation_data=False,
                   load_model=None, seed_value=-1):

    global model, loss_history
    model= None
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    # History callback to capture training curves
    history_cb = History()

    # ---------- model ----------
    input_width  = X_train_scaled.shape[1]   # timestep input
    num_features = X_train_scaled.shape[2]   # number of features

    if load_model is None:
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.Input(shape=(input_width, num_features)))
        model.add(tf.keras.layers.Flatten())  # Mengubah bentuk dari (timestep, num_features) menjadi (timestep*num_features,)

        model.add(tf.keras.layers.Dense(128, activation='tanh'))

        # Output layer
        model.add(tf.keras.layers.Dense(1, activation='linear'))  # Output prediksi untuk timestep ke-49


    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')],
                  steps_per_execution=128)

    # ---------- build callback list ----------
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(50, root=save_best_model_path.rstrip('.h5'))
    ]

    if validation_data:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=(X_val_scaled, Y_val_scaled) if validation_data else None,
                  validation_batch_size=jumlah_sampel_batch,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        # Save history to JSON even if training stopped early
        loss_history = {
            'loss': history_cb.history.get('loss', [])
        }
        if validation_data:
            loss_history['val_loss'] = history_cb.history.get('val_loss', [])
        with open('loss_history_%s.json'%seed_value, 'w') as f:
            json.dump(loss_history, f)
        print("Saved training & validation loss history to loss_history.json")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.001,  jumlah_epochs=100, jumlah_sampel_batch=32, 
                                                    jumlah_epoch_terbelakang=20,  save_best_model_path = "ANN%s_60_100_200.h5"%seed_value, 
                                                    validation_data=True, load_model='ANN20_60_epoch100.h5', seed_value=seed_value)

    print(loss, MSE, MAE, MAPE)
    print("model.evaluate(x_val, y_val): ", model.evaluate(x_val, y_val))
    predictions = model.predict(x_train[slice(None, None, label_width), :, :])
    predictions_reshaped = predictions.reshape(-1,)
    predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
    df_pred_act = compute_error(x_train, data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)
    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()







    df_pred_act = compute_error(x_val, data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)

    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# Running with seed: 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 540)               0
#
#  dense (Dense)               (None, 128)               69248
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 69,377
# Trainable params: 69,377
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0470 - mse: 0.0470 - mae: 0.1610 - mape: 344.4130
# Epoch 1: val_mse improved from inf to 0.06481, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 4s 3ms/step - loss: 0.0468 - mse: 0.0468 - mae: 0.1607 - mape: 342.3270 - val_loss: 0.0648 - val_mse: 0.0648 - val_mae: 0.1981 - val_mape: 358.8503
# Epoch 2/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0319 - mse: 0.0319 - mae: 0.1332 - mape: 278.7049
# Epoch 2: val_mse did not improve from 0.06481
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0322 - mse: 0.0322 - mae: 0.1340 - mape: 278.6276 - val_loss: 0.1075 - val_mse: 0.1075 - val_mae: 0.2627 - val_mape: 311.0558
# Epoch 3/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0255 - mse: 0.0255 - mae: 0.1187 - mape: 237.3810
# Epoch 3: val_mse did not improve from 0.06481
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0256 - mse: 0.0256 - mae: 0.1190 - mape: 237.2615 - val_loss: 0.0814 - val_mse: 0.0814 - val_mae: 0.2269 - val_mape: 308.9182
# Epoch 4/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0209 - mse: 0.0209 - mae: 0.1110 - mape: 228.7939
# Epoch 4: val_mse did not improve from 0.06481
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0208 - mse: 0.0208 - mae: 0.1108 - mape: 228.1285 - val_loss: 0.0666 - val_mse: 0.0666 - val_mae: 0.2011 - val_mape: 300.9551
# Epoch 5/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0180 - mse: 0.0180 - mae: 0.1027 - mape: 219.2308
# Epoch 5: val_mse improved from 0.06481 to 0.04015, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0179 - mse: 0.0179 - mae: 0.1022 - mape: 218.1164 - val_loss: 0.0402 - val_mse: 0.0402 - val_mae: 0.1547 - val_mape: 290.4038
# Epoch 6/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0154 - mse: 0.0154 - mae: 0.0937 - mape: 200.3329
# Epoch 6: val_mse did not improve from 0.04015
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0154 - mse: 0.0154 - mae: 0.0935 - mape: 198.8969 - val_loss: 0.0763 - val_mse: 0.0763 - val_mae: 0.2165 - val_mape: 353.3286
# Epoch 7/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0118 - mse: 0.0118 - mae: 0.0832 - mape: 177.5174
# Epoch 7: val_mse did not improve from 0.04015
# 1550/1550 [==============================] - 4s 3ms/step - loss: 0.0117 - mse: 0.0117 - mae: 0.0832 - mape: 176.7034 - val_loss: 0.0567 - val_mse: 0.0567 - val_mae: 0.2016 - val_mape: 399.4935
# Epoch 8/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0103 - mse: 0.0103 - mae: 0.0787 - mape: 163.5703
# Epoch 8: val_mse improved from 0.04015 to 0.03832, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0785 - mape: 162.3577 - val_loss: 0.0383 - val_mse: 0.0383 - val_mae: 0.1697 - val_mape: 491.0858
# Epoch 9/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0094 - mse: 0.0094 - mae: 0.0746 - mape: 161.8548
# Epoch 9: val_mse did not improve from 0.03832
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0744 - mape: 160.6176 - val_loss: 0.0732 - val_mse: 0.0732 - val_mae: 0.2428 - val_mape: 568.3196
# Epoch 10/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0101 - mse: 0.0101 - mae: 0.0736 - mape: 168.8335
# Epoch 10: val_mse improved from 0.03832 to 0.03458, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0732 - mape: 167.7091 - val_loss: 0.0346 - val_mse: 0.0346 - val_mae: 0.1599 - val_mape: 429.4914
# Epoch 11/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0084 - mse: 0.0084 - mae: 0.0687 - mape: 159.5031
# Epoch 11: val_mse improved from 0.03458 to 0.02936, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0684 - mape: 158.8525 - val_loss: 0.0294 - val_mse: 0.0294 - val_mae: 0.1430 - val_mape: 418.7850
# Epoch 12/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0079 - mse: 0.0079 - mae: 0.0665 - mape: 147.3811
# Epoch 12: val_mse improved from 0.02936 to 0.01346, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0662 - mape: 146.8658 - val_loss: 0.0135 - val_mse: 0.0135 - val_mae: 0.0900 - val_mape: 294.8686
# Epoch 13/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0067 - mse: 0.0067 - mae: 0.0620 - mape: 132.1462
# Epoch 13: val_mse did not improve from 0.01346
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0617 - mape: 131.6719 - val_loss: 0.0141 - val_mse: 0.0141 - val_mae: 0.0936 - val_mape: 241.9503
# Epoch 14/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0591 - mape: 120.8253
# Epoch 14: val_mse did not improve from 0.01346
# 1550/1550 [==============================] - 4s 3ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0588 - mape: 120.1694 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.0935 - val_mape: 207.9022
# Epoch 15/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0559 - mape: 109.6344
# Epoch 15: val_mse did not improve from 0.01346
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0557 - mape: 108.9707 - val_loss: 0.0170 - val_mse: 0.0170 - val_mae: 0.1069 - val_mape: 209.1565
# Epoch 16/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0529 - mape: 100.6595
# Epoch 16: val_mse did not improve from 0.01346
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0526 - mape: 99.9848 - val_loss: 0.0162 - val_mse: 0.0162 - val_mae: 0.1044 - val_mape: 205.6961
# Epoch 17/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0501 - mape: 92.2381
# Epoch 17: val_mse did not improve from 0.01346
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0499 - mape: 91.6276 - val_loss: 0.0159 - val_mse: 0.0159 - val_mae: 0.1030 - val_mape: 209.8404
# Epoch 18/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0480 - mape: 90.8903
# Epoch 18: val_mse improved from 0.01346 to 0.01282, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0478 - mape: 90.2757 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0912 - val_mape: 176.6066
# Epoch 19/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0039 - mse: 0.0039 - mae: 0.0469 - mape: 89.0526
# Epoch 19: val_mse improved from 0.01282 to 0.01241, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0467 - mape: 88.5243 - val_loss: 0.0124 - val_mse: 0.0124 - val_mae: 0.0910 - val_mape: 135.0100
# Epoch 20/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0470 - mape: 85.1986
# Epoch 20: val_mse did not improve from 0.01241
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0468 - mape: 85.0037 - val_loss: 0.0186 - val_mse: 0.0186 - val_mae: 0.1140 - val_mape: 161.4559
# Epoch 21/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0037 - mse: 0.0037 - mae: 0.0450 - mape: 88.5639
# Epoch 21: val_mse did not improve from 0.01241
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0448 - mape: 88.2562 - val_loss: 0.0156 - val_mse: 0.0156 - val_mae: 0.1046 - val_mape: 141.3449
# Epoch 22/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0433 - mape: 85.8137
# Epoch 22: val_mse did not improve from 0.01241
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0431 - mape: 85.3859 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0922 - val_mape: 123.0189
# Epoch 23/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - mae: 0.0421 - mape: 85.2375
# Epoch 23: val_mse improved from 0.01241 to 0.00891, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 4s 2ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0419 - mape: 84.7233 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0742 - val_mape: 124.8130
# Epoch 24/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0028 - mae: 0.0411 - mape: 82.3409
# Epoch 24: val_mse improved from 0.00891 to 0.00579, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0409 - mape: 81.8431 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0590 - val_mape: 109.9609
# Epoch 25/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0027 - mse: 0.0027 - mae: 0.0405 - mape: 79.5644
# Epoch 25: val_mse did not improve from 0.00579
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0403 - mape: 79.0636 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0724 - val_mape: 133.4830
# Epoch 26/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0029 - mse: 0.0029 - mae: 0.0407 - mape: 81.2543
# Epoch 26: val_mse did not improve from 0.00579
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0405 - mape: 80.8216 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0618 - val_mape: 136.0377
# Epoch 27/200
# 1550/1550 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0375 - mape: 78.4396
# Epoch 27: val_mse improved from 0.00579 to 0.00518, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 4s 2ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0375 - mape: 78.4396 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0556 - val_mape: 175.7758
# Epoch 28/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0373 - mape: 80.0876
# Epoch 28: val_mse improved from 0.00518 to 0.00470, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0372 - mape: 79.5985 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0531 - val_mape: 135.0740
# Epoch 29/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0022 - mse: 0.0022 - mae: 0.0362 - mape: 77.4287
# Epoch 29: val_mse did not improve from 0.00470
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0361 - mape: 76.9840 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0576 - val_mape: 159.2275
# Epoch 30/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0353 - mape: 78.7178
# Epoch 30: val_mse did not improve from 0.00470
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0352 - mape: 78.1503 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0551 - val_mape: 163.6996
# Epoch 31/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0352 - mape: 77.7606
# Epoch 31: val_mse did not improve from 0.00470
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0351 - mape: 77.3304 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0552 - val_mape: 134.0398
# Epoch 32/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0022 - mse: 0.0022 - mae: 0.0357 - mape: 76.9615
# Epoch 32: val_mse improved from 0.00470 to 0.00382, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0355 - mape: 76.6674 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0468 - val_mape: 106.8633
# Epoch 33/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020 - mae: 0.0337 - mape: 74.2264
# Epoch 33: val_mse did not improve from 0.00382
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0336 - mape: 73.8682 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0470 - val_mape: 86.7882
# Epoch 34/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0334 - mape: 74.1713
# Epoch 34: val_mse did not improve from 0.00382
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0333 - mape: 73.9126 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0464 - val_mape: 82.9474
# Epoch 35/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0327 - mape: 75.9762
# Epoch 35: val_mse improved from 0.00382 to 0.00356, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0326 - mape: 75.7654 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0442 - val_mape: 74.6757
# Epoch 36/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0319 - mape: 74.7263
# Epoch 36: val_mse improved from 0.00356 to 0.00341, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0319 - mape: 74.5633 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0436 - val_mape: 71.0976
# Epoch 37/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0309 - mape: 72.8811
# Epoch 37: val_mse improved from 0.00341 to 0.00293, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0308 - mape: 72.7366 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 70.9367
# Epoch 38/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0.0303 - mape: 71.6149
# Epoch 38: val_mse improved from 0.00293 to 0.00283, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0302 - mape: 71.4705 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0391 - val_mape: 76.1647
# Epoch 39/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0307 - mape: 69.1916
# Epoch 39: val_mse did not improve from 0.00283
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0306 - mape: 69.0533 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0485 - val_mape: 111.7641
# Epoch 40/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0306 - mape: 69.7254
# Epoch 40: val_mse did not improve from 0.00283
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0305 - mape: 69.5362 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0544 - val_mape: 165.3144
# Epoch 41/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0015 - mse: 0.0015 - mae: 0.0294 - mape: 68.8923
# Epoch 41: val_mse did not improve from 0.00283
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0293 - mape: 68.6520 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0453 - val_mape: 109.9924
# Epoch 42/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0287 - mape: 67.8437
# Epoch 42: val_mse did not improve from 0.00283
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0286 - mape: 67.5622 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0403 - val_mape: 72.6161
# Epoch 43/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0015 - mse: 0.0015 - mae: 0.0288 - mape: 65.5932
# Epoch 43: val_mse did not improve from 0.00283
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0287 - mape: 65.3988 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0463 - val_mape: 72.3640
# Epoch 44/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0277 - mape: 62.4461
# Epoch 44: val_mse improved from 0.00283 to 0.00259, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0276 - mape: 62.3282 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0372 - val_mape: 77.5473
# Epoch 45/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0013 - mse: 0.0013 - mae: 0.0266 - mape: 60.6352
# Epoch 45: val_mse did not improve from 0.00259
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0265 - mape: 60.5457 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0384 - val_mape: 69.9489
# Epoch 46/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0263 - mape: 59.6192
# Epoch 46: val_mse did not improve from 0.00259
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0262 - mape: 59.5037 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0438 - val_mape: 92.0712
# Epoch 47/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0013 - mse: 0.0013 - mae: 0.0270 - mape: 63.4461
# Epoch 47: val_mse did not improve from 0.00259
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0269 - mape: 63.2058 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0440 - val_mape: 118.4121
# Epoch 48/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0013 - mse: 0.0013 - mae: 0.0269 - mape: 62.4021
# Epoch 48: val_mse did not improve from 0.00259
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0268 - mape: 62.0417 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0423 - val_mape: 59.3440
# Epoch 49/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0258 - mape: 54.7588
# Epoch 49: val_mse improved from 0.00259 to 0.00233, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0257 - mape: 54.5470 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0364 - val_mape: 55.4060
# Epoch 50/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0248 - mape: 53.3472
# 📦  Saved checkpoint: ANN20_60_epoch50.h5
#
# Epoch 50: val_mse improved from 0.00233 to 0.00217, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 4s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0247 - mape: 53.2274 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0339 - val_mape: 47.7484
# Epoch 51/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - mape: 55.9759
# Epoch 51: val_mse did not improve from 0.00217
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - mape: 55.8089 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0470 - val_mape: 100.2729
# Epoch 52/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - mape: 57.0471
# Epoch 52: val_mse did not improve from 0.00217
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - mape: 56.8537 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0422 - val_mape: 124.9182
# Epoch 53/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0252 - mape: 57.2646
# Epoch 53: val_mse did not improve from 0.00217
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0251 - mape: 56.9336 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0461 - val_mape: 66.2783
# Epoch 54/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0243 - mape: 53.6021
# Epoch 54: val_mse improved from 0.00217 to 0.00216, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0243 - mape: 53.3661 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0350 - val_mape: 57.8224
# Epoch 55/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0010 - mse: 0.0010 - mae: 0.0237 - mape: 51.0926
# Epoch 55: val_mse did not improve from 0.00216
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0237 - mape: 50.9344 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0392 - val_mape: 66.7177
# Epoch 56/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0010 - mse: 0.0010 - mae: 0.0236 - mape: 49.2873
# Epoch 56: val_mse did not improve from 0.00216
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0236 - mape: 49.1604 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0460 - val_mape: 63.7304
# Epoch 57/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.6158e-04 - mse: 9.6158e-04 - mae: 0.0228 - mape: 49.3177
# Epoch 57: val_mse did not improve from 0.00216
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.5737e-04 - mse: 9.5737e-04 - mae: 0.0228 - mape: 49.2227 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0338 - val_mape: 48.1699
# Epoch 58/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0240 - mape: 54.8948
# Epoch 58: val_mse did not improve from 0.00216
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0240 - mape: 54.7064 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 85.3180
# Epoch 59/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0237 - mape: 51.1910
# Epoch 59: val_mse did not improve from 0.00216
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0237 - mape: 50.9157 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0386 - val_mape: 70.5276
# Epoch 60/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.6237e-04 - mse: 9.6237e-04 - mae: 0.0226 - mape: 48.5186
# Epoch 60: val_mse did not improve from 0.00216
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.5785e-04 - mse: 9.5785e-04 - mae: 0.0226 - mape: 48.2911 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0366 - val_mape: 55.4622
# Epoch 61/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.3814e-04 - mse: 9.3814e-04 - mae: 0.0224 - mape: 44.7625
# Epoch 61: val_mse improved from 0.00216 to 0.00211, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.3413e-04 - mse: 9.3413e-04 - mae: 0.0223 - mape: 44.6319 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0330 - val_mape: 54.5521
# Epoch 62/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.9500e-04 - mse: 9.9500e-04 - mae: 0.0232 - mape: 50.1510
# Epoch 62: val_mse did not improve from 0.00211
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.9051e-04 - mse: 9.9051e-04 - mae: 0.0231 - mape: 49.9995 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0357 - val_mape: 53.0367
# Epoch 63/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0237 - mape: 51.3621
# Epoch 63: val_mse did not improve from 0.00211
# 1550/1550 [==============================] - 3s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0237 - mape: 51.1712 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0380 - val_mape: 72.9597
# Epoch 64/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.2498e-04 - mse: 9.2498e-04 - mae: 0.0221 - mape: 48.1545
# Epoch 64: val_mse did not improve from 0.00211
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.2055e-04 - mse: 9.2055e-04 - mae: 0.0221 - mape: 47.8981 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0412 - val_mape: 71.0307
# Epoch 65/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.0610e-04 - mse: 9.0610e-04 - mae: 0.0218 - mape: 44.8546
# Epoch 65: val_mse improved from 0.00211 to 0.00191, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.0168e-04 - mse: 9.0168e-04 - mae: 0.0218 - mape: 44.6829 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0312 - val_mape: 54.7965
# Epoch 66/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.6056e-04 - mse: 8.6056e-04 - mae: 0.0217 - mape: 43.8605
# Epoch 66: val_mse did not improve from 0.00191
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.5722e-04 - mse: 8.5722e-04 - mae: 0.0217 - mape: 43.7533 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0312 - val_mape: 49.3892
# Epoch 67/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.2617e-04 - mse: 8.2617e-04 - mae: 0.0212 - mape: 46.2815
# Epoch 67: val_mse did not improve from 0.00191
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.2296e-04 - mse: 8.2296e-04 - mae: 0.0212 - mape: 46.2056 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0368 - val_mape: 62.7891
# Epoch 68/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 9.2071e-04 - mse: 9.2071e-04 - mae: 0.0220 - mape: 48.2892
# Epoch 68: val_mse did not improve from 0.00191
# 1550/1550 [==============================] - 3s 2ms/step - loss: 9.1643e-04 - mse: 9.1643e-04 - mae: 0.0219 - mape: 48.1161 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0350 - val_mape: 57.7042
# Epoch 69/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.5566e-04 - mse: 8.5566e-04 - mae: 0.0212 - mape: 45.1250
# Epoch 69: val_mse did not improve from 0.00191
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.5183e-04 - mse: 8.5183e-04 - mae: 0.0212 - mape: 44.8788 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0376 - val_mape: 77.1330
# Epoch 70/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.9558e-04 - mse: 8.9558e-04 - mae: 0.0215 - mape: 44.2364
# Epoch 70: val_mse did not improve from 0.00191
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.9104e-04 - mse: 8.9104e-04 - mae: 0.0214 - mape: 44.0440 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0318 - val_mape: 67.8851
# Epoch 71/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.7036e-04 - mse: 7.7036e-04 - mae: 0.0205 - mape: 40.5552
# Epoch 71: val_mse improved from 0.00191 to 0.00176, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.6699e-04 - mse: 7.6699e-04 - mae: 0.0204 - mape: 40.4535 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0304 - val_mape: 53.2032
# Epoch 72/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.3143e-04 - mse: 8.3143e-04 - mae: 0.0211 - mape: 47.0890
# Epoch 72: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.2789e-04 - mse: 8.2789e-04 - mae: 0.0211 - mape: 46.9853 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0346 - val_mape: 56.9397
# Epoch 73/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.8451e-04 - mse: 8.8451e-04 - mae: 0.0215 - mape: 44.7638
# Epoch 73: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.8037e-04 - mse: 8.8037e-04 - mae: 0.0214 - mape: 44.5553 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0357 - val_mape: 60.4905
# Epoch 74/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.2611e-04 - mse: 8.2611e-04 - mae: 0.0207 - mape: 44.6709
# Epoch 74: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.2201e-04 - mse: 8.2201e-04 - mae: 0.0206 - mape: 44.4194 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0396 - val_mape: 86.7354
# Epoch 75/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.2709e-04 - mse: 8.2709e-04 - mae: 0.0205 - mape: 41.0124
# Epoch 75: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.2288e-04 - mse: 8.2288e-04 - mae: 0.0205 - mape: 40.8588 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0315 - val_mape: 49.1401
# Epoch 76/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.4806e-04 - mse: 7.4806e-04 - mae: 0.0203 - mape: 42.3013
# Epoch 76: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.4544e-04 - mse: 7.4544e-04 - mae: 0.0203 - mape: 42.2099 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0366 - val_mape: 57.1636
# Epoch 77/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.8444e-04 - mse: 7.8444e-04 - mae: 0.0204 - mape: 43.4869
# Epoch 77: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.8120e-04 - mse: 7.8120e-04 - mae: 0.0204 - mape: 43.3615 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0333 - val_mape: 49.8020
# Epoch 78/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.6069e-04 - mse: 7.6069e-04 - mae: 0.0201 - mape: 42.2263
# Epoch 78: val_mse did not improve from 0.00176
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.5738e-04 - mse: 7.5738e-04 - mae: 0.0200 - mape: 42.0076 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0448 - val_mape: 78.0298
# Epoch 79/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 8.9180e-04 - mse: 8.9180e-04 - mae: 0.0211 - mape: 43.4733
# Epoch 79: val_mse improved from 0.00176 to 0.00171, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 8.8669e-04 - mse: 8.8669e-04 - mae: 0.0211 - mape: 43.2286 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0296 - val_mape: 51.5944
# Epoch 80/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.6326e-04 - mse: 6.6326e-04 - mae: 0.0191 - mape: 39.5042
# Epoch 80: val_mse did not improve from 0.00171
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.6071e-04 - mse: 6.6071e-04 - mae: 0.0190 - mape: 39.4155 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0317 - val_mape: 50.4632
# Epoch 81/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.3155e-04 - mse: 7.3155e-04 - mae: 0.0198 - mape: 42.0644
# Epoch 81: val_mse did not improve from 0.00171
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.2881e-04 - mse: 7.2881e-04 - mae: 0.0197 - mape: 41.9687 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0369 - val_mape: 50.1957
# Epoch 82/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.8849e-04 - mse: 6.8849e-04 - mae: 0.0192 - mape: 40.3825
# Epoch 82: val_mse did not improve from 0.00171
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.8589e-04 - mse: 6.8589e-04 - mae: 0.0192 - mape: 40.2241 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0331 - val_mape: 54.0716
# Epoch 83/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.9967e-04 - mse: 7.9967e-04 - mae: 0.0201 - mape: 41.6135
# Epoch 83: val_mse did not improve from 0.00171
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.9537e-04 - mse: 7.9537e-04 - mae: 0.0200 - mape: 41.3841 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0331 - val_mape: 71.9538
# Epoch 84/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.4754e-04 - mse: 6.4754e-04 - mae: 0.0186 - mape: 38.1399
# Epoch 84: val_mse improved from 0.00171 to 0.00164, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.4480e-04 - mse: 6.4480e-04 - mae: 0.0185 - mape: 38.0339 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0298 - val_mape: 50.1814
# Epoch 85/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.1109e-04 - mse: 7.1109e-04 - mae: 0.0195 - mape: 41.0784
# Epoch 85: val_mse did not improve from 0.00164
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.0843e-04 - mse: 7.0843e-04 - mae: 0.0195 - mape: 40.9696 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0360 - val_mape: 48.9306
# Epoch 86/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.7961e-04 - mse: 6.7961e-04 - mae: 0.0191 - mape: 39.9016
# Epoch 86: val_mse did not improve from 0.00164
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.7708e-04 - mse: 6.7708e-04 - mae: 0.0190 - mape: 39.7369 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0303 - val_mape: 49.9015
# Epoch 87/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.0636e-04 - mse: 7.0636e-04 - mae: 0.0191 - mape: 40.4631
# Epoch 87: val_mse did not improve from 0.00164
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.0302e-04 - mse: 7.0302e-04 - mae: 0.0191 - mape: 40.2458 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0406 - val_mape: 76.2137
# Epoch 88/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.1564e-04 - mse: 7.1564e-04 - mae: 0.0191 - mape: 38.5448
# Epoch 88: val_mse improved from 0.00164 to 0.00157, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.1209e-04 - mse: 7.1209e-04 - mae: 0.0191 - mape: 38.3910 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0286 - val_mape: 43.3846
# Epoch 89/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.7057e-04 - mse: 6.7057e-04 - mae: 0.0191 - mape: 39.1065
# Epoch 89: val_mse did not improve from 0.00157
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.6823e-04 - mse: 6.6823e-04 - mae: 0.0191 - mape: 38.9622 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0388 - val_mape: 69.2806
# Epoch 90/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.6579e-04 - mse: 6.6579e-04 - mae: 0.0188 - mape: 38.2150
# Epoch 90: val_mse did not improve from 0.00157
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.6327e-04 - mse: 6.6327e-04 - mae: 0.0188 - mape: 38.0855 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0300 - val_mape: 42.8077
# Epoch 91/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.6010e-04 - mse: 6.6010e-04 - mae: 0.0186 - mape: 39.0870
# Epoch 91: val_mse did not improve from 0.00157
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.5727e-04 - mse: 6.5727e-04 - mae: 0.0186 - mape: 38.8820 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0441 - val_mape: 69.5982
# Epoch 92/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.6221e-04 - mse: 7.6221e-04 - mae: 0.0196 - mape: 39.4609
# Epoch 92: val_mse improved from 0.00157 to 0.00148, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.5802e-04 - mse: 7.5802e-04 - mae: 0.0195 - mape: 39.2586 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0269 - val_mape: 43.2592
# Epoch 93/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.9207e-04 - mse: 5.9207e-04 - mae: 0.0180 - mape: 37.4153
# Epoch 93: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.9006e-04 - mse: 5.9006e-04 - mae: 0.0180 - mape: 37.3163 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0337 - val_mape: 61.0307
# Epoch 94/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.4300e-04 - mse: 6.4300e-04 - mae: 0.0185 - mape: 37.9706
# Epoch 94: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.4067e-04 - mse: 6.4067e-04 - mae: 0.0185 - mape: 37.8726 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0327 - val_mape: 43.7053
# Epoch 95/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.1321e-04 - mse: 6.1321e-04 - mae: 0.0181 - mape: 37.3924
# Epoch 95: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.1080e-04 - mse: 6.1080e-04 - mae: 0.0181 - mape: 37.2388 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0359 - val_mape: 53.6345
# Epoch 96/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 7.1161e-04 - mse: 7.1161e-04 - mae: 0.0190 - mape: 38.7140
# Epoch 96: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 7.0791e-04 - mse: 7.0791e-04 - mae: 0.0189 - mape: 38.5105 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0276 - val_mape: 53.9484
# Epoch 97/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.9228e-04 - mse: 5.9228e-04 - mae: 0.0178 - mape: 36.7903
# Epoch 97: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.8994e-04 - mse: 5.8994e-04 - mae: 0.0178 - mape: 36.6867 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0335 - val_mape: 52.5574
# Epoch 98/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.8228e-04 - mse: 5.8228e-04 - mae: 0.0178 - mape: 36.7608
# Epoch 98: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.8050e-04 - mse: 5.8050e-04 - mae: 0.0178 - mape: 36.6949 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0295 - val_mape: 41.2659
# Epoch 99/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.1876e-04 - mse: 6.1876e-04 - mae: 0.0182 - mape: 39.2151
# Epoch 99: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.1632e-04 - mse: 6.1632e-04 - mae: 0.0182 - mape: 39.0479 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0273 - val_mape: 37.4772
# Epoch 100/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.9408e-04 - mse: 5.9408e-04 - mae: 0.0176 - mape: 38.3006
# 📦  Saved checkpoint: ANN20_60_epoch100.h5
#
# Epoch 100: val_mse did not improve from 0.00148
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.9183e-04 - mse: 5.9183e-04 - mae: 0.0176 - mape: 38.1099 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0378 - val_mape: 61.4499
# Epoch 101/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.9222e-04 - mse: 6.9222e-04 - mae: 0.0189 - mape: 37.6716
# Epoch 101: val_mse improved from 0.00148 to 0.00143, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.8875e-04 - mse: 6.8875e-04 - mae: 0.0188 - mape: 37.4921 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0265 - val_mape: 43.3456
# Epoch 102/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.5759e-04 - mse: 5.5759e-04 - mae: 0.0174 - mape: 36.2446
# Epoch 102: val_mse improved from 0.00143 to 0.00137, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.5568e-04 - mse: 5.5568e-04 - mae: 0.0174 - mape: 36.1511 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0265 - val_mape: 41.9005
# Epoch 103/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.0805e-04 - mse: 6.0805e-04 - mae: 0.0180 - mape: 38.8506
# Epoch 103: val_mse did not improve from 0.00137
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.0566e-04 - mse: 6.0566e-04 - mae: 0.0180 - mape: 38.7261 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0255 - val_mape: 39.0313
# Epoch 104/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.8637e-04 - mse: 5.8637e-04 - mae: 0.0177 - mape: 37.6399
# Epoch 104: val_mse did not improve from 0.00137
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.8415e-04 - mse: 5.8415e-04 - mae: 0.0177 - mape: 37.4463 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0297 - val_mape: 47.8627
# Epoch 105/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 6.2281e-04 - mse: 6.2281e-04 - mae: 0.0179 - mape: 36.1886
# Epoch 105: val_mse did not improve from 0.00137
# 1550/1550 [==============================] - 3s 2ms/step - loss: 6.2000e-04 - mse: 6.2000e-04 - mae: 0.0179 - mape: 36.0173 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0274 - val_mape: 51.5289
# Epoch 106/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.5591e-04 - mse: 5.5591e-04 - mae: 0.0171 - mape: 34.9172
# Epoch 106: val_mse improved from 0.00137 to 0.00132, saving model to ANN20_60.h5
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.5348e-04 - mse: 5.5348e-04 - mae: 0.0171 - mape: 34.8223 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0252 - val_mape: 42.2349
# Epoch 107/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.8082e-04 - mse: 5.8082e-04 - mae: 0.0177 - mape: 38.1374
# Epoch 107: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.7852e-04 - mse: 5.7852e-04 - mae: 0.0176 - mape: 38.0119 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0261 - val_mape: 44.2315
# Epoch 108/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.8631e-04 - mse: 5.8631e-04 - mae: 0.0177 - mape: 37.6235
# Epoch 108: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.8425e-04 - mse: 5.8425e-04 - mae: 0.0177 - mape: 37.4276 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0314 - val_mape: 56.7572
# Epoch 109/200
# 1550/1550 [==============================] - ETA: 0s - loss: 5.4502e-04 - mse: 5.4502e-04 - mae: 0.0168 - mape: 36.0466
# Epoch 109: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 5s 4ms/step - loss: 5.4502e-04 - mse: 5.4502e-04 - mae: 0.0168 - mape: 36.0466 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0270 - val_mape: 47.1981
# Epoch 110/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.5451e-04 - mse: 5.5451e-04 - mae: 0.0170 - mape: 33.8932
# Epoch 110: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.5200e-04 - mse: 5.5200e-04 - mae: 0.0170 - mape: 33.7902 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0307 - val_mape: 58.2642
# Epoch 111/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.5858e-04 - mse: 5.5858e-04 - mae: 0.0174 - mape: 37.0301
# Epoch 111: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.5640e-04 - mse: 5.5640e-04 - mae: 0.0173 - mape: 36.9050 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0257 - val_mape: 46.6024
# Epoch 112/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.9011e-04 - mse: 5.9011e-04 - mae: 0.0178 - mape: 37.5296
# Epoch 112: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.8804e-04 - mse: 5.8804e-04 - mae: 0.0177 - mape: 37.3244 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0331 - val_mape: 57.4444
# Epoch 113/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.1503e-04 - mse: 5.1503e-04 - mae: 0.0164 - mape: 35.7862
# Epoch 113: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.1361e-04 - mse: 5.1361e-04 - mae: 0.0164 - mape: 35.6545 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0263 - val_mape: 40.9257
# Epoch 114/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.4483e-04 - mse: 5.4483e-04 - mae: 0.0169 - mape: 33.1617
# Epoch 114: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.4239e-04 - mse: 5.4239e-04 - mae: 0.0168 - mape: 33.0548 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0332 - val_mape: 67.4554
# Epoch 115/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.2996e-04 - mse: 5.2996e-04 - mae: 0.0169 - mape: 35.3362
# Epoch 115: val_mse did not improve from 0.00132
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.2789e-04 - mse: 5.2789e-04 - mae: 0.0169 - mape: 35.2271 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0275 - val_mape: 56.9471
# Epoch 116/200
# 1536/1550 [============================>.] - ETA: 0s - loss: 5.7945e-04 - mse: 5.7945e-04 - mae: 0.0177 - mape: 38.1926
# Epoch 116: val_mse did not improve from 0.00132
# Restoring model weights from the end of the best epoch: 106.
# 1550/1550 [==============================] - 3s 2ms/step - loss: 5.7737e-04 - mse: 5.7737e-04 - mae: 0.0176 - mape: 37.9864 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0320 - val_mape: 51.6075
# Epoch 116: early stopping
# Saved training & validation loss history to loss_history.json
# Train time (s): 332.80857253074646
# Train  Loss=0.00137  MSE=0.00137  MAE=0.02840  MAPE=53.982%
# 0.0013666526647284627 0.0013666526647284627 0.028403490781784058 53.982383728027344
# 545/545 [==============================] - 1s 1ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0252 - mape: 42.2349
# model.evaluate(x_val, y_val):  [0.0013179524103179574, 0.0013179524103179574, 0.025190941989421844, 42.23493957519531]
# 1550/1550 [==============================] - 1s 528us/step
# 1550/1550 [==============================] - 1s 454us/step
# MAE: 7493.576385983157, MAPE %: 32.13352236979469, MSE: 66220285.94118853, RMSE: 8137.58477321057
#                          Prediksi        Aktual
# Date
# 2022-01-02 06:30:00   2477.294922  17078.000000
# 2022-01-02 07:00:00   1791.358398  17069.000000
# 2022-01-02 07:30:00   2200.602539  17281.000000
# 2022-01-02 08:00:00   2097.740234  17534.000000
# 2022-01-02 08:30:00   1906.687500  17992.000000
# ...                           ...           ...
# 2024-10-30 22:00:00  25684.232422  29019.070312
# 2024-10-30 22:30:00  24098.367188  28465.740234
# 2024-10-30 23:00:00  22986.210938  27755.750000
# 2024-10-30 23:30:00  21934.839844  27277.500000
# 2024-10-31 00:00:00  20866.289062  26757.400391
#
# [49572 rows x 2 columns]
# 545/545 [==============================] - 0s 466us/step
# MAE: 5810.181417851581, MAPE %: 23.296610882994425, MSE: 43229501.45059087, RMSE: 6574.914558425141
#                          Prediksi        Aktual
# Date
# 2024-11-01 06:30:00  19204.363281  25667.769531
# 2024-11-01 07:00:00  19569.027344  25859.470703
# 2024-11-01 07:30:00  21406.750000  26921.429688
# 2024-11-01 08:00:00  23358.384766  27918.650391
# 2024-11-01 08:30:00  25398.632812  28897.460938
# ...                           ...           ...
# 2025-10-30 10:00:00  28922.183594  30957.800781
# 2025-10-30 10:30:00  29339.781250  30580.789062
# 2025-10-30 11:00:00  29209.988281  31497.359375
# 2025-10-30 11:30:00  28603.781250  31337.589844
# 2025-10-30 12:00:00  26823.117188  20014.880859
#
# [17436 rows x 2 columns]
