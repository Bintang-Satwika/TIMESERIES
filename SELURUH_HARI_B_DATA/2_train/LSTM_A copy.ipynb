# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
# Parameter windowing
input_width = int(48*3)
label_width = 1
shift = label_width
total_window_size = input_width + shift
OUT_STEPS = label_width
# Definisikan irisan untuk input dan label
input_slice = slice(0, input_width)
label_start = total_window_size - label_width
labels_slice = slice(label_start, None)

from B_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive, make_windows

# %% [markdown]
# # data training

# %%
data_training_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_train_data.xlsx', index_col=0)
data_training= data_training_awal.astype('float32').copy()
data_training
# Out:
#                             Beban   Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2022-01-01 00:30:00  18402.000000  0.130526  0.991445 -0.974928 -0.222521
# 2022-01-01 01:00:00  18214.000000  0.258819  0.965926 -0.974928 -0.222521
# 2022-01-01 01:30:00  17974.000000  0.382683  0.923880 -0.974928 -0.222521
# 2022-01-01 02:00:00  17729.000000  0.500000  0.866025 -0.974928 -0.222521
# 2022-01-01 02:30:00  17532.000000  0.608761  0.793353 -0.974928 -0.222521
# ...                           ...       ...       ...       ...       ...
# 2024-10-30 22:00:00  29019.070312 -0.500000  0.866025  0.974928 -0.222521
# 2024-10-30 22:30:00  28465.740234 -0.382683  0.923880  0.974928 -0.222521
# 2024-10-30 23:00:00  27755.750000 -0.258819  0.965926  0.974928 -0.222521
# 2024-10-30 23:30:00  27277.500000 -0.130526  0.991445  0.974928 -0.222521
# 2024-10-31 00:00:00  26757.400391  0.000000  1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2022-01-01 00:30:00        0.0  1.000000e+00        0.762049 -4.403535
# 2022-01-01 01:00:00        0.0  1.000000e+00        0.762049 -4.566491
# 2022-01-01 01:30:00        0.0  1.000000e+00        0.762049 -4.811594
# 2022-01-01 02:00:00        0.0  1.000000e+00        0.762049 -5.056697
# 2022-01-01 02:30:00        0.0  1.000000e+00        0.762049 -5.223890
# ...                        ...           ...             ...       ...
# 2024-10-30 22:00:00       -1.0 -1.836970e-16        1.012018  0.447690
# 2024-10-30 22:30:00       -1.0 -1.836970e-16        1.012018  0.134316
# 2024-10-30 23:00:00       -1.0 -1.836970e-16        1.012018 -0.179059
# 2024-10-30 23:30:00       -1.0 -1.836970e-16        1.012018 -0.402285
# 2024-10-31 00:00:00       -1.0 -1.836970e-16        1.012018 -0.625510
#
# [49632 rows x 9 columns]

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean   24933.849609  1.229754e-09  0.000000e+00      0.000028      0.001729
# std     3040.183838  7.071139e-01  7.071139e-01      0.707530      0.706637
# min    13475.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%    22701.939941 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%    24934.724609  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%    27240.225586  7.071068e-01  7.071068e-01      0.781832      0.623490
# max    32758.619141  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        1.000537     -0.297909
# std    7.057171e-01  7.060366e-01        0.047190      4.279032
# min   -1.000000e+00 -1.000000e+00        0.697430    -10.782065
# 25%   -5.000000e-01 -8.660254e-01        1.012018     -3.767943
# 50%    1.224647e-16 -1.836970e-16        1.012018     -1.268959
# 75%    8.660254e-01  5.000000e-01        1.012018      2.886689
# max    1.000000e+00  1.000000e+00        1.012018     13.803565

# %%
data_training['Suhu_PCA'], min_suhu, max_suhu = scale_array(
    data_training['Suhu_PCA'].values, 
    new_min=-1,
    new_max=1)

data_training['Holiday_Impact'], min_holiday, max_holiday = scale_array(
    data_training['Holiday_Impact'].values, 
    new_min=-1, 
    new_max=1
)

data_training['Beban'], min_beban, max_beban = scale_array(
    data_training['Beban'].values, 
    new_min=0, 
    new_max=1)
# Out:
# Computed orig_min: -10.782065391540527
# Computed orig_max: 13.80356502532959
# Computed orig_min: 0.6974297761917114
# Computed orig_max: 1.0120183229446411
# Computed orig_min: 13475.0
# Computed orig_max: 32758.619140625

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean       0.594227  1.229754e-09  0.000000e+00      0.000028      0.001729
# std        0.157657  7.071139e-01  7.071139e-01      0.707530      0.706637
# min        0.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        0.478486 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.594273  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%        0.713830  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.000000  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        0.927008     -0.147131
# std    7.057171e-01  7.060366e-01        0.300029      0.348093
# min   -1.000000e+00 -1.000000e+00       -1.000000     -1.000000
# 25%   -5.000000e-01 -8.660254e-01        1.000000     -0.429413
# 50%    1.224647e-16 -1.836970e-16        1.000000     -0.226125
# 75%    8.660254e-01  5.000000e-01        1.000000      0.111930
# max    1.000000e+00  1.000000e+00        1.000000      1.000000

# %% [markdown]
# # data validation (testing)

# %%
data_validation_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_test_data.xlsx', index_col=0)
data_validation= data_validation_awal.astype('float32').copy()
data_validation
# Out:
#                             Beban       Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2024-10-31 00:30:00  26460.919922  1.305262e-01  0.991445  0.433884 -0.900969
# 2024-10-31 01:00:00  26184.929688  2.588190e-01  0.965926  0.433884 -0.900969
# 2024-10-31 01:30:00  25976.689453  3.826834e-01  0.923880  0.433884 -0.900969
# 2024-10-31 02:00:00  25745.220703  5.000000e-01  0.866025  0.433884 -0.900969
# 2024-10-31 02:30:00  25441.970703  6.087614e-01  0.793353  0.433884 -0.900969
# ...                           ...           ...       ...       ...       ...
# 2025-10-30 10:00:00  30957.800781  5.000000e-01 -0.866025  0.433884 -0.900969
# 2025-10-30 10:30:00  30580.789062  3.826834e-01 -0.923880  0.433884 -0.900969
# 2025-10-30 11:00:00  31497.359375  2.588190e-01 -0.965926  0.433884 -0.900969
# 2025-10-30 11:30:00  31337.589844  1.305262e-01 -0.991445  0.433884 -0.900969
# 2025-10-30 12:00:00  20014.880859  1.224647e-16 -1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2024-10-31 00:30:00       -1.0 -1.836970e-16        1.012018 -0.829108
# 2024-10-31 01:00:00       -1.0 -1.836970e-16        1.012018 -1.032705
# 2024-10-31 01:30:00       -1.0 -1.836970e-16        1.012018 -1.284443
# 2024-10-31 02:00:00       -1.0 -1.836970e-16        1.012018 -1.536183
# 2024-10-31 02:30:00       -1.0 -1.836970e-16        1.012018 -1.717856
# ...                        ...           ...             ...       ...
# 2025-10-30 10:00:00       -1.0 -1.836970e-16        1.012018  3.765654
# 2025-10-30 10:30:00       -1.0 -1.836970e-16        1.012018  4.427866
# 2025-10-30 11:00:00       -1.0 -1.836970e-16        1.012018  5.090077
# 2025-10-30 11:30:00       -1.0 -1.836970e-16        1.012018  5.516177
# 2025-10-30 12:00:00       -1.0 -1.836970e-16        1.012018  5.942276
#
# [17496 rows x 9 columns]

# %%
data_validation['Suhu_PCA'], _, _ = scale_array(
    data_validation['Suhu_PCA'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_suhu,
    orig_max=max_suhu
)
data_validation['Holiday_Impact'], _, _ = scale_array(
    data_validation['Holiday_Impact'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_holiday,
    orig_max=max_holiday
)
data_validation['Beban'], _, _ = scale_array(
    data_validation['Beban'].values, 
    new_min=0, 
    new_max=1,
    orig_min=min_beban,
    orig_max=max_beban
)

# %%
data_validation.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  17496.000000  1.749600e+04  1.749600e+04  17496.000000  17496.000000
# mean       0.694760  8.720320e-04 -5.715587e-05      0.000595     -0.001236
# std        0.158522  7.071220e-01  7.071295e-01      0.706819      0.707422
# min        0.112257 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        0.579484 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.692562  1.224647e-16 -6.123234e-17      0.000000     -0.222521
# 75%        0.834486  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.069814  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17496.000000  1.749600e+04    17496.000000  17496.000000
# mean      -0.002107 -4.751840e-03        0.927556     -0.054150
# std        0.706636  7.075914e-01        0.295125      0.311896
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310872
# 50%        0.000000 -1.836970e-16        1.000000     -0.119035
# 75%        0.866025  5.000000e-01        1.000000      0.207501
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
x_train,    y_train     =   make_windows(input_make_windows, output_make_windows,total_window_size, input_slice, labels_slice)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows(input_make_windows_validation, output_make_windows_validation,total_window_size, input_slice, labels_slice)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((49488, 144, 9), (49488, 1), (17352, 144, 9), (17352, 1))

# %%
x_train.dtype, y_train.dtype, x_val.dtype, y_val.dtype
# Out:
# (dtype('float32'), dtype('float32'), dtype('float32'), dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

seed_value = 20
tf.random.set_seed(seed_value)
import json
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, History
import time


def tensorflow_model(X_train_scaled, Y_train_scaled,
                   X_val_scaled,   Y_val_scaled,
                   learning_rate=1e-3,
                   target_MAE=0.001,
                   jumlah_epochs=50,
                   jumlah_sampel_batch=1,
                   jumlah_epoch_terbelakang=10,
                   save_best_model_path="model.h5",
                   validation_data=False,
                   load_model=None, seed_value=-1):

    global model, loss_history
    model= None
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    # History callback to capture training curves
    history_cb = History()

    # ---------- model ----------
    input_width  = X_train_scaled.shape[1]   # 300
    num_features = X_train_scaled.shape[2]   # 1

    if load_model is None:
        model = tf.keras.models.Sequential()
        model.add(layers.LSTM(
            units=32,
            input_shape=(input_width, num_features),
            return_sequences=True,
            kernel_initializer=initializers.GlorotUniform(seed=10),
            recurrent_initializer=initializers.Orthogonal(seed=10),
            bias_initializer=initializers.Zeros()
        ))
        model.add( layers.Flatten())
        
        model.add(layers.Dense(
            1, dtype='float32',                        # cast back to fp32
            kernel_initializer=initializers.GlorotUniform(seed=seed_value),
            bias_initializer=initializers.Zeros())
                )
    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')],
                  steps_per_execution=128)

    # ---------- build callback list ----------
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(2, root=save_best_model_path.rstrip('.h5'))
    ]

    if validation_data:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=(X_val_scaled, Y_val_scaled) if validation_data else None,
                  validation_batch_size=jumlah_sampel_batch,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        # Save history to JSON even if training stopped early
        loss_history = {
            'loss': history_cb.history.get('loss', [])
        }
        if validation_data:
            loss_history['val_loss'] = history_cb.history.get('val_loss', [])
        with open('loss_history_%s.json'%seed_value, 'w') as f:
            json.dump(loss_history, f)
        print("Saved training & validation loss history to loss_history.json")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.001,  jumlah_epochs=30, jumlah_sampel_batch=32, 
                                                    jumlah_epoch_terbelakang=10,  save_best_model_path = "LSTM%s_1.h5"%seed_value, 
                                                    validation_data=True, load_model=None, seed_value=seed_value)

    print(loss, MSE, MAE, MAPE)
    print("model.evaluate(x_val, y_val): ", model.evaluate(x_val, y_val))
    predictions = model.predict(x_train[slice(None, None, label_width), :, :])
    predictions_reshaped = predictions.reshape(-1,)
    predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
    df_pred_act = compute_error(x_train, data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)
    df= df_pred_act.copy() 
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()







    df_pred_act = compute_error(x_val, data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)

    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# Running with seed: 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 144, 32)           5376
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 1)                 4609
#
# =================================================================
# Total params: 9,985
# Trainable params: 9,985
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0139 - mse: 0.0139 - mae: 0.0891 - mape: 1456.4830
# Epoch 1: val_mse improved from inf to 0.01797, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 23s 15ms/step - loss: 0.0139 - mse: 0.0139 - mae: 0.0891 - mape: 1456.4830 - val_loss: 0.0180 - val_mse: 0.0180 - val_mae: 0.1072 - val_mape: 17.8321
# Epoch 2/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0600 - mape: 8693.1514
# 📦  Saved checkpoint: LSTM20_1_epoch02.h5
#
# Epoch 2: val_mse did not improve from 0.01797
# 1547/1547 [==============================] - 16s 11ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0600 - mape: 8693.1514 - val_loss: 0.0261 - val_mse: 0.0261 - val_mae: 0.1349 - val_mape: 21.2350
# Epoch 3/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0052 - mse: 0.0052 - mae: 0.0556 - mape: 174.6517
# Epoch 3: val_mse did not improve from 0.01797
# 1547/1547 [==============================] - 20s 13ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0556 - mape: 174.6517 - val_loss: 0.0236 - val_mse: 0.0236 - val_mae: 0.1306 - val_mape: 20.2511
# Epoch 4/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0569 - mape: 3855.6641
# 📦  Saved checkpoint: LSTM20_1_epoch04.h5
#
# Epoch 4: val_mse improved from 0.01797 to 0.01100, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 21s 13ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0569 - mape: 3855.6641 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0870 - val_mape: 13.5938
# Epoch 5/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0511 - mape: 1935.4766
# Epoch 5: val_mse improved from 0.01100 to 0.00870, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 23s 15ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0511 - mape: 1935.4766 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0763 - val_mape: 12.1468
# Epoch 6/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0491 - mape: 2676.7637
# 📦  Saved checkpoint: LSTM20_1_epoch06.h5
#
# Epoch 6: val_mse improved from 0.00870 to 0.00580, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 12ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0491 - mape: 2676.7637 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0599 - val_mape: 9.6607
# Epoch 7/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0036 - mse: 0.0036 - mae: 0.0464 - mape: 2027.2491
# Epoch 7: val_mse improved from 0.00580 to 0.00500, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 17s 11ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0464 - mape: 2027.2491 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0542 - val_mape: 8.8994
# Epoch 8/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0033 - mse: 0.0033 - mae: 0.0442 - mape: 2207.9749
# 📦  Saved checkpoint: LSTM20_1_epoch08.h5
#
# Epoch 8: val_mse improved from 0.00500 to 0.00428, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 16s 11ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0442 - mape: 2207.9749 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0490 - val_mape: 8.1414
# Epoch 9/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - mae: 0.0422 - mape: 2109.4753
# Epoch 9: val_mse improved from 0.00428 to 0.00385, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 25s 16ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0422 - mape: 2109.4753 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0459 - val_mape: 7.6879
# Epoch 10/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0028 - mse: 0.0028 - mae: 0.0404 - mape: 2142.2585
# 📦  Saved checkpoint: LSTM20_1_epoch10.h5
#
# Epoch 10: val_mse improved from 0.00385 to 0.00357, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 47s 30ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0404 - mape: 2142.2585 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0439 - val_mape: 7.3807
# Epoch 11/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026 - mae: 0.0388 - mape: 2178.0171
# Epoch 11: val_mse improved from 0.00357 to 0.00335, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 38s 25ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0388 - mape: 2178.0171 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0424 - val_mape: 7.1367
# Epoch 12/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024 - mae: 0.0374 - mape: 2210.8762
# 📦  Saved checkpoint: LSTM20_1_epoch12.h5
#
# Epoch 12: val_mse improved from 0.00335 to 0.00317, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 16s 11ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0374 - mape: 2210.8762 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0413 - val_mape: 6.9335
# Epoch 13/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0022 - mse: 0.0022 - mae: 0.0360 - mape: 2236.4912
# Epoch 13: val_mse improved from 0.00317 to 0.00303, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 16s 11ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0360 - mape: 2236.4912 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0403 - val_mape: 6.7662
# Epoch 14/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0021 - mse: 0.0021 - mae: 0.0348 - mape: 2270.3003
# 📦  Saved checkpoint: LSTM20_1_epoch14.h5
#
# Epoch 14: val_mse improved from 0.00303 to 0.00291, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 13ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0348 - mape: 2270.3003 - val_loss: 0.0029 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 6.6401
# Epoch 15/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0020 - mse: 0.0020 - mae: 0.0338 - mape: 2289.8882
# Epoch 15: val_mse improved from 0.00291 to 0.00279, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 20s 13ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0338 - mape: 2289.8882 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0391 - val_mape: 6.5108
# Epoch 16/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0019 - mse: 0.0019 - mae: 0.0328 - mape: 2311.6467
# 📦  Saved checkpoint: LSTM20_1_epoch16.h5
#
# Epoch 16: val_mse improved from 0.00279 to 0.00267, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 20s 13ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0328 - mape: 2311.6467 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0385 - val_mape: 6.3788
# Epoch 17/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0319 - mape: 2311.8452
# Epoch 17: val_mse improved from 0.00267 to 0.00257, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 13ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0319 - mape: 2311.8452 - val_loss: 0.0026 - val_mse: 0.0026 - val_mae: 0.0379 - val_mape: 6.2513
# Epoch 18/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0311 - mape: 2310.9114
# 📦  Saved checkpoint: LSTM20_1_epoch18.h5
#
# Epoch 18: val_mse improved from 0.00257 to 0.00245, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 12ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0311 - mape: 2310.9114 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0372 - val_mape: 6.0951
# Epoch 19/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0.0303 - mape: 2291.1064
# Epoch 19: val_mse improved from 0.00245 to 0.00231, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 23s 15ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0303 - mape: 2291.1064 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0363 - val_mape: 5.9139
# Epoch 20/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0016 - mse: 0.0016 - mae: 0.0296 - mape: 2257.1421
# 📦  Saved checkpoint: LSTM20_1_epoch20.h5
#
# Epoch 20: val_mse improved from 0.00231 to 0.00218, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 21s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0296 - mape: 2257.1421 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0353 - val_mape: 5.7174
# Epoch 21/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0015 - mse: 0.0015 - mae: 0.0289 - mape: 2218.7910
# Epoch 21: val_mse improved from 0.00218 to 0.00206, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 17s 11ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0289 - mape: 2218.7910 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0343 - val_mape: 5.5230
# Epoch 22/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0282 - mape: 2158.6772
# 📦  Saved checkpoint: LSTM20_1_epoch22.h5
#
# Epoch 22: val_mse improved from 0.00206 to 0.00193, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 17s 11ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0282 - mape: 2158.6772 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0332 - val_mape: 5.3200
# Epoch 23/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0276 - mape: 2102.5786
# Epoch 23: val_mse improved from 0.00193 to 0.00184, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 17s 11ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0276 - mape: 2102.5786 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0323 - val_mape: 5.1524
# Epoch 24/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0013 - mse: 0.0013 - mae: 0.0270 - mape: 2037.2494
# 📦  Saved checkpoint: LSTM20_1_epoch24.h5
#
# Epoch 24: val_mse improved from 0.00184 to 0.00173, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 12ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0270 - mape: 2037.2494 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0313 - val_mape: 4.9805
# Epoch 25/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0013 - mse: 0.0013 - mae: 0.0265 - mape: 1972.5627
# Epoch 25: val_mse improved from 0.00173 to 0.00165, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 17s 11ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0265 - mape: 1972.5627 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0305 - val_mape: 4.8434
# Epoch 26/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0260 - mape: 1916.8762
# 📦  Saved checkpoint: LSTM20_1_epoch26.h5
#
# Epoch 26: val_mse improved from 0.00165 to 0.00156, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 16s 11ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0260 - mape: 1916.8762 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0295 - val_mape: 4.6912
# Epoch 27/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0255 - mape: 1850.9647
# Epoch 27: val_mse improved from 0.00156 to 0.00148, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 23s 15ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0255 - mape: 1850.9647 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0287 - val_mape: 4.5735
# Epoch 28/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - mape: 1822.6365
# 📦  Saved checkpoint: LSTM20_1_epoch28.h5
#
# Epoch 28: val_mse improved from 0.00148 to 0.00141, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 32s 20ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - mape: 1822.6365 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0280 - val_mape: 4.4622
# Epoch 29/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0246 - mape: 1791.6417
# Epoch 29: val_mse improved from 0.00141 to 0.00134, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 12ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0246 - mape: 1791.6417 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0272 - val_mape: 4.3475
# Epoch 30/30
# 1547/1547 [==============================] - ETA: 0s - loss: 0.0010 - mse: 0.0010 - mae: 0.0242 - mape: 1777.0039
# 📦  Saved checkpoint: LSTM20_1_epoch30.h5
#
# Epoch 30: val_mse improved from 0.00134 to 0.00128, saving model to LSTM20_1.h5
# 1547/1547 [==============================] - 19s 12ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0242 - mape: 1777.0039 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0265 - val_mape: 4.2557
# Saved training & validation loss history to loss_history.json
# Train time (s): 635.2871050834656
# Train  Loss=0.00369  MSE=0.00369  MAE=0.05131  MAPE=2543.918%
# 0.0036860613618046045 0.0036860613618046045 0.05130673199892044 2543.917724609375
# 543/543 [==============================] - 4s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0265 - mape: 4.2557
# model.evaluate(x_val, y_val):  [0.0012801181292161345, 0.0012801181292161345, 0.026485644280910492, 4.255738258361816]
# 1547/1547 [==============================] - 8s 5ms/step
# 1547/1547 [==============================] - 10s 6ms/step
# MAE: 989.3788515295059, MAPE %: 4.037074200756971, MSE: 1370693.2337558265, RMSE: 1170.7660884035831
#                          Prediksi        Aktual
# Date
# 2022-01-04 00:30:00  22877.644531  21847.000000
# 2022-01-04 01:00:00  22793.367188  21593.000000
# 2022-01-04 01:30:00  22672.097656  21483.000000
# 2022-01-04 02:00:00  22610.640625  21223.000000
# 2022-01-04 02:30:00  22440.484375  21024.000000
# ...                           ...           ...
# 2024-10-30 22:00:00  29317.734375  29019.070312
# 2024-10-30 22:30:00  28757.292969  28465.740234
# 2024-10-30 23:00:00  28194.392578  27755.750000
# 2024-10-30 23:30:00  27689.179688  27277.500000
# 2024-10-31 00:00:00  27177.382812  26757.400391
#
# [49488 rows x 2 columns]
# 543/543 [==============================] - 2s 4ms/step
# MAE: 510.73892863349687, MAPE %: 1.9493006363107979, MSE: 476022.49013786146, RMSE: 689.9438311470445
#                          Prediksi        Aktual
# Date
# 2024-11-03 00:30:00  23310.183594  22582.580078
# 2024-11-03 01:00:00  22859.187500  22360.220703
# 2024-11-03 01:30:00  22450.662109  22163.289062
# 2024-11-03 02:00:00  22103.697266  21898.589844
# 2024-11-03 02:30:00  21884.316406  21737.949219
# ...                           ...           ...
# 2025-10-30 10:00:00  30482.367188  30957.800781
# 2025-10-30 10:30:00  30567.519531  30580.789062
# 2025-10-30 11:00:00  30475.751953  31497.359375
# 2025-10-30 11:30:00  30214.957031  31337.589844
# 2025-10-30 12:00:00  30062.244141  20014.880859
#
# [17352 rows x 2 columns]
