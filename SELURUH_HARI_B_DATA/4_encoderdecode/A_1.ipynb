# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
# Parameter windowing
input_width = int(48)*7
label_width = 48
shift = label_width
total_window_size = input_width + shift
OUT_STEPS = label_width
# Definisikan irisan untuk input dan label
input_slice = slice(0, input_width)
label_start = total_window_size - label_width
labels_slice = slice(label_start, None)

from B_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive, make_windows

# %% [markdown]
# # data training

# %%
data_training_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_train_data.xlsx', index_col=0)
data_training= data_training_awal.astype('float32').copy()
data_training
# Out:
#                             Beban   Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2022-01-01 00:30:00  18402.000000  0.130526  0.991445 -0.974928 -0.222521
# 2022-01-01 01:00:00  18214.000000  0.258819  0.965926 -0.974928 -0.222521
# 2022-01-01 01:30:00  17974.000000  0.382683  0.923880 -0.974928 -0.222521
# 2022-01-01 02:00:00  17729.000000  0.500000  0.866025 -0.974928 -0.222521
# 2022-01-01 02:30:00  17532.000000  0.608761  0.793353 -0.974928 -0.222521
# ...                           ...       ...       ...       ...       ...
# 2024-10-30 22:00:00  29019.070312 -0.500000  0.866025  0.974928 -0.222521
# 2024-10-30 22:30:00  28465.740234 -0.382683  0.923880  0.974928 -0.222521
# 2024-10-30 23:00:00  27755.750000 -0.258819  0.965926  0.974928 -0.222521
# 2024-10-30 23:30:00  27277.500000 -0.130526  0.991445  0.974928 -0.222521
# 2024-10-31 00:00:00  26757.400391  0.000000  1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2022-01-01 00:30:00        0.0  1.000000e+00        0.762049 -4.403535
# 2022-01-01 01:00:00        0.0  1.000000e+00        0.762049 -4.566491
# 2022-01-01 01:30:00        0.0  1.000000e+00        0.762049 -4.811594
# 2022-01-01 02:00:00        0.0  1.000000e+00        0.762049 -5.056697
# 2022-01-01 02:30:00        0.0  1.000000e+00        0.762049 -5.223890
# ...                        ...           ...             ...       ...
# 2024-10-30 22:00:00       -1.0 -1.836970e-16        1.012018  0.447690
# 2024-10-30 22:30:00       -1.0 -1.836970e-16        1.012018  0.134316
# 2024-10-30 23:00:00       -1.0 -1.836970e-16        1.012018 -0.179059
# 2024-10-30 23:30:00       -1.0 -1.836970e-16        1.012018 -0.402285
# 2024-10-31 00:00:00       -1.0 -1.836970e-16        1.012018 -0.625510
#
# [49632 rows x 9 columns]

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean   24933.849609  1.229754e-09  0.000000e+00      0.000028      0.001729
# std     3040.183838  7.071139e-01  7.071139e-01      0.707530      0.706637
# min    13475.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%    22701.939941 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%    24934.724609  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%    27240.225586  7.071068e-01  7.071068e-01      0.781832      0.623490
# max    32758.619141  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        1.000537     -0.297909
# std    7.057171e-01  7.060366e-01        0.047190      4.279032
# min   -1.000000e+00 -1.000000e+00        0.697430    -10.782065
# 25%   -5.000000e-01 -8.660254e-01        1.012018     -3.767943
# 50%    1.224647e-16 -1.836970e-16        1.012018     -1.268959
# 75%    8.660254e-01  5.000000e-01        1.012018      2.886689
# max    1.000000e+00  1.000000e+00        1.012018     13.803565

# %%
data_training['Suhu_PCA'], min_suhu, max_suhu = scale_array(
    data_training['Suhu_PCA'].values, 
    new_min=-1,
    new_max=1)

data_training['Holiday_Impact'], min_holiday, max_holiday = scale_array(
    data_training['Holiday_Impact'].values, 
    new_min=-1, 
    new_max=1
)

data_training['Beban'], min_beban, max_beban = scale_array(
    data_training['Beban'].values, 
    new_min=-1, 
    new_max=1)
# Out:
# Computed orig_min: -10.782065391540527
# Computed orig_max: 13.80356502532959
# Computed orig_min: 0.6974297761917114
# Computed orig_max: 1.0120183229446411
# Computed orig_min: 13475.0
# Computed orig_max: 32758.619140625

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count
].values,
    new_min=-1,
    new_max=1,
    orig_min=min_suhu,
    orig_max=max_suhu
)
data_validation['Holiday_Impact'], _, _ = scale_array(
    data_validation['Holiday_Impact'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_holiday,
    orig_max=max_holiday
)
data_validation['Beban'], _, _ = scale_array(
    data_validation['Beban'].values, 
    new_min=-1, 
    new_max=1,
    orig_min=min_beban,
    orig_max=max_beban
)

# %%
data_validation.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  17496.000000  1.749600e+04  1.749600e+04  17496.000000  17496.000000
# mean       0.389520  8.720320e-04 -5.715587e-05      0.000595     -0.001236
# std        0.317044  7.071220e-01  7.071295e-01      0.706819      0.707422
# min       -0.775485 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        0.158968 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.385124  1.224647e-16 -6.123234e-17      0.000000     -0.222521
# 75%        0.668971  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.139628  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17496.000000  1.749600e+04    17496.000000  17496.000000
# mean      -0.002107 -4.751840e-03        0.927556     -0.054150
# std        0.706636  7.075914e-01        0.295125      0.311896
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310872
# 50%        0.000000 -1.836970e-16        1.000000     -0.119035
# 75%        0.866025  5.000000e-01        1.000000      0.207501
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
x_train,    y_train     =   make_windows(input_make_windows, output_make_windows,total_window_size, input_slice, labels_slice)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows(input_make_windows_validation, output_make_windows_validation,total_window_size, input_slice, labels_slice)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((49249, 336, 9), (49249, 48), (17113, 336, 9), (17113, 48))

# %%
x_train.dtype, y_train.dtype, x_val.dtype, y_val.dtype
# Out:
# (dtype('float32'), dtype('float32'), dtype('float32'), dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, RepeatVector, TimeDistributed, Dense, Input
import json
from tensorflow.keras import layers, mixed_precision, initializers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, History
import time

def build_model_tensor(input_lag, num_features, forecast_horizon):
    # 2. Build the Model
    model = Sequential()

    # --- THE ENCODER ---
    # This layer reads your 336 steps of 9 features. 
    # Because return_sequences=False (the default), it compresses the entire week 
    # into a single 1D context vector of 128 numbers. It learns the "story" of the week.
    model.add(Input(shape=(input_lag, num_features)))
   # model.add(LSTM(units=32, activation='relu'))
    model.add(LSTM(units=32))

    # --- THE BRIDGE ---
    # The Decoder needs to output 48 steps, but it only has one context vector from the Encoder.
    # RepeatVector copies that single context vector 48 times to create a 3D grid again.
    model.add(RepeatVector(forecast_horizon))

    # --- THE DECODER ---
    # This layer reads the 48 repeated context vectors. 
    # Because return_sequences=True, it outputs a distinct prediction representation 
    # for every single one of the 48 future time steps, keeping the flow of time intact.
    model.add(LSTM(units=32, return_sequences=True))

    # --- THE OUTPUT ---
    # Notice we are using TimeDistributed here! 
    # Because the Decoder output is an actual sequence of 48 steps, we use TimeDistributed 
    # to apply a standard Dense(1) layer to each of the 48 steps individually. 
    # This converts the LSTM's hidden representations into your final Megawatt load numbers.
    model.add(TimeDistributed(Dense(units=1)))
    return model

# %%
def tensorflow_model(X_train_scaled, Y_train_scaled,
                   X_val_scaled,   Y_val_scaled,
                   learning_rate=1e-3,
                   target_MAE=0.001,
                   jumlah_epochs=50,
                   jumlah_sampel_batch=1,
                   jumlah_epoch_terbelakang=10,
                   save_best_model_path="model.h5",
                   validation_data=False,
                   load_model=None, seed_value=-1):

    global model, loss_history
    model= None
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    # History callback to capture training curves
    history_cb = History()

    # ---------- model ----------
    input_width  = X_train_scaled.shape[1]   # 300
    num_features = X_train_scaled.shape[2]   # 9
    if load_model is None:
        # --- CARA MENGGUNAKAN ---
        # input_width = 48, num_features = 9
        # output_steps = 48
        model =  build_model_tensor(input_width, num_features, OUT_STEPS)

    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')],
                  steps_per_execution=128)

    # ---------- build callback list ----------
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(10, root=save_best_model_path.rstrip('.h5'))
    ]

    if validation_data:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=(X_val_scaled, Y_val_scaled) if validation_data else None,
                  validation_batch_size=jumlah_sampel_batch,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        # Save history to JSON even if training stopped early
        loss_history = {
            'loss': history_cb.history.get('loss', [])
        }
        if validation_data:
            loss_history['val_loss'] = history_cb.history.get('val_loss', [])
        with open('loss_history_%s.json'%seed_value, 'w') as f:
            json.dump(loss_history, f)
        print("Saved training & validation loss history to loss_history.json")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.001,  jumlah_epochs=100, jumlah_sampel_batch=32, 
                                                    jumlah_epoch_terbelakang=10,  save_best_model_path = "ED1_%s.h5"%seed_value, 
                                                    validation_data=True, load_model=None, seed_value=seed_value)
    print(loss, MSE, MAE, MAPE)
    pilih_models = "ED1_%s.h5"%seed_value
    model.load_weights(pilih_models)
    print("Loading best model from: ", pilih_models)
    print("model.evaluate(x_val, y_val): ", model.evaluate(x_val, y_val))
    predictions = model.predict(x_train[slice(None, None, label_width), :, :])
    predictions_reshaped = predictions.reshape(-1,)
    predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
    df_pred_act = compute_error(x_train, data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)
    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()







    df_pred_act = compute_error(x_val, data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)

    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# Running with seed: 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  repeat_vector (RepeatVector  (None, 48, 32)           0
#  )
#
#  lstm_1 (LSTM)               (None, 48, 32)            8320
#
#  time_distributed (TimeDistr  (None, 48, 1)            33
#  ibuted)
#
# =================================================================
# Total params: 13,729
# Trainable params: 13,729
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0616 - mse: 0.0616 - mae: 0.2118 - mape: 384.2688
# Epoch 1: val_mse improved from inf to 0.06891, saving model to ED1_20.h5
# 1540/1540 [==============================] - 40s 26ms/step - loss: 0.0616 - mse: 0.0616 - mae: 0.2118 - mape: 384.2688 - val_loss: 0.0689 - val_mse: 0.0689 - val_mae: 0.2138 - val_mape: 833.2411
# Epoch 2/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0347 - mse: 0.0347 - mae: 0.1473 - mape: 286.9927
# Epoch 2: val_mse improved from 0.06891 to 0.03355, saving model to ED1_20.h5
# 1540/1540 [==============================] - 35s 22ms/step - loss: 0.0347 - mse: 0.0347 - mae: 0.1473 - mape: 286.9927 - val_loss: 0.0335 - val_mse: 0.0335 - val_mae: 0.1389 - val_mape: 424.2683
# Epoch 3/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0208 - mse: 0.0208 - mae: 0.1061 - mape: 190.2502
# Epoch 3: val_mse improved from 0.03355 to 0.02467, saving model to ED1_20.h5
# 1540/1540 [==============================] - 37s 24ms/step - loss: 0.0208 - mse: 0.0208 - mae: 0.1061 - mape: 190.2502 - val_loss: 0.0247 - val_mse: 0.0247 - val_mae: 0.1135 - val_mape: 240.7716
# Epoch 4/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0180 - mse: 0.0180 - mae: 0.0973 - mape: 176.1357
# Epoch 4: val_mse improved from 0.02467 to 0.02155, saving model to ED1_20.h5
# 1540/1540 [==============================] - 36s 23ms/step - loss: 0.0180 - mse: 0.0180 - mae: 0.0973 - mape: 176.1357 - val_loss: 0.0216 - val_mse: 0.0216 - val_mae: 0.1038 - val_mape: 200.9408
# Epoch 5/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.
100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0107 - mse: 0.0107 - mae: 0.0719 - mape: 139.7923
# Epoch 15: val_mse improved from 0.01376 to 0.01346, saving model to ED1_20.h5
# 1540/1540 [==============================] - 56s 37ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0719 - mape: 139.7923 - val_loss: 0.0135 - val_mse: 0.0135 - val_mae: 0.0814 - val_mape: 135.6222
# Epoch 16/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0104 - mse: 0.0104 - mae: 0.0708 - mape: 138.2951
# Epoch 16: val_mse improved from 0.01346 to 0.01320, saving model to ED1_20.h5
# 1540/1540 [==============================] - 87s 57ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0708 - mape: 138.2951 - val_loss: 0.0132 - val_mse: 0.0132 - val_mae: 0.0805 - val_mape: 132.6314
# Epoch 17/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0102 - mse: 0.0102 - mae: 0.0698 - mape: 136.8298
# Epoch 17: val_mse improved from 0.01320 to 0.01296, saving model to ED1_20.h5
# 1540/1540 [==============================] - 57s 37ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0698 - mape: 136.8298 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.0796 - val_mape: 129.6191
# Epoch 18/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0100 - mse: 0.0100 - mae: 0.0690 - mape: 135.2631
# Epoch 18: val_mse improved from 0.01296 to 0.01275, saving model to ED1_20.h5
# 1540/1540 [==============================] - 48s 31ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0690 - mape: 135.2631 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0788 - val_mape: 126.8796
# Epoch 19/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0098 - mse: 0.0098 - mae: 0.0682 - mape: 133.7050
# Epoch 19: val_mse improved from 0.01275 to 0.01255, saving model to ED1_20.h5
# 1540/1540 [==============================] - 37s 24ms/step - loss: 0.0098 - mse: 0.0098 - mae: 0.0682 - mape: 133.7050 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0780 - val_mape: 124.4153
# Epoch 20/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0097 - mse: 0.0097 - mae: 0.0675 - mape: 132.0648
# 📦  Saved checkpoint: ED1_20_epoch20.h5
#
# Epoch 20: val_mse improved from 0.01255 to 0.01238, saving model to ED1_20.h5
# 1540/1540 [==============================] - 38s 25ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0675 - mape: 132.0648 - val_loss: 0.0124 - val_mse: 0.0124 - val_mae: 0.0773 - val_mape: 121.9606
# Epoch 21/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0095 - mse: 0.0095 - mae: 0.0668 - mape: 130.4724
# Epoch 21: val_mse improved from 0.01238 to 0.01222, saving model to ED1_20.h5
# 1540/1540 [==============================] - 36s 24ms/step - loss: 0.0095 - mse: 0.0095 - mae: 0.0668 - mape: 130.4724 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0767 - val_mape: 119.6831
# Epoch 22/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0094 - mse: 0.0094 - mae: 0.0662 - mape: 128.8875
# Epoch 22: val_mse improved from 0.01222 to 0.01207, saving model to ED1_20.h5
# 1540/1540 [==============================] - 51s 33ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0662 - mape: 128.8875 - val_loss: 0.0121 - val_mse: 0.0121 - val_mae: 0.0761 - val_mape: 117.7567
# Epoch 23/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0093 - mse: 0.0093 - mae: 0.0657 - mape: 127.3945
# Epoch 23: val_mse improved from 0.01207 to 0.01194, saving model to ED1_20.h5
# 1540/1540 [==============================] - 52s 34ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0657 - mape: 127.3945 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0756 - val_mape: 115.8401
# Epoch 24/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0092 - mse: 0.0092 - mae: 0.0651 - mape: 125.9796
# Epoch 24: val_mse improved from 0.01194 to 0.01181, saving model to ED1_20.h5
# 1540/1540 [==============================] - 84s 54ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.
val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 78s 50ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0521 - mape: 102.2322 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0640 - val_mape: 116.0122
# Epoch 63/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0066 - mse: 0.0066 - mae: 0.0518 - mape: 101.7637
# Epoch 63: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 74s 48ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0518 - mape: 101.7637 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0639 - val_mape: 115.9367
# Epoch 64/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0065 - mse: 0.0065 - mae: 0.0516 - mape: 101.3244
# Epoch 64: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 77s 50ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0516 - mape: 101.3244 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0639 - val_mape: 115.8142
# Epoch 65/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0065 - mse: 0.0065 - mae: 0.0513 - mape: 100.8692
# Epoch 65: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 78s 51ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0513 - mape: 100.8692 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0639 - val_mape: 115.7403
# Epoch 66/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0064 - mse: 0.0064 - mae: 0.0511 - mape: 100.4037
# Epoch 66: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 74s 48ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0511 - mape: 100.4037 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0638 - val_mape: 115.6833
# Epoch 67/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0064 - mse: 0.0064 - mae: 0.0509 - mape: 99.9498
# Epoch 67: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 72s 47ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0509 - mape: 99.9498 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0638 - val_mape: 115.7135
# Epoch 68/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0507 - mape: 99.5021
# Epoch 68: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 75s 49ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0507 - mape: 99.5021 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0638 - val_mape: 115.9374
# Epoch 69/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0504 - mape: 99.0948
# Epoch 69: val_mse did not improve from 0.00973
# 1540/1540 [==============================] - 76s 49ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0504 - mape: 99.0948 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0638 - val_mape: 116.1948
# Epoch 70/100
# 1540/1540 [==============================] - ETA: 0s - loss: 0.0062 - mse: 0.0062 - mae: 0.0502 - mape: 98.7039
# 📦  Saved checkpoint: ED1_20_epoch70.h5
#
# Epoch 70: val_mse did not improve from 0.00973
# Restoring model weights from the end of the best epoch: 60.
# 1540/1540 [==============================] - 66s 43ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0502 - mape: 98.7039 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0638 - val_mape: 116.6358
# Epoch 70: early stopping
# Saved training & validation loss history to loss_history.json
# Train time (s): 4508.619777679443
# Train  Loss=0.01025  MSE=0.01025  MAE=0.07272  MAPE=168.975%
# 0.01025149691849947 0.01025149691849947 0.0727151483297348 168.97486877441406
# Loading best model from:  ED1_20.h5
# 535/535 [==============================] - 5s 10ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0643 - mape: 116.0943
# model.evaluate(x_val, y_val):  [0.0097295381128788, 0.0097295381128788, 0.06426425278186798, 116.09431457519531]
# 33/33 [==============================] - 1s 37ms/step
# 33/33 [==============================] - 0s 9ms/step
# before dropna
#                          Prediksi        Aktual
# Date
# 2022-01-08 00:30:00  12565.086914  21871.000000
# 2022-01-08 01:00:00  11985.473633  21730.000000
# 2022-01-08 01:30:00  11558.243164  21464.000000
# 2022-01-08 02:00:00  11207.249023  21225.000000
# 2022-01-08 02:30:00  10951.980469  21132.000000
# ...                           ...           ...
# 2024-10-30 22:00:00  25634.509766  29019.070312
# 2024-10-30 22:30:00  24423.523438  28465.740234
# 2024-10-30 23:00:00  23250.390625  27755.750000
# 2024-10-30 23:30:00  22146.808594  27277.500000
# 2024-10-31 00:00:00  21135.562500  26757.400391
#
# [49296 rows x 2 columns]
# after dropna
#                          Prediksi        Aktual
# Date
# 2022-01-08 00:30:00  12565.086914  21871.000000
# 2022-01-08 01:00:00  11985.473633  21730.000000
# 2022-01-08 01:30:00  11558.243164  21464.000000
# 2022-01-08 02:00:00  11207.249023  21225.000000
