-1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        0.579484 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.692562  1.224647e-16 -6.123234e-17      0.000000     -0.222521
# 75%        0.834486  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.069814  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17496.000000  1.749600e+04    17496.000000  17496.000000
# mean      -0.002107 -4.751840e-03        0.927556     -0.054150
# std        0.706636  7.075914e-01        0.295125      0.311896
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310872
# 50%        0.000000 -1.836970e-16        1.000000     -0.119035
# 75%        0.866025  5.000000e-01        1.000000      0.207501
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
x_train,    y_train     =   make_windows(input_make_windows, output_make_windows,total_window_size, input_slice, labels_slice)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows(input_make_windows_validation, output_make_windows_validation,total_window_size, input_slice, labels_slice)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((49537, 48, 9), (49537, 48), (17401, 48, 9), (17401, 48))

# %%
x_train.dtype, y_train.dtype, x_val.dtype, y_val.dtype
# Out:
# (dtype('float32'), dtype('float32'), dtype('float32'), dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input

def build_residual_cnn(input_shape, output_steps):
    # INPUT LAYER
    inputs = Input(shape=input_shape)

    # 1. INITIAL PROJECTION
    # Mengubah 9 fitur input menjadi 64 channel fitur laten
    x = layers.Conv1D(filters=64, kernel_size=1, padding='same')(inputs)
    
    # 2. RESIDUAL BLOCKS (Dengan Dilation rate bertingkat)
    # Ini kuncinya: Dilation 1, 2, 4, 8 mencakup "Receptive Field" > 48 jam
    for dilation_rate in [1, 2, 4, 8]:
        # Simpan input sebelumnya untuk ditambahkan nanti (Residual)
        shortcut = x
        
        # Layer Konvolusi dengan Dilation
        x = layers.Conv1D(filters=64, kernel_size=3, padding='same', 
                          dilation_rate=dilation_rate, activation='relu')(x)
        x = layers.BatchNormalization()(x) # Menstabilkan training
        x = layers.Dropout(0.1)(x)         # Mencegah overfitting
        
        # Layer Konvolusi kedua di dalam blok
        x = layers.Conv1D(filters=64, kernel_size=3, padding='same', 
                          dilation_rate=dilation_rate, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        
        # Add (Skip Connection)
        # Menambahkan output blok dengan input blok (x + shortcut)
        x = layers.Add()([x, shortcut])
        x = layers.Activation('relu')(x)

    # 3. OUTPUT HEAD
    # Flatten untuk menggabungkan seluruh fitur waktu
    x = layers.Flatten()(x)
    
    # Dense Layer untuk interpretasi akhir
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Output Layer (48 langkah ke depan)
    outputs = layers.Dense(output_steps)(x)

    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mae', metrics=['mse'])
    
    return model

# %%
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

seed_value = 20
tf.random.set_seed(seed_value)
import json
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, History
import time


def tensorflow_model(X_train_scaled, Y_train_scaled,
                   X_val_scaled,   Y_val_scaled,
                   learning_rate=1e-3,
                   target_MAE=0.001,
                   jumlah_epochs=50,
                   jumlah_sampel_batch=1,
                   jumlah_epoch_terbelakang=10,
                   save_best_model_path="model.h5",
                   validation_data=False,
                   load_model=None, seed_value=-1):

    global model, loss_history
    model= None
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    # History callback to capture training curves
    history_cb = History()

    # ---------- model ----------
    input_width  = X_train_scaled.shape[1]   # 300
    num_features = X_train_scaled.shape[2]   # 1
    CONV_WIDTH = OUT_STEPS
    if load_model is None:
        # --- CARA MENGGUNAKAN ---
        # input_width = 48, num_features = 9
        # output_steps = 48
        model = build_residual_cnn(input_shape=(input_width, 9), output_steps=label_width)
    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')],
                  steps_per_execution=128)

    # ---------- build callback list ----------
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(2, root=save_best_model_path.rstrip('.h5'))
    ]

    if validation_data:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=(X_val_scaled, Y_val_scaled) if validation_data else None,
                  validation_batch_size=jumlah_sampel_batch,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        # Save history to JSON even if training stopped early
        loss_history = {
            'loss': history_cb.history.get('loss', [])
        }
        if validation_data:
            loss_history['val_loss'] = history_cb.history.get('val_loss', [])
        with open('loss_history_%s.json'%seed_value, 'w') as f:
            json.dump(loss_history, f)
        print("Saved training & validation loss history to loss_history.json")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.001,  jumlah_epochs=10, jumlah_sampel_batch=32, 
                                                    jumlah_epoch_terbelakang=10,  save_best_model_path = "CNN%s_1.h5"%seed_value, 
                                                    validation_data=True, load_model=None, seed_value=seed_value)

    print(loss, MSE, MAE, MAPE)
    print("model.evaluate(x_val, y_val): ", model.evaluate(x_val, y_val))
    predictions = model.predict(x_train[slice(None, None, label_width), :, :])
    predictions_reshaped = predictions.reshape(-1,)
    predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
    df_pred_act = compute_error(x_train, data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)
    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()







    df_pred_act = compute_error(x_val, data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)

    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# Running with seed: 20
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 9)]      0           []
#
#  conv1d (Conv1D)                (None, 48, 64)       640         ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 48, 64)       12352       ['conv1d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 64)      256         ['conv1d_1[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 48, 64)       0           ['batch_normalization[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 48, 64)       12352       ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 64)      256         ['conv1d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 48, 64)       0           ['batch_normalization_1[0][0]',
#                                                                   'conv1d[0][0]']
#
#  activation (Activation)        (None, 48, 64)       0           ['add[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 48, 64)       12352       ['activation[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 64)      256         ['conv1d_3[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 48, 64)       0           ['batch_normalization_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 48, 64)       12352       ['dropout_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 48, 64)      256         ['conv1d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 48, 64)       0           ['batch_normalization_3[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (None, 48, 64)       0           ['add_1[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 48, 64)       12352       ['activation_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 64)      256         ['conv1d_5[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 48, 64)       0           ['batch_normalization_4[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 48, 64)       12352       ['dropout_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 64)      256         ['conv1d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 48, 64)       0           ['batch_normalization_5[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 48, 64)       0           ['add_2[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 48, 64)       12352       ['activation_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 64)      256         ['conv1d_7[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 48, 64)       0           ['batch_normalization_6[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 48, 64)       12352       ['dropout_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 64)      256         ['conv1d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 48, 64)       0           ['batch_normalization_7[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 48, 64)       0           ['add_3[0][0]']
#
#  flatten (Flatten)              (None, 3072)         0           ['activation_3[0][0]']
#
#  dense (Dense)                  (None, 128)          393344      ['flatten[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 48)           6192        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 501,040
# Trainable params: 500,016
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# Epoch 1/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.1706 - mse: 0.1706 - mae: 0.3161 - mape: 3704.4363
# Epoch 1: val_mse improved from inf to 0.66393, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 26s 17ms/step - loss: 0.1706 - mse: 0.1706 - mae: 0.3161 - mape: 3704.4363 - val_loss: 0.6639 - val_mse: 0.6639 - val_mae: 0.6698 - val_mape: 114.0876
# Epoch 2/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0528 - mse: 0.0528 - mae: 0.1801 - mape: 6578.1650
# 📦  Saved checkpoint: CNN20_1_epoch02.h5
#
# Epoch 2: val_mse improved from 0.66393 to 0.54368, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 23s 15ms/step - loss: 0.0528 - mse: 0.0528 - mae: 0.1801 - mape: 6578.1650 - val_loss: 0.5437 - val_mse: 0.5437 - val_mae: 0.6281 - val_mape: 107.1850
# Epoch 3/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0399 - mse: 0.0399 - mae: 0.1553 - mape: 7196.9932
# Epoch 3: val_mse improved from 0.54368 to 0.54295, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 40s 26ms/step - loss: 0.0399 - mse: 0.0399 - mae: 0.1553 - mape: 7196.9932 - val_loss: 0.5429 - val_mse: 0.5429 - val_mae: 0.6097 - val_mape: 104.8129
# Epoch 4/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0318 - mse: 0.0318 - mae: 0.1375 - mape: 7569.2749
# 📦  Saved checkpoint: CNN20_1_epoch04.h5
#
# Epoch 4: val_mse improved from 0.54295 to 0.40850, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 27s 17ms/step - loss: 0.0318 - mse: 0.0318 - mae: 0.1375 - mape: 7569.2749 - val_loss: 0.4085 - val_mse: 0.4085 - val_mae: 0.5068 - val_mape: 89.5097
# Epoch 5/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0255 - mse: 0.0255 - mae: 0.1220 - mape: 7121.4229
# Epoch 5: val_mse improved from 0.40850 to 0.26696, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 25s 16ms/step - loss: 0.0255 - mse: 0.0255 - mae: 0.1220 - mape: 7121.4229 - val_loss: 0.2670 - val_mse: 0.2670 - val_mae: 0.3985 - val_mape: 71.2782
# Epoch 6/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0207 - mse: 0.0207 - mae: 0.1099 - mape: 7071.6333
# 📦  Saved checkpoint: CNN20_1_epoch06.h5
#
# Epoch 6: val_mse improved from 0.26696 to 0.13902, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 20s 13ms/step - loss: 0.0207 - mse: 0.0207 - mae: 0.1099 - mape: 7071.6333 - val_loss: 0.1390 - val_mse: 0.1390 - val_mae: 0.2576 - val_mape: 47.6420
# Epoch 7/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0180 - mse: 0.0180 - mae: 0.1029 - mape: 7875.7100
# Epoch 7: val_mse improved from 0.13902 to 0.13499, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 20s 13ms/step - loss: 0.0180 - mse: 0.0180 - mae: 0.1029 - mape: 7875.7100 - val_loss: 0.1350 - val_mse: 0.1350 - val_mae: 0.2502 - val_mape: 45.7696
# Epoch 8/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0163 - mse: 0.0163 - mae: 0.0988 - mape: 8804.8955
# 📦  Saved checkpoint: CNN20_1_epoch08.h5
#
# Epoch 8: val_mse improved from 0.13499 to 0.07596, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 23s 15ms/step - loss: 0.0163 - mse: 0.0163 - mae: 0.0988 - mape: 8804.8955 - val_loss: 0.0760 - val_mse: 0.0760 - val_mae: 0.1864 - val_mape: 33.7554
# Epoch 9/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0155 - mse: 0.0155 - mae: 0.0969 - mape: 9436.2852
# Epoch 9: val_mse improved from 0.07596 to 0.06413, saving model to CNN20_1.h5
# 1549/1549 [==============================] - 22s 14ms/step - loss: 0.0155 - mse: 0.0155 - mae: 0.0969 - mape: 9436.2852 - val_loss: 0.0641 - val_mse: 0.0641 - val_mae: 0.1687 - val_mape: 30.7045
# Epoch 10/10
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0152 - mse: 0.0152 - mae: 0.0960 - mape: 9842.3301
# 📦  Saved checkpoint: CNN20_1_epoch10.h5
#
# Epoch 10: val_mse did not improve from 0.06413
# 1549/1549 [==============================] - 22s 14ms/step - loss: 0.0152 - mse: 0.0152 - mae: 0.0960 - mape: 9842.3301 - val_loss: 0.0770 - val_mse: 0.0770 - val_mae: 0.1813 - val_mape: 33.4600
# Saved training & validation loss history to loss_history.json
# Train time (s): 247.72874927520752
# Train  Loss=0.10011  MSE=0.10011  MAE=0.22499  MAPE=27331.223%
# 0.10011135786771774 0.10011135786771774 0.22499200701713562 27331.22265625
# 544/544 [==============================] - 2s 3ms/step - loss: 0.0770 - mse: 0.0770 - mae: 0.1813 - mape: 33.4600
# model.evaluate(x_val, y_val):  [0.07699226588010788, 0.07699226588010788, 0.18130935728549957, 33.46002197265625]
# 33/33 [==============================] - 1s 19ms/step
# 33/33 [==============================] - 0s 2ms/step
# before dropna
#                          Prediksi        Aktual
# Date
# 2022-01-02 00:30:00  32030.826172  17506.000000
# 2022-01-02 01:00:00  31122.648438  17293.000000
# 2022-01-02 01:30:00  30344.605469  17108.000000
# 2022-01-02 02:00:00  29620.548828  16876.000000
# 2022-01-02 02:30:00  29034.859375  16729.000000
# ...                           ...           ...
# 2024-10-30 22:00:00  28503.871094  29019.070312
# 2024-10-30 22:30:00  27036.220703  28465.740234
# 2024-10-30 23:00:00  27699.121094  27755.750000
# 2024-10-30 23:30:00  28143.324219  27277.500000
# 2024-10-31 00:00:00  28184.957031  26757.400391
#
# [49584 rows x 2 columns]
# after dropna
#                          Prediksi        Aktual
# Date
# 2022-01-02 00:30:00