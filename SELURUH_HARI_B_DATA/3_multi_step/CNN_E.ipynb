7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.139628  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17496.000000  1.749600e+04    17496.000000  17496.000000
# mean      -0.002107 -4.751840e-03        0.927556     -0.054150
# std        0.706636  7.075914e-01        0.295125      0.311896
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310872
# 50%        0.000000 -1.836970e-16        1.000000     -0.119035
# 75%        0.866025  5.000000e-01        1.000000      0.207501
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
x_train,    y_train     =   make_windows(input_make_windows, output_make_windows,total_window_size, input_slice, labels_slice)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows(input_make_windows_validation, output_make_windows_validation,total_window_size, input_slice, labels_slice)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((49537, 48, 9), (49537, 48), (17401, 48, 9), (17401, 48))

# %%
x_train.dtype, y_train.dtype, x_val.dtype, y_val.dtype
# Out:
# (dtype('float32'), dtype('float32'), dtype('float32'), dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input

def build_real_tcms_cnn(input_shape, output_steps, num_filters=24, num_blocks=8):
    # 1. Input Layer
    inputs = Input(shape=input_shape)
    
    # 2. Initial Projection
    # Ubah dimensi input (9 fitur) agar sesuai dengan jumlah filter (misal 64)
    # Gunakan 'causal' padding atau 'same' (paper load forecasting sering pakai 'same' untuk konteks penuh)
    x = layers.Conv1D(filters=num_filters, kernel_size=1, padding='same', activation='linear')(inputs)
    
    # 3. Stack 8 Blocks (Sesuai Paper)
    for i in range(num_blocks):
        # Simpan input blok untuk Residual Connection (Skip Connection)
        shortcut = x
        
        # --- ISI BLOK: 3 Layer Konvolusi Berurutan (Dilation 1, 2, 4) ---
        
        # Layer 1: Dilation rate = 1
        x = layers.Conv1D(filters=num_filters, kernel_size=3, padding='same', dilation_rate=1, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.1)(x)
        
        # Layer 2: Dilation rate = 2
        x = layers.Conv1D(filters=num_filters, kernel_size=3, padding='same', dilation_rate=2, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.1)(x)
        
        # Layer 3: Dilation rate = 4
        x = layers.Conv1D(filters=num_filters, kernel_size=3, padding='same', dilation_rate=4, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        
        # --- RESIDUAL ADDITION ---
        # Tambahkan output blok dengan input awal blok
        x = layers.Add()([x, shortcut])
        x = layers.Activation('relu')(x)

    # # Flatten untuk menjaga urutan waktu sebelum masuk Dense
    x = layers.Flatten()(x)

    x = layers.Dense(48, activation='relu')(x)

    # Output Layer: Prediksi 48 langkah ke depan
    outputs = layers.Dense(output_steps)(x)
    model = models.Model(inputs=inputs, outputs=outputs, name="Real_TCMS_CNN_8Blocks")
    return model

# %%
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

seed_value = 20
tf.random.set_seed(seed_value)
import json
import tensorflow as tf
from tensorflow.keras import layers, mixed_precision, initializers, models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, History
import time


def tensorflow_model(X_train_scaled, Y_train_scaled,
                   X_val_scaled,   Y_val_scaled,
                   learning_rate=1e-3,
                   target_MAE=0.001,
                   jumlah_epochs=50,
                   jumlah_sampel_batch=1,
                   jumlah_epoch_terbelakang=10,
                   save_best_model_path="model.h5",
                   validation_data=False,
                   load_model=None, seed_value=-1):

    global model, loss_history
    model= None
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    # History callback to capture training curves
    history_cb = History()

    # ---------- model ----------
    input_width  = X_train_scaled.shape[1]   # 300
    num_features = X_train_scaled.shape[2]   # 9
    if load_model is None:
        # --- CARA MENGGUNAKAN ---
        # input_width = 48, num_features = 9
        # output_steps = 48
        model =   build_real_tcms_cnn(
    input_shape=(input_width, 9), 
    output_steps=OUT_STEPS,
    num_filters=24,
    num_blocks=8  # Total 8 blok
)

    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')],
                  steps_per_execution=128)

    # ---------- build callback list ----------
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(10, root=save_best_model_path.rstrip('.h5'))
    ]

    if validation_data:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        cb += [
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=(X_val_scaled, Y_val_scaled) if validation_data else None,
                  validation_batch_size=jumlah_sampel_batch,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        # Save history to JSON even if training stopped early
        loss_history = {
            'loss': history_cb.history.get('loss', [])
        }
        if validation_data:
            loss_history['val_loss'] = history_cb.history.get('val_loss', [])
        with open('loss_history_%s.json'%seed_value, 'w') as f:
            json.dump(loss_history, f)
        print("Saved training & validation loss history to loss_history.json")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.001,  jumlah_epochs=20, jumlah_sampel_batch=32, 
                                                    jumlah_epoch_terbelakang=10,  save_best_model_path = "CNN_D1_%s.h5"%seed_value, 
                                                    validation_data=True, load_model=None, seed_value=seed_value)

    print(loss, MSE, MAE, MAPE)
    print("model.evaluate(x_val, y_val): ", model.evaluate(x_val, y_val))
    predictions = model.predict(x_train[slice(None, None, label_width), :, :])
    predictions_reshaped = predictions.reshape(-1,)
    predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
    df_pred_act = compute_error(x_train, data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)
    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()







    df_pred_act = compute_error(x_val, data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)

    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# Running with seed: 20
# Model: "Real_TCMS_CNN_8Blocks"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 9)]      0           []
#
#  conv1d (Conv1D)                (None, 48, 24)       240         ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 48, 24)       1752        ['conv1d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 24)      96          ['conv1d_1[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 48, 24)       0           ['batch_normalization[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 48, 24)       1752        ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 24)      96          ['conv1d_2[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 48, 24)       0           ['batch_normalization_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 48, 24)       1752        ['dropout_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 24)      96          ['conv1d_3[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 48, 24)       0           ['batch_normalization_2[0][0]',
#                                                                   'conv1d[0][0]']
#
#  activation (Activation)        (None, 48, 24)       0           ['add[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 48, 24)       1752        ['activation[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 48, 24)      96          ['conv1d_4[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 48, 24)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 48, 24)       1752        ['dropout_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 24)      96          ['conv1d_5[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 48, 24)       0           ['batch_normalization_4[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 48, 24)       1752        ['dropout_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 24)      96          ['conv1d_6[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 48, 24)       0           ['batch_normalization_5[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (None, 48, 24)       0           ['add_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 48, 24)       1752        ['activation_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 24)      96          ['conv1d_7[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 48, 24)       0           ['batch_normalization_6[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 48, 24)       1752        ['dropout_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 24)      96          ['conv1d_8[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 48, 24)       0           ['batch_normalization_7[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 48, 24)       1752        ['dropout_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 48, 24)      96          ['conv1d_9[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 48, 24)       0           ['batch_normalization_8[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 48, 24)       0           ['add_2[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 48, 24)       1752        ['activation_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 48, 24)      96          ['conv1d_10[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 48, 24)       0           ['batch_normalization_9[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 48, 24)       1752        ['dropout_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 48, 24)      96          ['conv1d_11[0][0]']
#  ormalization)
#
#  dropout_7 (Dropout)            (None, 48, 24)       0           ['batch_normalization_10[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 48, 24)       1752        ['dropout_7[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 48, 24)      96          ['conv1d_12[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 48, 24)       0           ['batch_normalization_11[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 48, 24)       0           ['add_3[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 48, 24)       1752        ['activation_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 48, 24)      96          ['conv1d_13[0][0]']
#  ormalization)
#
#  dropout_8 (Dropout)            (None, 48, 24)       0           ['batch_normalization_12[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 48, 24)       1752        ['dropout_8[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 48, 24)      96          ['conv1d_14[0][0]']
#  ormalization)
#
#  dropout_9 (Dropout)            (None, 48, 24)       0           ['batch_normalization_13[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 48, 24)       1752        ['dropout_9[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 48, 24)      96          ['conv1d_15[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 48, 24)       0           ['batch_normalization_14[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 48, 24)       0           ['add_4[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 48, 24)       1752        ['activation_4[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 48, 24)      96          ['conv1d_16[0][0]']
#  ormalization)
#
#  dropout_10 (Dropout)           (None, 48, 24)       0           ['batch_normalization_15[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 48, 24)       1752        ['dropout_10[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 48, 24)      96          ['conv1d_17[0][0]']
#  ormalization)
#
#  dropout_11 (Dropout)           (None, 48, 24)       0           ['batch_normalization_16[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 48, 24)       1752        ['dropout_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 48, 24)      96          ['conv1d_18[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 48, 24)       0           ['batch_normalization_17[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 48, 24)       0           ['add_5[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 48, 24)       1752        ['activation_5[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 48, 24)      96          ['conv1d_19[0][0]']
#  ormalization)
#
#  dropout_12 (Dropout)           (None, 48, 24)       0           ['batch_normalization_18[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 48, 24)       1752        ['dropout_12[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 48, 24)      96          ['conv1d_20[0][0]']
#  ormalization)
#
#  dropout_13 (Dropout)           (None, 48, 24)       0           ['batch_normalization_19[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 48, 24)       1752        ['dropout_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 48, 24)      96          ['conv1d_21[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 48, 24)       0           ['batch_normalization_20[0][0]',
#                                                                   'activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 48, 24)       0           ['add_6[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 48, 24)       1752        ['activation_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 48, 24)      96          ['conv1d_22[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 48, 24)       0           ['batch_normalization_21[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 48, 24)       1752        ['dropout_14[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 48, 24)      96          ['conv1d_23[0][0]']
#  ormalization)
#
#  dropout_15 (Dropout)           (None, 48, 24)       0           ['batch_normalization_22[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 48, 24)       1752        ['dropout_15[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 48, 24)      96          ['conv1d_24[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 48, 24)       0           ['batch_normalization_23[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 48, 24)       0           ['add_7[0][0]']
#
#  flatten (Flatten)              (None, 1152)         0           ['activation_7[0][0]']
#
#  dense (Dense)                  (None, 48)           55344       ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 48)           2352        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 102,288
# Trainable params: 101,136
# Non-trainable params: 1,152
# __________________________________________________________________________________________________
# Epoch 1/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.1993 - mse: 0.1993 - mae: 0.3197 - mape: 242.9991
# Epoch 1: val_mse improved from inf to 0.19499, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 55s 36ms/step - loss: 0.1993 - mse: 0.1993 - mae: 0.3197 - mape: 242.9991 - val_loss: 0.1950 - val_mse: 0.1950 - val_mae: 0.3650 - val_mape: 251.2393
# Epoch 2/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.1049 - mse: 0.1049 - mae: 0.2665 - mape: 248.2360
# Epoch 2: val_mse improved from 0.19499 to 0.16432, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 53s 34ms/step - loss: 0.1049 - mse: 0.1049 - mae: 0.2665 - mape: 248.2360 - val_loss: 0.1643 - val_mse: 0.1643 - val_mae: 0.3319 - val_mape: 362.4562
# Epoch 3/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0997 - mse: 0.0997 - mae: 0.2610 - mape: 325.5235
# Epoch 3: val_mse improved from 0.16432 to 0.14863, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 58s 37ms/step - loss: 0.0997 - mse: 0.0997 - mae: 0.2610 - mape: 325.5235 - val_loss: 0.1486 - val_mse: 0.1486 - val_mae: 0.3149 - val_mape: 432.7496
# Epoch 4/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0985 - mse: 0.0985 - mae: 0.2598 - mape: 375.0728
# Epoch 4: val_mse improved from 0.14863 to 0.14074, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 44s 28ms/step - loss: 0.0985 - mse: 0.0985 - mae: 0.2598 - mape: 375.0728 - val_loss: 0.1407 - val_mse: 0.1407 - val_mae: 0.3065 - val_mape: 473.3036
# Epoch 5/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0984 - mse: 0.0984 - mae: 0.2597 - mape: 402.7127
# Epoch 5: val_mse improved from 0.14074 to 0.13673, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 46s 29ms/step - loss: 0.0984 - mse: 0.0984 - mae: 0.2597 - mape: 402.7127 - val_loss: 0.1367 - val_mse: 0.1367 - val_mae: 0.3022 - val_mape: 495.6042
# Epoch 6/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0985 - mse: 0.0985 - mae: 0.2598 - mape: 418.0432
# Epoch 6: val_mse improved from 0.13673 to 0.13466, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 49s 32ms/step - loss: 0.0985 - mse: 0.0985 - mae: 0.2598 - mape: 418.0432 - val_loss: 0.1347 - val_mse: 0.1347 - val_mae: 0.3000 - val_mape: 507.6463
# Epoch 7/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0986 - mse: 0.0986 - mae: 0.2600 - mape: 426.3262
# Epoch 7: val_mse improved from 0.13466 to 0.13358, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 46s 30ms/step - loss: 0.0986 - mse: 0.0986 - mae: 0.2600 - mape: 426.3262 - val_loss: 0.1336 - val_mse: 0.1336 - val_mae: 0.2989 - val_mape: 514.1513
# Epoch 8/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 430.7867
# Epoch 8: val_mse improved from 0.13358 to 0.13301, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 46s 30ms/step - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 430.7867 - val_loss: 0.1330 - val_mse: 0.1330 - val_mae: 0.2983 - val_mape: 517.5423
# Epoch 9/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 433.1740
# Epoch 9: val_mse improved from 0.13301 to 0.13271, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 47s 31ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 433.1740 - val_loss: 0.1327 - val_mse: 0.1327 - val_mae: 0.2980 - val_mape: 519.4137
# Epoch 10/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 434.4405
# 📦  Saved checkpoint: CNN_D1_20_epoch10.h5
#
# Epoch 10: val_mse improved from 0.13271 to 0.13255, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 58s 38ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 434.4405 - val_loss: 0.1325 - val_mse: 0.1325 - val_mae: 0.2978 - val_mape: 520.4029
# Epoch 11/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 435.1286
# Epoch 11: val_mse improved from 0.13255 to 0.13246, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 83s 54ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 435.1286 - val_loss: 0.1325 - val_mse: 0.1325 - val_mae: 0.2977 - val_mape: 520.9334
# Epoch 12/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 435.4978
# Epoch 12: val_mse improved from 0.13246 to 0.13242, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 72s 47ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 435.4978 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2977 - val_mape: 521.2153
# Epoch 13/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 435.6884
# Epoch 13: val_mse improved from 0.13242 to 0.13239, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 42s 27ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2601 - mape: 435.6884 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.3695
# Epoch 14/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.7973
# Epoch 14: val_mse improved from 0.13239 to 0.13238, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 40s 26ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.7973 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.4594
# Epoch 15/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.8549
# Epoch 15: val_mse improved from 0.13238 to 0.13237, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 41s 26ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.8549 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.4932
# Epoch 16/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.8846
# Epoch 16: val_mse improved from 0.13237 to 0.13237, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 45s 29ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.8846 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.5166
# Epoch 17/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.8999
# Epoch 17: val_mse improved from 0.13237 to 0.13236, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 41s 27ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.8999 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.5286
# Epoch 18/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.9059
# Epoch 18: val_mse improved from 0.13236 to 0.13236, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 41s 26ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.9059 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.5361
# Epoch 19/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.9145
# Epoch 19: val_mse improved from 0.13236 to 0.13236, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 41s 26ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.9145 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.5403
# Epoch 20/20
# 1549/1549 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.9228
# 📦  Saved checkpoint: CNN_D1_20_epoch20.h5
#
# Epoch 20: val_mse improved from 0.13236 to 0.13236, saving model to CNN_D1_20.h5
# 1549/1549 [==============================] - 41s 26ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 435.9228 - val_loss: 0.1324 - val_mse: 0.1324 - val_mae: 0.2976 - val_mape: 521.5405
# Saved training & validation loss history to loss_history.json
# Train time (s): 989.9709904193878
# Train  Loss=0.09917  MSE=0.09917  MAE=0.26064  MAPE=478.622%
# 0.09916751831769943 0.09916751831769943 0.26063790917396545 478.6222839355469
# 544/544 [==============================] - 3s 6ms/step - loss: 0.1324 - mse: 0.1324 - mae: 0.2976 - mape: 521.5405
# model.evaluate(x_val, y_val):  [0.13236288726329803, 0.13236288726329803, 0.2975960373878479, 521.5404663085938]
# 33/33 [==============================] - 2s 48ms/step
# 33/33 [==============================] - 0s 6ms/step
# before dropna
#                          Prediksi        Aktual
# Date
# 2022-01-02 00:30:00  17513.089844  17506.000000
# 2022-01-02 01:00:00  17516.044922  17293.000000
# 2022-01-02 01:30:00  17519.322266  17108.000000
# 2022-01-02 02:00:00  17522.287109  16876.000000
# 2022-01-02 02:30:00  17524.642578  16729.000000
# ...                           ...           ...
# 2024-10-30 22:00:00  17532.820312  29019.070312
# 2024-10-30 22:30:00  17531.410156  28465.740234
# 2024-10-30 23:00:00  17529.544922  27755.750000
# 2024-10-30 23:30:00  17527.949219  27277.500000
# 2024-10-31 00:00:00  17527.869141  26757.400391
#
# [49584 rows x 2 columns]
# after dropna
#                          Prediksi        Aktual
# Date
# 2022-01-02 00:30:00