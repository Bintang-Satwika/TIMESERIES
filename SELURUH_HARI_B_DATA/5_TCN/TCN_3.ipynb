# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
# Parameter windowing
input_width = int(48)*7
label_width = 48
shift = label_width
total_window_size = input_width + shift
OUT_STEPS = label_width
# Definisikan irisan untuk input dan label
input_slice = slice(0, input_width)
label_start = total_window_size - label_width
labels_slice = slice(label_start, None)

from B_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive, make_windows

# %% [markdown]
# # data training

# %%
data_training_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_train_data.xlsx', index_col=0)
data_training= data_training_awal.astype('float32').copy()
data_training
# Out:
#                             Beban   Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2022-01-01 00:30:00  18402.000000  0.130526  0.991445 -0.974928 -0.222521
# 2022-01-01 01:00:00  18214.000000  0.258819  0.965926 -0.974928 -0.222521
# 2022-01-01 01:30:00  17974.000000  0.382683  0.923880 -0.974928 -0.222521
# 2022-01-01 02:00:00  17729.000000  0.500000  0.866025 -0.974928 -0.222521
# 2022-01-01 02:30:00  17532.000000  0.608761  0.793353 -0.974928 -0.222521
# ...                           ...       ...       ...       ...       ...
# 2024-10-30 22:00:00  29019.070312 -0.500000  0.866025  0.974928 -0.222521
# 2024-10-30 22:30:00  28465.740234 -0.382683  0.923880  0.974928 -0.222521
# 2024-10-30 23:00:00  27755.750000 -0.258819  0.965926  0.974928 -0.222521
# 2024-10-30 23:30:00  27277.500000 -0.130526  0.991445  0.974928 -0.222521
# 2024-10-31 00:00:00  26757.400391  0.000000  1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2022-01-01 00:30:00        0.0  1.000000e+00        0.762049 -4.403535
# 2022-01-01 01:00:00        0.0  1.000000e+00        0.762049 -4.566491
# 2022-01-01 01:30:00        0.0  1.000000e+00        0.762049 -4.811594
# 2022-01-01 02:00:00        0.0  1.000000e+00        0.762049 -5.056697
# 2022-01-01 02:30:00        0.0  1.000000e+00        0.762049 -5.223890
# ...                        ...           ...             ...       ...
# 2024-10-30 22:00:00       -1.0 -1.836970e-16        1.012018  0.447690
# 2024-10-30 22:30:00       -1.0 -1.836970e-16        1.012018  0.134316
# 2024-10-30 23:00:00       -1.0 -1.836970e-16        1.012018 -0.179059
# 2024-10-30 23:30:00       -1.0 -1.836970e-16        1.012018 -0.402285
# 2024-10-31 00:00:00       -1.0 -1.836970e-16        1.012018 -0.625510
#
# [49632 rows x 9 columns]

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean   24933.849609  1.229754e-09  0.000000e+00      0.000028      0.001729
# std     3040.183838  7.071139e-01  7.071139e-01      0.707530      0.706637
# min    13475.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%    22701.939941 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%    24934.724609  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%    27240.225586  7.071068e-01  7.071068e-01      0.781832      0.623490
# max    32758.619141  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        1.000537     -0.297909
# std    7.057171e-01  7.060366e-01        0.047190      4.279032
# min   -1.000000e+00 -1.000000e+00        0.697430    -10.782065
# 25%   -5.000000e-01 -8.660254e-01        1.012018     -3.767943
# 50%    1.224647e-16 -1.836970e-16        1.012018     -1.268959
# 75%    8.660254e-01  5.000000e-01        1.012018      2.886689
# max    1.000000e+00  1.000000e+00        1.012018     13.803565

# %%
data_training['Suhu_PCA'], min_suhu, max_suhu = scale_array(
    data_training['Suhu_PCA'].values, 
    new_min=-1,
    new_max=1)

data_training['Holiday_Impact'], min_holiday, max_holiday = scale_array(
    data_training['Holiday_Impact'].values, 
    new_min=-1, 
    new_max=1
)

data_training['Beban'], min_beban, max_beban = scale_array(
    data_training['Beban'].values, 
    new_min=-1, 
    new_max=1)
# Out:
# Computed orig_min: -10.782065391540527
# Computed orig_max: 13.80356502532959
# Computed orig_min: 0.6974297761917114
# Computed orig_max: 1.0120183229446411
# Computed orig_min: 13475.0
# Computed orig_max: 32758.619140625

# %%
data_training.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  49632.000000  4.963200e+04  4.963200e+04  49632.000000  49632.000000
# mean       0.188454  1.229754e-09  0.000000e+00      0.000028      0.001729
# std        0.315313  7.071139e-01  7.071139e-01      0.707530      0.706637
# min       -1.000000 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%       -0.043028 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.188545  6.123234e-17 -6.123234e-17      0.000000     -0.222521
# 75%        0.427660  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.000000  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  4.963200e+04  4.963200e+04    49632.000000  49632.000000
# mean   3.786855e-02 -4.467865e-02        0.927008     -0.147131
# std    7.057171e-01  7.060366e-01        0.300029      0.348093
# min   -1.000000e+00 -1.000000e+00       -1.000000     -1.000000
# 25%   -5.000000e-01 -8.660254e-01        1.000000     -0.429413
# 50%    1.224647e-16 -1.836970e-16        1.000000     -0.226125
# 75%    8.660254e-01  5.000000e-01        1.000000      0.111930
# max    1.000000e+00  1.000000e+00        1.000000      1.000000

# %% [markdown]
# # data validation (testing)

# %%
data_validation_awal= pd.read_excel('D:\\JAMALI FORECASTING\\B_test_data.xlsx', index_col=0)
data_validation= data_validation_awal.astype('float32').copy()
data_validation
# Out:
#                             Beban       Jam_sin   Jam_cos  Hari_sin  Hari_cos  \
# Date
# 2024-10-31 00:30:00  26460.919922  1.305262e-01  0.991445  0.433884 -0.900969
# 2024-10-31 01:00:00  26184.929688  2.588190e-01  0.965926  0.433884 -0.900969
# 2024-10-31 01:30:00  25976.689453  3.826834e-01  0.923880  0.433884 -0.900969
# 2024-10-31 02:00:00  25745.220703  5.000000e-01  0.866025  0.433884 -0.900969
# 2024-10-31 02:30:00  25441.970703  6.087614e-01  0.793353  0.433884 -0.900969
# ...                           ...           ...       ...       ...       ...
# 2025-10-30 10:00:00  30957.800781  5.000000e-01 -0.866025  0.433884 -0.900969
# 2025-10-30 10:30:00  30580.789062  3.826834e-01 -0.923880  0.433884 -0.900969
# 2025-10-30 11:00:00  31497.359375  2.588190e-01 -0.965926  0.433884 -0.900969
# 2025-10-30 11:30:00  31337.589844  1.305262e-01 -0.991445  0.433884 -0.900969
# 2025-10-30 12:00:00  20014.880859  1.224647e-16 -1.000000  0.433884 -0.900969
#
#                      Bulan_sin     Bulan_cos  Holiday_Impact  Suhu_PCA
# Date
# 2024-10-31 00:30:00       -1.0 -1.836970e-16        1.012018 -0.829108
# 2024-10-31 01:00:00       -1.0 -1.836970e-16        1.012018 -1.032705
# 2024-10-31 01:30:00       -1.0 -1.836970e-16        1.012018 -1.284443
# 2024-10-31 02:00:00       -1.0 -1.836970e-16        1.012018 -1.536183
# 2024-10-31 02:30:00       -1.0 -1.836970e-16        1.012018 -1.717856
# ...                        ...           ...             ...       ...
# 2025-10-30 10:00:00       -1.0 -1.836970e-16        1.012018  3.765654
# 2025-10-30 10:30:00       -1.0 -1.836970e-16        1.012018  4.427866
# 2025-10-30 11:00:00       -1.0 -1.836970e-16        1.012018  5.090077
# 2025-10-30 11:30:00       -1.0 -1.836970e-16        1.012018  5.516177
# 2025-10-30 12:00:00       -1.0 -1.836970e-16        1.012018  5.942276
#
# [17496 rows x 9 columns]

# %%
data_validation['Suhu_PCA'], _, _ = scale_array(
    data_validation['Suhu_PCA'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_suhu,
    orig_max=max_suhu
)
data_validation['Holiday_Impact'], _, _ = scale_array(
    data_validation['Holiday_Impact'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_holiday,
    orig_max=max_holiday
)
data_validation['Beban'], _, _ = scale_array(
    data_validation['Beban'].values, 
    new_min=-1, 
    new_max=1,
    orig_min=min_beban,
    orig_max=max_beban
)

# %%
data_validation.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  17496.000000  1.749600e+04  1.749600e+04  17496.000000  17496.000000
# mean       0.389520  8.720320e-04 -5.715587e-05      0.000595     -0.001236
# std        0.317044  7.071220e-01  7.071295e-01      0.706819      0.707422
# min       -0.775485 -1.000000e+00 -1.000000e+00     -0.974928     -0.900969
# 25%        0.158968 -7.071068e-01 -7.071068e-01     -0.781832     -0.900969
# 50%        0.385124  1.224647e-16 -6.123234e-17      0.000000     -0.222521
# 75%        0.668971  7.071068e-01  7.071068e-01      0.781832      0.623490
# max        1.139628  1.000000e+00  1.000000e+00      0.974928      1.000000
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17496.000000  1.749600e+04    17496.000000  17496.000000
# mean      -0.002107 -4.751840e-03        0.927556     -0.054150
# std        0.706636  7.075914e-01        0.295125      0.311896
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310872
# 50%        0.000000 -1.836970e-16        1.000000     -0.119035
# 75%        0.866025  5.000000e-01        1.000000      0.207501
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
x_train,    y_train     =   make_windows(input_make_windows, output_make_windows,total_window_size, input_slice, labels_slice)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val,  y_val                   = make_windows(input_make_windows_validation, output_make_windows_validation,total_window_size, input_slice, labels_slice)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((49249, 336, 9), (49249, 48), (17113, 336, 9), (17113, 48))

# %%
x_train.dtype, y_train.dtype, x_val.dtype, y_val.dtype
# Out:
# (dtype('float32'), dtype('float32'), dtype('float32'), dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense

def build_model_tensor(input_lag, num_features, forecast_horizon):
    model = Sequential()
    
    # 1. The Input Layer
    # Accepts the full 336 steps and 9 features without deleting anything.
    model.add(Input(shape=(input_lag, num_features)))

    # 2. Convolutional Layers (The Feature Extractors)
    # kernel_size=3 allows the filter to look at 1.5 hours of data at a time
    # and actually slide across the entire week to find trends.
    # We use the default glorot_uniform initializer to avoid symmetry breaking.
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))

    # 3. The Flatten Layer
    # Converts the extracted temporal patterns into a flat summary vector.
    model.add(Flatten())

    # 4. Hidden Dense Layer
    # Helps the model interpret the complex relationships between the 9 features.
    model.add(Dense(128, activation='relu'))

    # 5. The Output Layer
    # Directly outputs the next 48 steps of Megawatt load predictions.
    # The shape is naturally (Batch, 48), so no awkward Reshape layer is needed.
    model.add(Dense(forecast_horizon))

    return model

# %%
import tensorflow as tf
import time
import json
from tensorflow.keras.callbacks import History, ModelCheckpoint, EarlyStopping

def tensorflow_model(X_train_scaled, Y_train_scaled,
                   X_val_scaled,   Y_val_scaled,
                   learning_rate=1e-3,
                   target_MAE=0.001,
                   jumlah_epochs=50,
                   jumlah_sampel_batch=1,
                   jumlah_epoch_terbelakang=10,
                   save_best_model_path="model.h5",
                   validation_data=False,
                   load_model=None, seed_value=-1):

    global model, loss_history
    model= None
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    class LiveLossLogger(tf.keras.callbacks.Callback):
        def __init__(self, filename, use_validation):
            super().__init__()
            self.filename = filename
            self.use_validation = use_validation
            self.live_history = {'loss': []}
            if self.use_validation:
                self.live_history['val_loss'] = []

        def on_epoch_end(self, epoch, logs=None):
            logs = logs or {}
            
            # Convert float32 from TensorFlow to native Python float for JSON compatibility
            current_loss = logs.get('loss')
            if current_loss is not None:
                self.live_history['loss'].append(float(current_loss))
            
            if self.use_validation:
                # Keras usually stores validation loss under 'val_loss'
                current_val_loss = logs.get('val_loss') 
                if current_val_loss is not None:
                    self.live_history['val_loss'].append(float(current_val_loss))
            
            # Open the file and overwrite it with the updated arrays
            with open(self.filename, 'w') as f:
                json.dump(self.live_history, f)

    # History callback to capture training curves
    history_cb = History()

    # ---------- model ----------
    input_width  = X_train_scaled.shape[1]   
    num_features = X_train_scaled.shape[2]   
    
    if load_model is None:
        model = build_model_tensor(input_width, num_features, Y_train_scaled.shape[1])
    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')],
                  steps_per_execution=128)

    # ---------- build callback list ----------
    json_filename = f"loss_history_{save_best_model_path}.json"
    
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(10, root=save_best_model_path.rstrip('.h5')),
        LiveLossLogger(json_filename, validation_data)
    ]

    if validation_data:
        lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_mse',    
            factor=0.5,           
            patience=4,           
            min_lr=1e-6,          
            verbose=1             
        )
        
        cb += [
            lr_scheduler,
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='mse',        
            factor=0.5,
            patience=4,
            min_lr=1e-6,
            verbose=1
        )
        
        cb += [
            lr_scheduler,
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=(X_val_scaled, Y_val_scaled) if validation_data else None,
                  validation_batch_size=jumlah_sampel_batch,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        # We can read the final saved state from the file to populate the return variable
        try:
            with open(json_filename, 'r') as f:
                loss_history = json.load(f)
        except FileNotFoundError:
            loss_history = {}
        print(f"Final training and validation loss securely saved to {json_filename}")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    save_best_model_path = "TCN3_%s.h5"%seed_value
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(x_train, y_train, x_val, y_val, learning_rate=0.001, target_MAE=0.001,  jumlah_epochs=100, jumlah_sampel_batch=16, 
                                                    jumlah_epoch_terbelakang=10,  save_best_model_path = save_best_model_path, 
                                                    validation_data=True, load_model=None, seed_value=seed_value)
    print(loss, MSE, MAE, MAPE)
    save_best_model_path
    model.load_weights(save_best_model_path)
    print("Loading best model from: ", save_best_model_path)
    print("model.evaluate(x_val, y_val): ", model.evaluate(x_val, y_val))
    predictions = model.predict(x_train[slice(None, None, label_width), :, :])
    predictions_reshaped = predictions.reshape(-1,)
    predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
    df_pred_act = compute_error(x_train, data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)
    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()







    df_pred_act = compute_error(x_val, data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
    print(df_pred_act)

    df= df_pred_act.copy()
    plt.figure(figsize=(16, 6))

    # Plot the "Actual" as a green line with dot markers
    plt.plot(
        df.index, 
        df['Aktual'], 
        label='Actual output', 
        marker='.', 
        markersize=5, 
        color='#2ca02c', 
        zorder=-100
    )

    # Scatter plot for "Prediction" in orange X markers
    plt.plot(
        df.index, 
        df['Prediksi'], 
        marker='x', 
        markersize=5, 
        #edgecolors='k', 
        label='Prediction', 
        c='#ff7f0e', 
        #s=15
    )

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.xticks(rotation=30)
    plt.title(' Actual and Predictions Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# Running with seed: 20
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 334, 64)           1792
#
#  max_pooling1d (MaxPooling1D  (None, 167, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 165, 128)          24704
#
#  max_pooling1d_1 (MaxPooling  (None, 82, 128)          0
#  1D)
#
#  flatten (Flatten)           (None, 10496)             0
#
#  dense (Dense)               (None, 128)               1343616
#
#  dense_1 (Dense)             (None, 48)                6192
#
# =================================================================
# Total params: 1,376,304
# Trainable params: 1,376,304
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0336 - mse: 0.0336 - mae: 0.1351 - mape: 218.2169
# Epoch 1: val_mse improved from inf to 0.06861, saving model to TCN3_20.h5
# 3079/3079 [==============================] -
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0108 - mse: 0.0108 - mae: 0.0706 - mape: 137.9072 - val_loss: 0.0335 - val_mse: 0.0335 - val_mae: 0.1300 - val_mape: 292.6758 - lr: 0.0010
# Epoch 22/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0105 - mse: 0.0105 - mae: 0.0692 - mape: 140.0167
# Epoch 22: val_mse did not improve from 0.02759
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0692 - mape: 139.7791 - val_loss: 0.0355 - val_mse: 0.0355 - val_mae: 0.1271 - val_mape: 350.0103 - lr: 0.0010
# Epoch 23/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0114 - mse: 0.0114 - mae: 0.0701 - mape: 136.0565
# Epoch 23: val_mse improved from 0.02759 to 0.02600, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0114 - mse: 0.0114 - mae: 0.0700 - mape: 135.8485 - val_loss: 0.0260 - val_mse: 0.0260 - val_mae: 0.1143 - val_mape: 293.7618 - lr: 0.0010
# Epoch 24/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0099 - mse: 0.0099 - mae: 0.0673 - mape: 133.4647
# Epoch 24: val_mse did not improve from 0.02600
# 3079/3079 [==============================] - 14s 5ms/step - loss: 0.0098 - mse: 0.0098 - mae: 0.0672 - mape: 133.2650 - val_loss: 0.0288 - val_mse: 0.0288 - val_mae: 0.1168 - val_mape: 377.9562 - lr: 0.0010
# Epoch 25/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0102 - mse: 0.0102 - mae: 0.0689 - mape: 137.5322
# Epoch 25: val_mse did not improve from 0.02600
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0689 - mape: 137.2995 - val_loss: 0.0357 - val_mse: 0.0357 - val_mae: 0.1252 - val_mape: 403.5110 - lr: 0.0010
# Epoch 26/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0097 - mse: 0.0097 - mae: 0.0667 - mape: 132.6919
# Epoch 26: val_mse did not improve from 0.02600
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0666 - mape: 132.4649 - val_loss: 0.0281 - val_mse: 0.0281 - val_mae: 0.1131 - val_mape: 337.2305 - lr: 0.0010
# Epoch 27/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0101 - mse: 0.0101 - mae: 0.0676 - mape: 135.7528
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 27: val_mse did not improve from 0.02600
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0676 - mape: 135.5409 - val_loss: 0.0322 - val_mse: 0.0322 - val_mae: 0.1211 - val_mape: 350.8410 - lr: 0.0010
# Epoch 28/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0091 - mse: 0.0091 - mae: 0.0639 - mape: 127.8499
# Epoch 28: val_mse improved from 0.02600 to 0.02022, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0639 - mape: 127.6686 - val_loss: 0.0202 - val_mse: 0.0202 - val_mae: 0.0937 - val_mape: 225.2287 - lr: 5.0000e-04
# Epoch 29/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0082 - mse: 0.0082 - mae: 0.0612 - mape: 124.3989
# Epoch 29: val_mse improved from 0.02022 to 0.01909, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0611 - mape: 124.2178 - val_loss: 0.0191 - val_mse: 0.0191 - val_mae: 0.0919 - val_mape: 228.5762 - lr: 5.0000e-04
# Epoch 30/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0080 - mse: 0.0080 - mae: 0.0602 - mape: 121.0270
# 📦  Saved checkpoint: TCN3_20_epoch30.h5
#
# Epoch 30: val_mse improved from 0.01909 to 0.01623, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0601 - mape: 120.8533 - val_loss: 0.0162 - val_mse: 0.0162 - val_mae: 0.0848 - val_mape: 219.5547 - lr: 5.0000e-04
# Epoch 31/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0077 - mse: 0.0077 - mae: 0.0588 - mape: 118.6312
# Epoch 31: val_mse did not improve from 0.01623
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0588 - mape: 118.4457 - val_loss: 0.0183 - val_mse: 0.0183 - val_mae: 0.0892 - val_mape: 225.4102 - lr: 5.0000e-04
# Epoch 32/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0074 - mse: 0.0074 - mae: 0.0578 - mape: 118.3046
# Epoch 32: val_mse did not improve from 0.01623
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0577 - mape: 118.1189 - val_loss: 0.0163 - val_mse: 0.0163 - val_mae: 0.0853 - val_mape: 205.5270 - lr: 5.0000e-04
# Epoch 33/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0074 - mse: 0.0074 - mae: 0.0578 - mape: 118.4555
# Epoch 33: val_mse did not improve from 0.01623
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0578 - mape: 118.2530 - val_loss: 0.0175 - val_mse: 0.0175 - val_mae: 0.0873 - val_mape: 211.6497 - lr: 5.0000e-04
# Epoch 34/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0076 - mse: 0.0076 - mae: 0.0583 - mape: 119.3887
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 34: val_mse did not improve from 0.01623
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0583 - mape: 119.2003 - val_loss: 0.0193 - val_mse: 0.0193 - val_mae: 0.0894 - val_mape: 208.9046 - lr: 5.0000e-04
# Epoch 35/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0078 - mse: 0.0078 - mae: 0.0587 - mape: 120.6864
# Epoch 35: val_mse improved from 0.01623 to 0.01325, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0587 - mape: 120.5003 - val_loss: 0.0132 - val_mse: 0.0132 - val_mae: 0.0752 - val_mape: 152.8628 - lr: 2.5000e-04
# Epoch 36/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0067 - mse: 0.0067 - mae: 0.0546 - mape: 114.3930
# Epoch 36: val_mse improved from 0.01325 to 0.01286, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0546 - mape: 114.2200 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0746 - val_mape: 158.1721 - lr: 2.5000e-04
# Epoch 37/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0065 - mse: 0.0065 - mae: 0.0533 - mape: 111.7768
# Epoch 37: val_mse improved from 0.01286 to 0.01277, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0533 - mape: 111.6065 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0741 - val_mape: 163.3928 - lr: 2.5000e-04
# Epoch 38/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0524 - mape: 110.2394
# Epoch 38: val_mse improved from 0.01277 to 0.01277, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0524 - mape: 110.0686 - val_loss: 0.0128 - val_mse: 0.0128 - val_mae: 0.0742 - val_mape: 169.7174 - lr: 2.5000e-04
# Epoch 39/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0062 - mse: 0.0062 - mae: 0.0519 - mape: 109.4312
# Epoch 39: val_mse improved from 0.01277 to 0.01270, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0518 - mape: 109.2624 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0739 - val_mape: 169.2577 - lr: 2.5000e-04
# Epoch 40/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0061 - mse: 0.0061 - mae: 0.0514 - mape: 109.1902
# 📦  Saved checkpoint: TCN3_20_epoch40.h5
#
# Epoch 40: val_mse improved from 0.01270 to 0.01262, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0514 - mape: 109.0140 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0739 - val_mape: 166.6483 - lr: 2.5000e-04
# Epoch 41/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0510 - mape: 108.1527
# Epoch 41: val_mse improved from 0.01262 to 0.01248, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0510 - mape: 107.9807 - val_loss: 0.0125 - val_mse: 0.0125 - val_mae: 0.0732 - val_mape: 160.1691 - lr: 2.5000e-04
# Epoch 42/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0509 - mape: 108.3738
# Epoch 42: val_mse did not improve from 0.01248
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0509 - mape: 108.2006 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0740 - val_mape: 159.1542 - lr: 2.5000e-04
# Epoch 43/100
# 3079/3079 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0506 - mape: 106.8383
# Epoch 43: val_mse did not improve from 0.01248
# 3079/3079 [==============================] - 13s 4ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0506 - mape: 106.8383 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0740 - val_mape: 158.5390 - lr: 2.5000e-04
# Epoch 44/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0505 - mape: 106.9765
# Epoch 44: val_mse did not improve from 0.01248
# 3079/3079 [==============================] - 15s 5ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0505 - mape: 106.8019 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.0749 - val_mape: 162.0089 - lr: 2.5000e-04
# Epoch 45/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0509 - mape: 106.5209
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 45: val_mse did not improve from 0.01248
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0509 - mape: 106.3463 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.0764 - val_mape: 157.1244 - lr: 2.5000e-04
# Epoch 46/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0056 - mse: 0.0056 - mae: 0.0498 - mape: 104.3520
# Epoch 46: val_mse improved from 0.01248 to 0.01194, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0498 - mape: 104.1852 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0718 - val_mape: 136.8318 - lr: 1.2500e-04
# Epoch 47/100
# 3079/3079 [==============================] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0485 - mape: 102.4773
# Epoch 47: val_mse improved from 0.01194 to 0.01188, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 14s 5ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0485 - mape: 102.4773 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0717 - val_mape: 137.7477 - lr: 1.2500e-04
# Epoch 48/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0053 - mse: 0.0053 - mae: 0.0477 - mape: 101.8592
# Epoch 48: val_mse did not improve from 0.01188
# 3079/3079 [==============================] - 15s 5ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0477 - mape: 101.6969 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0719 - val_mape: 136.7066 - lr: 1.2500e-04
# Epoch 49/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0052 - mse: 0.0052 - mae: 0.0472 - mape: 100.5904
# Epoch 49: val_mse improved from 0.01188 to 0.01172, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0471 - mape: 100.4297 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0714 - val_mape: 136.0900 - lr: 1.2500e-04
# Epoch 50/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0469 - mape: 100.0207
# 📦  Saved checkpoint: TCN3_20_epoch50.h5
#
# Epoch 50: val_mse did not improve from 0.01172
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0468 - mape: 99.8608 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0716 - val_mape: 136.5560 - lr: 1.2500e-04
# Epoch 51/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0051 - mse: 0.0051 - mae: 0.0467 - mape: 99.6768
# Epoch 51: val_mse improved from 0.01172 to 0.01169, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0467 - mape: 99.5177 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0715 - val_mape: 134.5370 - lr: 1.2500e-04
# Epoch 52/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0464 - mape: 98.6996
# Epoch 52: val_mse improved from 0.01169 to 0.01159, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0464 - mape: 98.5408 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0711 - val_mape: 133.4481 - lr: 1.2500e-04
# Epoch 53/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0462 - mape: 98.3871
# Epoch 53: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0462 - mape: 98.2294 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0713 - val_mape: 132.3289 - lr: 1.2500e-04
# Epoch 54/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0460 - mape: 98.0493
# Epoch 54: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0460 - mape: 97.8904 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0719 - val_mape: 132.8460 - lr: 1.2500e-04
# Epoch 55/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0459 - mape: 97.5808
# Epoch 55: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0459 - mape: 97.4219 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0718 - val_mape: 131.5014 - lr: 1.2500e-04
# Epoch 56/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0457 - mape: 97.1338
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 56: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0457 - mape: 96.9753 - val_loss: 0.0119 - val_mse: 0.0119 - val_mae: 0.0722 - val_mape: 132.9003 - lr: 1.2500e-04
# Epoch 57/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0455 - mape: 96.2246
# Epoch 57: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0455 - mape: 96.0639 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0717 - val_mape: 126.3186 - lr: 6.2500e-05
# Epoch 58/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0450 - mape: 95.1305
# Epoch 58: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0450 - mape: 94.9722 - val_loss: 0.0117 - val_mse: 0.0117 - val_mae: 0.0718 - val_mape: 126.3263 - lr: 6.2500e-05
# Epoch 59/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0448 - mape: 94.8301
# Epoch 59: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 11s 4ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0448 - mape: 94.6724 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0716 - val_mape: 126.0027 - lr: 6.2500e-05
# Epoch 60/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0446 - mape: 94.2720
# 📦  Saved checkpoint: TCN3_20_epoch60.h5
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 60: val_mse did not improve from 0.01159
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0446 - mape: 94.1151 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0716 - val_mape: 126.4307 - lr: 6.2500e-05
# Epoch 61/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.
- val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0711 - val_mape: 127.5132 - lr: 3.9063e-06
# Epoch 78/100
# 3079/3079 [==============================] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0438 - mape: 88.2446
# Epoch 78: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 13s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0438 - mape: 88.2446 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0711 - val_mape: 127.5988 - lr: 3.9063e-06
# Epoch 79/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0438 - mape: 88.3386
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 79: val_mse improved from 0.01127 to 0.01127, saving model to TCN3_20.h5
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0438 - mape: 88.1984 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0711 - val_mape: 127.6706 - lr: 3.9063e-06
# Epoch 80/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0438 - mape: 88.5204
# 📦  Saved checkpoint: TCN3_20_epoch80.h5
#
# Epoch 80: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 10s 3ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0438 - mape: 88.3790 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0715 - val_mape: 129.0058 - lr: 1.9531e-06
# Epoch 81/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.1695
# Epoch 81: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 15s 5ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.0287 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0715 - val_mape: 129.2155 - lr: 1.9531e-06
# Epoch 82/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.1238
# Epoch 82: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 13s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 87.9832 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0715 - val_mape: 129.2869 - lr: 1.9531e-06
# Epoch 83/100
# 3079/3079 [==============================] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 87.9573
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 83: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 19s 6ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 87.9573 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0715 - val_mape: 129.3072 - lr: 1.9531e-06
# Epoch 84/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.2337
# Epoch 84: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 19s 6ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.0925 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0717 - val_mape: 129.7862 - lr: 1.0000e-06
# Epoch 85/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.0772
# Epoch 85: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 87.9362 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0717 - val_mape: 129.9900 - lr: 1.0000e-06
# Epoch 86/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 88.0277
# Epoch 86: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 12s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0437 - mape: 87.8868 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0717 - val_mape: 130.0735 - lr: 1.0000e-06
# Epoch 87/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0436 - mape: 87.9977
# Epoch 87: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 13s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0436 - mape: 87.8568 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0717 - val_mape: 130.1109 - lr: 1.0000e-06
# Epoch 88/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0436 - mape: 87.9794
# Epoch 88: val_mse did not improve from 0.01127
# 3079/3079 [==============================] - 11s 3ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0436 - mape: 87.8386 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0717 - val_mape: 130.1518 - lr: 1.0000e-06
# Epoch 89/100
# 3072/3079 [============================>.] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0436 - mape: 87.9708
# Epoch 89: val_mse did not improve from 0.01127
# Restoring model weights from the end of the best epoch: 79.
# 3079/3079 [==============================] - 13s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0436 - mape: 87.8300 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0717 - val_mape: 130.1776 - lr: 1.0000e-06
# Epoch 89: early stopping
# Final training and validation loss securely saved to loss_history_20.json
# Train time (s): 1043.3496840000153
# Train  Loss=0.00434  MSE=0.00434  MAE=0.04386  MAPE=90.013%
# 0.004336373880505562 0.004336373880505562 0.04385751858353615 90.01270294189453
# Loading best model from:  TCN3_20.h5
# 535/535 [==============================] - 1s 2ms/step - loss: 0.0113 - mse: 0.0113 - mae: 0.0711 - mape: 127.6706
# model.evaluate(x_val, y_val):  [0.011267478577792645, 0.011267478577792645, 0.07111087441444397, 127.67057037353516]
# 33/33 [==============================] - 0s 9ms/step
# 33/33 [==============================] - 0s 1ms/step
# before dropna
#                          Prediksi        Aktual
# Date
# 2022-01-08 00:30:00  11055.374023  21871.000000
# 2022-01-08 01:00:00  10604.923828  21730.000000
# 2022-01-08 01:30:00  10215.430664  21464.000000
# 2022-01-08 02:00:00   9906.648438  21225.000000
# 2022-01-08 02:30:00   9730.541016  21132.000000
# ...                           ...           ...
# 2024-10-30 22:00:00  26063.599609  29019.070312
# 2024-10-30 22:30:00  24893.966797  28465.740234
# 2024-10-30 23:00:00  23782.394531  27755.750000
# 2024-10-30 23:30:00  22765.031250  27277.500000
# 2024-10-31 00:00:00  21822.097656  26757.400391
#
# [49296 rows x 2 columns]
# after dropna
#                          Prediksi        Aktual
# Date
# 2022-01-08 00:30:00  11055.374023  21871.000000
# 2022-01-08 01:00:00  10604.923828  21730.000000
# 2022-01-08 01:30:00  10215.430664  21464.000000
# 2022-01-08 02:00:00   9906.648438  21225.000000
# 2022-01-08 02:30:00   9730.541016  21132.000000
# ...                           ...           ...
# 2024-10-30 22:00:00