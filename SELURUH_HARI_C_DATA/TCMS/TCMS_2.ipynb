rows x 9 columns]

# %%
data_validation['Suhu_PCA'], _, _ = scale_array(
    data_validation['Suhu_PCA'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_suhu,
    orig_max=max_suhu
)
data_validation['Holiday_Impact'], _, _ = scale_array(
    data_validation['Holiday_Impact'].values,
    new_min=-1,
    new_max=1,
    orig_min=min_holiday,
    orig_max=max_holiday
)
data_validation['Beban'], _, _ = scale_array(
    data_validation['Beban'].values, 
    new_min=-1, 
    new_max=1,
    orig_min=min_beban,
    orig_max=max_beban
)

# %%
data_validation.describe()
# Out:
#               Beban       Jam_sin       Jam_cos      Hari_sin      Hari_cos  \
# count  17472.000000  1.747200e+04  1.747200e+04  1.747200e+04  1.747200e+04
# mean       0.389521  5.458301e-11  2.265195e-09 -2.488985e-08  8.733282e-09
# std        0.317072  7.071270e-01  7.071270e-01  7.071270e-01  7.071270e-01
# min       -0.775485 -1.000000e+00 -1.000000e+00 -9.749279e-01 -9.009688e-01
# 25%        0.158794 -7.071068e-01 -7.071068e-01 -7.818315e-01 -9.009688e-01
# 50%        0.385354  6.123234e-17 -6.123234e-17  0.000000e+00 -2.225209e-01
# 75%        0.668933  7.071068e-01  7.071068e-01  7.818315e-01  6.234898e-01
# max        1.139628  1.000000e+00  1.000000e+00  9.749279e-01  1.000000e+00
#
#           Bulan_sin     Bulan_cos  Holiday_Impact      Suhu_PCA
# count  17472.000000  1.747200e+04    17472.000000  17472.000000
# mean      -0.000736 -4.758367e-03        0.927457     -0.054006
# std        0.706155  7.080817e-01        0.295316      0.311923
# min       -1.000000 -1.000000e+00       -1.000000     -0.847113
# 25%       -0.500000 -8.660254e-01        1.000000     -0.310480
# 50%        0.000000 -1.836970e-16        1.000000     -0.118824
# 75%        0.866025  5.000000e-01        1.000000      0.207680
# max        1.000000  1.000000e+00        1.000000      0.836694

# %% [markdown]
# # training model

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
periodic_indices = data_training.columns.get_indexer(['Jam_sin','Jam_cos', 'Hari_sin', 'Hari_cos', 'Bulan_sin', 'Bulan_cos'])
    
x_train, x_train_periodic, y_train = make_multi_input_windows(input_make_windows,
                                                         output_make_windows,
                                                         total_window_size=total_window_size, 
                                                         input_slice=input_slice,
                                                         labels_slice=labels_slice, 
                                                         periodic_indices=periodic_indices)

# %%
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()
x_val, x_val_periodic, y_val                   = make_multi_input_windows(input_make_windows_validation, 
                                                           output_make_windows_validation,
                                                           total_window_size=total_window_size,
                                                             input_slice=input_slice, 
                                                             labels_slice=labels_slice,
                                                             periodic_indices=periodic_indices)

# %%
x_train.shape, y_train.shape,  x_train_periodic.shape, x_val.shape, y_val.shape,  x_val_periodic.shape,
# Out:
# ((49489, 48, 9),
#  (49489, 48),
#  (49489, 48, 6),
#  (17377, 48, 9),
#  (17377, 48),
#  (17377, 48, 6))

# %%
x_train.dtype, y_train.dtype, x_train_periodic.dtype, x_val.dtype, y_val.dtype, x_val_periodic.dtype,
# Out:
# (dtype('float32'),
#  dtype('float32'),
#  dtype('float32'),
#  dtype('float32'),
#  dtype('float32'),
#  dtype('float32'))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, ReLU, BatchNormalization, Dropout, Add, Flatten, Dense, Concatenate
from tensorflow.keras.models import Model
import time
import json
from tensorflow.keras.callbacks import History, ModelCheckpoint, EarlyStopping

def build_model_tensor(input_lag, num_features, forecast_horizon, periodic_features):
    
# Branch 1: MS-CNN for History 
    input_history = Input(shape=(input_lag, num_features), name='historical_input')
    
    # Initial convolutions based on the architectural diagram
    x = Conv1D(filters=64, kernel_size=8, padding='same', dilation_rate=1)(input_history)
    x = Conv1D(filters=24, kernel_size=8, padding='same', dilation_rate=1)(x)

    # 8 Residual Blocks with multi-scale convolutions
    for block in range(8):
        for s in [1, 2, 4]:
            res = x 
            
            # The dilation rate 's' scales up within each block
            x = Conv1D(filters=24, kernel_size=8, padding='same', dilation_rate=s)(x)
            x = ReLU()(x)
            x = BatchNormalization()(x)
            x = Dropout(0.05)(x)
            
            x = Add()([res, x])
            
    cnn_out = Flatten()(x)

    # Branch 2: Fully Connected Subnetwork for Future Periodic Coding
    input_periodic = Input(shape=(forecast_horizon, periodic_features), name='periodic_input')
    x2 = Flatten()(input_periodic)
    
    # The paper shows multiple dense layers for the time cognition branch
    x2 = Dense(64, activation='relu')(x2)
    periodic_out = Dense(32, activation='relu')(x2)

    # Fusion Layer: Combine spatial features with future time cognition
    merged = Concatenate()([cnn_out, periodic_out])
    merged = Dense(128, activation='relu')(merged)
    
    # Output: Load forecast for the targeted horizon
    final_output = Dense(forecast_horizon, name='forecast_output')(merged)

    model = Model(inputs=[input_history, input_periodic], outputs=final_output)
    return model

# %%
def tensorflow_model(X_train_scaled, Y_train_scaled,
                     X_val_scaled,   Y_val_scaled,
                     learning_rate=1e-3,
                     target_MAE=0.001,
                     jumlah_epochs=50,
                     jumlah_sampel_batch=32, 
                     jumlah_epoch_terbelakang=10,
                     save_best_model_path="model.h5",
                     validation_data=False,
                     load_model=None, seed_value=-1):

    # Removing global variables for safer execution
    loss_history = {}

    # ---------- callbacks ----------
    class MAEStop(tf.keras.callbacks.Callback):
        def __init__(self, thr): super().__init__(); self.thr = thr
        def on_epoch_end(self, epoch, logs=None):
            if logs and logs.get('mae', 1e9) < self.thr:
                print(f"\nMAE < {self.thr}. Stop."); self.model.stop_training = True

    class SaveEveryNEpoch(tf.keras.callbacks.Callback):
        def __init__(self, n, root): super().__init__(); self.n, self.root = n, root
        def on_epoch_end(self, epoch, logs=None):
            if (epoch + 1) % self.n == 0:
                fname = f"{self.root}_epoch{epoch+1:02d}.h5"
                self.model.save(fname)
                print(f"\n📦  Saved checkpoint: {fname}")

    class LiveLossLogger(tf.keras.callbacks.Callback):
        def __init__(self, filename, use_validation):
            super().__init__()
            self.filename = filename
            self.use_validation = use_validation
            self.live_history = {'loss': []}
            if self.use_validation:
                self.live_history['val_loss'] = []

        def on_epoch_end(self, epoch, logs=None):
            logs = logs or {}
            
            current_loss = logs.get('loss')
            if current_loss is not None:
                self.live_history['loss'].append(float(current_loss))
            
            if self.use_validation:
                current_val_loss = logs.get('val_loss') 
                if current_val_loss is not None:
                    self.live_history['val_loss'].append(float(current_val_loss))
            
            with open(self.filename, 'w') as f:
                json.dump(self.live_history, f)

    history_cb = History()

    # ---------- model ----------
    # X_train_scaled is now a list [X_history, X_periodic]
    # We must extract the shapes from the specific array indices
    input_width  = X_train_scaled[0].shape[1]   
    num_features = X_train_scaled[0].shape[2]   
    periodic_feats = X_train_scaled[1].shape[2]
    forecast_horizon = Y_train_scaled.shape[1]
    
    if load_model is None:
        model = build_model_tensor(input_width, num_features, forecast_horizon, periodic_feats)
    else:
        model = tf.keras.models.load_model(load_model)

    model.summary()
    
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                  loss='mse',
                  metrics=['mse', 'mae',
                           tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]
                           ,  steps_per_execution=500)

    # ---------- build callback list ----------
    json_filename = f"loss_history_{save_best_model_path}.json"
    
    cb = [
        history_cb,
        MAEStop(target_MAE),
        SaveEveryNEpoch(10, root=save_best_model_path.rstrip('.h5')),
        LiveLossLogger(json_filename, validation_data)
    ]

    if validation_data:
        lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_mse',    
            factor=0.5,           
            patience=4,           
            min_lr=1e-6,          
            verbose=1             
        )
        
        cb += [
            lr_scheduler,
            ModelCheckpoint(save_best_model_path,
                            monitor='val_mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='val_mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]
    else:
        lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='mse',        
            factor=0.3,
            patience=8,
            min_lr=1e-6,
            verbose=1
        )
        
        cb += [
            lr_scheduler,
            ModelCheckpoint(save_best_model_path,
                            monitor='mse', mode='min',
                            save_best_only=True, verbose=1),
            EarlyStopping(monitor='mse', mode='min',
                          patience=jumlah_epoch_terbelakang,
                          restore_best_weights=True, verbose=1)
        ]

    # ---------- training with exception handling ----------
    start = time.time()
    
    # Prepare validation tuple safely
    val_tuple = (X_val_scaled, Y_val_scaled) if validation_data else None

    try:
        model.fit(X_train_scaled, Y_train_scaled,
                  epochs=jumlah_epochs,
                  batch_size=jumlah_sampel_batch,
                  shuffle=False,
                  validation_data=val_tuple,
                  callbacks=cb,
                  verbose=True)
    except Exception as e:
        print("Training stopped with error:", e)
    finally:
        try:
            with open(json_filename, 'r') as f:
                loss_history = json.load(f)
        except FileNotFoundError:
            loss_history = {}
        print(f"Final training and validation loss securely saved to {json_filename}")

    print("Train time (s):", time.time() - start)

    # ---------- evaluate ----------
    loss, mse, mae, mape = model.evaluate(X_train_scaled, Y_train_scaled, verbose=0)
    print(f"Train  Loss={loss:.5f}  MSE={mse:.5f}  MAE={mae:.5f}  MAPE={mape:.3f}%")
    return model, loss, mse, mae, mape, loss_history

# %%
seed_vektor= [20]
for seed_value in seed_vektor:
    print(f"Running with seed: {seed_value}")
    tf.random.set_seed(seed_value)
    save_best_model_path = "TCMS2_%s.h5"%seed_value
    model,     loss, MSE, MAE, MAPE, loss_history  = tensorflow_model(
        X_train_scaled=[x_train, x_train_periodic], Y_train_scaled=y_train, X_val_scaled=[x_val, x_val_periodic], Y_val_scaled=y_val, learning_rate=0.001, target_MAE=0.0001,  jumlah_epochs=100, jumlah_sampel_batch=64, 
                                                    jumlah_epoch_terbelakang=20,  save_best_model_path = save_best_model_path, 
                                                    validation_data=True, load_model=None, seed_value=seed_value)
    print(loss, MSE, MAE, MAPE)
# Out:
# Running with seed: 20
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  historical_input (InputLayer)  [(None, 48, 9)]      0           []
#
#  conv1d (Conv1D)                (None, 48, 64)       4672        ['historical_input[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 48, 24)       12312       ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 48, 24)       4632        ['conv1d_1[0][0]']
#
#  re_lu (ReLU)                   (None, 48, 24)       0           ['conv1d_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 24)      96          ['re_lu[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 48, 24)       0           ['batch_normalization[0][0]']
#
#  add (Add)                      (None, 48, 24)       0           ['conv1d_1[0][0]',
#                                                                   'dropout[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 48, 24)       4632        ['add[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 48, 24)       0           ['conv1d_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 24)      96          ['re_lu_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 48, 24)       0           ['batch_normalization_1[0][0]']
#
#  add_1 (Add)                    (None, 48, 24)       0           ['add[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 48, 24)       4632        ['add_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 48, 24)       0           ['conv1d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 24)      96          ['re_lu_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 48, 24)       0           ['batch_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 48, 24)       0           ['add_1[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 48, 24)       4632        ['add_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 48, 24)       0           ['conv1d_5[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 48, 24)      96          ['re_lu_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 48, 24)       0           ['batch_normalization_3[0][0]']
#
#  add_3 (Add)                    (None, 48, 24)       0           ['add_2[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 48, 24)       4632        ['add_3[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 48, 24)       0           ['conv1d_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 48, 24)      96          ['re_lu_4[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 48, 24)       0           ['batch_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 48, 24)       0           ['add_3[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 48, 24)       4632        ['add_4[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 48, 24)       0           ['conv1d_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 48, 24)      96          ['re_lu_5[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 48, 24)       0           ['batch_normalization_5[0][0]']
#
#  add_5 (Add)                    (None, 48, 24)       0           ['add_4[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 48, 24)       4632        ['add_5[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 48, 24)       0           ['conv1d_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 24)      96          ['re_lu_6[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 48, 24)       0           ['batch_normalization_6[0][0]']
#
#  add_6 (Add)                    (None, 48, 24)       0           ['add_5[0][0]',
#                                                                   'dropout_6[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 48, 24)       4632        ['add_6[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 48, 24)       0           ['conv1d_9[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 24)      96          ['re_lu_7[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 48, 24)       0           ['batch_normalization_7[0][0]']
#
#  add_7 (Add)                    (None, 48, 24)       0           ['add_6[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 48, 24)       4632        ['add_7[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 48, 24)       0           ['conv1d_10[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 48, 24)      96          ['re_lu_8[0][0]']
#  rmalization)
#
#  dropout_8 (Dropout)            (None, 48, 24)       0           ['batch_normalization_8[0][0]']
#
#  add_8 (Add)                    (None, 48, 24)       0           ['add_7[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 48, 24)       4632        ['add_8[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 48, 24)       0           ['conv1d_11[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 48, 24)      96          ['re_lu_9[0][0]']
#  rmalization)
#
#  dropout_9 (Dropout)            (None, 48, 24)       0           ['batch_normalization_9[0][0]']
#
#  add_9 (Add)                    (None, 48, 24)       0           ['add_8[0][0]',
#                                                                   'dropout_9[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 48, 24)       4632        ['add_9[0][0]']
#
#  re_lu_10 (ReLU)                (None, 48, 24)       0           ['conv1d_12[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 48, 24)      96          ['re_lu_10[0][0]']
#  ormalization)
#
#  dropout_10 (Dropout)           (None, 48, 24)       0           ['batch_normalization_10[0][0]']
#
#  add_10 (Add)                   (None, 48, 24)       0           ['add_9[0][0]',
#                                                                   'dropout_10[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 48, 24)       4632        ['add_10[0][0]']
#
#  re_lu_11 (ReLU)                (None, 48, 24)       0           ['conv1d_13[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 48, 24)      96          ['re_lu_11[0][0]']
#  ormalization)
#
#  dropout_11 (Dropout)           (None, 48, 24)       0           ['batch_normalization_11[0][0]']
#
#  add_11 (Add)                   (None, 48, 24)       0           ['add_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 48, 24)       4632        ['add_11[0][0]']
#
#  re_lu_12 (ReLU)                (None, 48, 24)       0           ['conv1d_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 48, 24)      96          ['re_lu_12[0][0]']
#  ormalization)
#
#  dropout_12 (Dropout)           (None, 48, 24)       0           ['batch_normalization_12[0][0]']
#
#  add_12 (Add)                   (None, 48, 24)       0           ['add_11[0][0]',
#                                                                   'dropout_12[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 48, 24)       4632        ['add_12[0][0]']
#
#  re_lu_13 (ReLU)                (None, 48, 24)       0           ['conv1d_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 48, 24)      96          ['re_lu_13[0][0]']
#  ormalization)
#
#  dropout_13 (Dropout)           (None, 48, 24)       0           ['batch_normalization_13[0][0]']
#
#  add_13 (Add)                   (None, 48, 24)       0           ['add_12[0][0]',
#                                                                   'dropout_13[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 48, 24)       4632        ['add_13[0][0]']
#
#  re_lu_14 (ReLU)                (None, 48, 24)       0           ['conv1d_16[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 48, 24)      96          ['re_lu_14[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 48, 24)       0           ['batch_normalization_14[0][0]']
#
#  add_14 (Add)                   (None, 48, 24)       0           ['add_13[0][0]',
#                                                                   'dropout_14[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 48, 24)       4632        ['add_14[0][0]']
#
#  re_lu_15 (ReLU)                (None, 48, 24)       0           ['conv1d_17[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 48, 24)      96          ['re_lu_15[0][0]']
#  ormalization)
#
#  dropout_15 (Dropout)           (None, 48, 24)       0           ['batch_normalization_15[0][0]']
#
#  add_15 (Add)                   (None, 48, 24)       0           ['add_14[0][0]',
#                                                                   'dropout_15[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 48, 24)       4632        ['add_15[0][0]']
#
#  re_lu_16 (ReLU)                (None, 48, 24)       0           ['conv1d_18[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 48, 24)      96          ['re_lu_16[0][0]']
#  ormalization)
#
#  dropout_16 (Dropout)           (None, 48, 24)       0           ['batch_normalization_16[0][0]']
#
#  add_16 (Add)                   (None, 48, 24)       0           ['add_15[0][0]',
#                                                                   'dropout_16[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 48, 24)       4632        ['add_16[0][0]']
#
#  re_lu_17 (ReLU)                (None, 48, 24)       0           ['conv1d_19[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 48, 24)      96          ['re_lu_17[0][0]']
#  ormalization)
#
#  dropout_17 (Dropout)           (None, 48, 24)       0           ['batch_normalization_17[0][0]']
#
#  add_17 (Add)                   (None, 48, 24)       0           ['add_16[0][0]',
#                                                                   'dropout_17[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 48, 24)       4632        ['add_17[0][0]']
#
#  re_lu_18 (ReLU)                (None, 48, 24)       0           ['conv1d_20[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 48, 24)      96          ['re_lu_18[0][0]']
#  ormalization)
#
#  dropout_18 (Dropout)           (None, 48, 24)       0           ['batch_normalization_18[0][0]']
#
#  add_18 (Add)                   (None, 48, 24)       0           ['add_17[0][0]',
#                                                                   'dropout_18[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 48, 24)       4632        ['add_18[0][0]']
#
#  re_lu_19 (ReLU)                (None, 48, 24)       0           ['conv1d_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 48, 24)      96          ['re_lu_19[0][0]']
#  ormalization)
#
#  dropout_19 (Dropout)           (None, 48, 24)       0           ['batch_normalization_19[0][0]']
#
#  add_19 (Add)                   (None, 48, 24)       0           ['add_18[0][0]',
#                                                                   'dropout_19[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 48, 24)       4632        ['add_19[0][0]']
#
#  re_lu_20 (ReLU)                (None, 48, 24)       0           ['conv1d_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 48, 24)      96          ['re_lu_20[0][0]']
#  ormalization)
#
#  dropout_20 (Dropout)           (None, 48, 24)       0           ['batch_normalization_20[0][0]']
#
#  add_20 (Add)                   (None, 48, 24)       0           ['add_19[0][0]',
#                                                                   'dropout_20[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 48, 24)       4632        ['add_20[0][0]']
#
#  re_lu_21 (ReLU)                (None, 48, 24)       0           ['conv1d_23[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 48, 24)      96          ['re_lu_21[0][0]']
#  ormalization)
#
#  dropout_21 (Dropout)           (None, 48, 24)       0           ['batch_normalization_21[0][0]']
#
#  add_21 (Add)                   (None, 48, 24)       0           ['add_20[0][0]',
#                                                                   'dropout_21[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 48, 24)       4632        ['add_21[0][0]']
#
#  re_lu_22 (ReLU)                (None, 48, 24)       0           ['conv1d_24[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 48, 24)      96          ['re_lu_22[0][0]']
#  ormalization)
#
#  dropout_22 (Dropout)           (None, 48, 24)       0           ['batch_normalization_22[0][0]']
#
#  add_22 (Add)                   (None, 48, 24)       0           ['add_21[0][0]',
#                                                                   'dropout_22[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 48, 24)       4632        ['add_22[0][0]']
#
#  re_lu_23 (ReLU)                (None, 48, 24)       0           ['conv1d_25[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 48, 24)      96          ['re_lu_23[0][0]']
#  ormalization)
#
#  periodic_input (InputLayer)    [(None, 48, 6)]      0           []
#
#  dropout_23 (Dropout)           (None, 48, 24)       0           ['batch_normalization_23[0][0]']
#
#  flatten_1 (Flatten)            (None, 288)          0           ['periodic_input[0][0]']
#
#  add_23 (Add)                   (None, 48, 24)       0           ['add_22[0][0]',
#                                                                   'dropout_23[0][0]']
#
#  dense (Dense)                  (None, 64)           18496       ['flatten_1[0][0]']
#
#  flatten (Flatten)              (None, 1152)         0           ['add_23[0][0]']
#
#  dense_1 (Dense)                (None, 32)           2080        ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 1184)         0           ['flatten[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          151680      ['concatenate[0][0]']
#
#  forecast_output (Dense)        (None, 48)           6192        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 308,904
# Trainable params: 307,752
# Non-trainable params: 1,152
# __________________________________________________________________________________________________
# Epoch 1/100
# 774/774 [==============================] - ETA: 0s - loss: 0.3109 - mse: 0.3109 - mae: 0.3001 - mape: 312.8493
# Epoch 1: val_mse improved from inf to 0.12471, saving model to TCMS2_20.h5
# 774/774 [==============================] - 23s 30ms/step - loss: 0.3109 - mse: 0.3109 - mae: 0.3001 - mape: 312.8493 - val_loss: 0.1247 - val_mse: 0.1247 - val_mae: 0.2897 - val_mape: 602.5420 - lr: 0.0010
# Epoch 2/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0965 - mse: 0.0965 - mae: 0.2576 - mape: 400.8778
# Epoch 2: val_mse improved from 0.12471 to 0.11347, saving model to TCMS2_20.h5
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0965 - mse: 0.0965 - mae: 0.2576 - mape: 400.8778 - val_loss: 0.1135 - val_mse: 0.1135 - val_mae: 0.2785 - val_mape: 676.9835 - lr: 0.0010
# Epoch 3/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0977 - mse: 0.0977 - mae: 0.2589 - mape: 416.9183
# Epoch 3: val_mse improved from 0.11347 to 0.11160, saving model to TCMS2_20.h5
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0977 - mse: 0.0977 - mae: 0.2589 - mape: 416.9183 - val_loss: 0.1116 - val_mse: 0.1116 - val_mae: 0.2767 - val_mape: 689.7638 - lr: 0.0010
# Epoch 4/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 417.0808
# Epoch 4: val_mse improved from 0.11160 to 0.11094, saving model to TCMS2_20.h5
# 774/774 [==============================] - 16s 20ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 417.0808 - val_loss: 0.1109 - val_mse: 0.1109 - val_mae: 0.2760 - val_mape: 694.3000 - lr: 0.0010
# Epoch 5/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.6701
# Epoch 5: val_mse improved from 0.11094 to 0.11067, saving model to TCMS2_20.h5
# 774/774 [==============================] - 15s 19ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.6701 - val_loss: 0.1107 - val_mse: 0.1107 - val_mae: 0.2758 - val_mape: 696.4058 - lr: 0.0010
# Epoch 6/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.4583
# Epoch 6: val_mse improved from 0.11067 to 0.11056, saving model to TCMS2_20.h5
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.4583 - val_loss: 0.1106 - val_mse: 0.1106 - val_mae: 0.2757 - val_mape: 697.4028 - lr: 0.0010
# Epoch 7/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.3501
# Epoch 7: val_mse improved from 0.11056 to 0.11052, saving model to TCMS2_20.h5
# 774/774 [==============================] - 17s 21ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.3501 - val_loss: 0.1105 - val_mse: 0.1105 - val_mae: 0.2756 - val_mape: 697.8739 - lr: 0.0010
# Epoch 8/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.3038
# Epoch 8: val_mse improved from 0.11052 to 0.11050, saving model to TCMS2_20.h5
# 774/774 [==============================] - 17s 22ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.3038 - val_loss: 0.1105 - val_mse: 0.1105 - val_mae: 0.2756 - val_mape: 698.1013 - lr: 0.0010
# Epoch 9/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.2833
# Epoch 9: val_mse did not improve from 0.11050
# 774/774 [==============================] - 16s 21ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.2833 - val_loss: 0.1106 - val_mse: 0.1106 - val_mae: 0.2756 - val_mape: 698.2277 - lr: 0.0010
# Epoch 10/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.2733
# 📦  Saved checkpoint: TCMS2_20_epoch10.h5
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_mse did not improve from 0.11050
# 774/774 [==============================] - 16s 20ms/step - loss: 0.0978 - mse: 0.0978 - mae: 0.2590 - mape: 416.2733 - val_loss: 0.1106 - val_mse: 0.1106 - val_mae: 0.2756 - val_mape: 698.2898 - lr: 0.0010
# Epoch 11/100
# 774/774 [==============================] - ETA: 0s - loss: 0.1018 - mse: 0.1018 - mae: 0.2630 - mape: 476.3270
# Epoch 11: val_mse did not improve from 0.11050
# 774/774 [==============================] - 15s 20ms/step - loss: 0.1018 - mse: 0.1018 - mae: 0.2630 - mape: 476.3270 - val_loss: 0.1198 - val_mse: 0.1198 - val_mae: 0.2847 - val_mape: 610.7832 - lr: 5.0000e-04
# Epoch 12/100
# 774/774 [==============================] - ETA: 0s - loss: 0.
100
# 774/774 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 451.9124
# Epoch 24: val_mse did not improve from 0.11050
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 451.9124 - val_loss: 0.1350 - val_mse: 0.1350 - val_mae: 0.3003 - val_mape: 505.9146 - lr: 6.2500e-05
# Epoch 25/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 449.4180
# Epoch 25: val_mse did not improve from 0.11050
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0988 - mse: 0.0988 - mae: 0.2602 - mape: 449.4180 - val_loss: 0.1354 - val_mse: 0.1354 - val_mae: 0.3007 - val_mape: 503.4964 - lr: 6.2500e-05
# Epoch 26/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 447.4040
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 26: val_mse did not improve from 0.11050
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 447.4040 - val_loss: 0.1357 - val_mse: 0.1357 - val_mae: 0.3011 - val_mape: 501.5428 - lr: 6.2500e-05
# Epoch 27/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 452.6528
# Epoch 27: val_mse did not improve from 0.11050
# 774/774 [==============================] - 15s 20ms/step - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 452.6528 - val_loss: 0.1360 - val_mse: 0.1360 - val_mae: 0.3013 - val_mape: 500.0265 - lr: 3.1250e-05
# Epoch 28/100
# 774/774 [==============================] - ETA: 0s - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 451.3242
# Epoch 28: val_mse did not improve from 0.11050
# Restoring model weights from the end of the best epoch: 8.
# 774/774 [==============================] - 15s 19ms/step - loss: 0.0987 - mse: 0.0987 - mae: 0.2601 - mape: 451.3242 - val_loss: 0.1362 - val_mse: 0.1362 - val_mae: 0.3016 - val_mape: 498.6621 - lr: 3.1250e-05
# Epoch 28: early stopping
# Final training and validation loss securely saved to loss_history_TCMS2_20.h5.json
# Train time (s): 436.1575753688812
# Train  Loss=0.11123  MSE=0.11123  MAE=0.27215  MAPE=643.075%
# 0.11123058199882507 0.11123058199882507 0.27214908599853516 643.0747680664062

# %%
save_best_model_path
model.load_weights(save_best_model_path)
print("Loading best model from: ", save_best_model_path)
print("model.evaluate(x_val, y_val): ", model.evaluate([x_val, x_val_periodic], y_val))
predictions = model.predict([x_train[slice(None, None, label_width), :, :], x_train_periodic[slice(None, None, label_width), :, :]] )
predictions_reshaped = predictions.reshape(-1,)
predictions_unscaled = inverse_scale_array(predictions_reshaped, orig_min=min_beban, orig_max=max_beban)
df_pred_act = compute_error([x_train, x_train_periodic], 
                            data_training_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
print(df_pred_act)
df= df_pred_act.copy()
plt.figure(figsize=(16, 6))

# Plot the "Actual" as a green line with dot markers
plt.plot(
    df.index, 
    df['Aktual'], 
    label='Actual output', 
    marker='.', 
    markersize=5, 
    color='#2ca02c', 
    zorder=-100
)

# Scatter plot for "Prediction" in orange X markers
plt.plot(
    df.index, 
    df['Prediksi'], 
    marker='x', 
    markersize=5, 
    #edgecolors='k', 
    label='Prediction', 
    c='#ff7f0e', 
    #s=15
)

plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=30)
plt.title(' Actual and Predictions Over Time')
plt.tight_layout()
plt.show()







df_pred_act = compute_error([x_val, x_val_periodic], data_validation_awal['Beban'], ['Beban'], model, input_width,label_width, min_beban, max_beban)
print(df_pred_act)

df= df_pred_act.copy()
plt.figure(figsize=(16, 6))

# Plot the "Actual" as a green line with dot markers
plt.plot(
    df.index, 
    df['Aktual'], 
    label='Actual output', 
    marker='.', 
    markersize=5, 
    color='#2ca02c', 
    zorder=-100
)

# Scatter plot for "Prediction" in orange X markers
plt.plot(
    df.index, 
    df['Prediksi'], 
    marker='x', 
    markersize=5, 
    #edgecolors='k', 
    label='Prediction', 
    c='#ff7f0e', 
    #s=15
)

plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=30)
plt.title(' Actual and Predictions Over Time')
plt.tight_layout()
plt.show()
# Out:
# Loading best model from:  TCMS2_20.h5
# 544/544 [==============================] - 2s 4ms/step - loss: 0.1105 - mse: 0.1105 - mae: 0.2756 - mape: 698.1010
# model.evaluate(x_val, y_val):  [0.11050020903348923, 0.11050020903348923, 0.27559444308280945, 698.1010131835938]
# 33/33 [==============================] - 1s 31ms/step
# 33/33 [==============================] - 0s 3ms/step
# before dropna
#                          Prediksi        Aktual
# Date
# 2022-01-03 00:00:00  19028.314453  19210.000000
# 2022-01-03 00:30:00  19031.335938  19023.000000
# 2022-01-03 01:00:00  19025.949219  18850.000000
# 2022-01-03 01:30:00  19039.101562  18607.000000
# 2022-01-03 02:00:00  19043.771484  18430.000000
# ...                           ...           ...
# 2024-10-30 21:30:00  19042.847656  29717.320312
# 2024-10-30 22:00:00  19042.205078  29019.070312
# 2024-10-30 22:30:00  19040.146484  28465.740234
# 2024-10-30 23:00:00  19038.556641  27755.750000
# 2024-10-30 23:30:00  19039.992188  27277.500000
#
# [49536 rows x 2 columns]
# after dropna
#                          Prediksi        Aktual
# Date
# 2022-01