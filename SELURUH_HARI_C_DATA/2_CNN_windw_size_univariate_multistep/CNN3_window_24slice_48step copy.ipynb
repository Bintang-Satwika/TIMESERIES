# %%
import pandas as pd
import os
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

from B_template import  scale_array, inverse_scale_array,  process_predictions, compute_metrics, compute_error, make_windows_autoregressive

# %%
import os

# Get the directory of the current file
current_path = os.getcwd()

# Go up two levels to reach TIMESERIES-MASTER
master_folder = os.path.abspath(os.path.join(current_path, "..", ".."))

print(f"Master folder path: {master_folder}")
# Out:
# Master folder path: d:\satwika_bintang\CODE\TIMESERIES-master

# %%
file_name = 'C_train_data.xlsx'
path_train_data = os.path.join(master_folder, file_name)

# 3. Read the excel file using the combined path
data_training_awal = pd.read_excel(path_train_data, index_col=0)
data_training= data_training_awal.astype('float32').copy()
data_training = data_training[['Beban']].copy()

# %%
# data_training['Suhu_PCA'], min_suhu, max_suhu = scale_array(
#     data_training['Suhu_PCA'].values, 
#     new_min=-1,
#     new_max=1)

# data_training['Holiday_Impact'], min_holiday, max_holiday = scale_array(
#     data_training['Holiday_Impact'].values, 
#     new_min=-1, 
#     new_max=1
# )

data_training['Beban'], min_beban, max_beban = scale_array(
    data_training['Beban'].values, 
    new_min=-1, 
    new_max=1)
# Out:
# Computed orig_min: 13475.0
# Computed orig_max: 32758.619140625

# %%
file_name = 'C_test_data.xlsx'
path_validation_data = os.path.join(master_folder, file_name)
data_validation_awal= pd.read_excel(path_validation_data, index_col=0)
data_validation= data_validation_awal.astype('float32').copy()
data_validation = data_validation[['Beban']].copy()

# %%
# data_validation['Suhu_PCA'], _, _ = scale_array(
#     data_validation['Suhu_PCA'].values,
#     new_min=-1,
#     new_max=1,
#     orig_min=min_suhu,
#     orig_max=max_suhu
# )
# data_validation['Holiday_Impact'], _, _ = scale_array(
#     data_validation['Holiday_Impact'].values,
#     new_min=-1,
#     new_max=1,
#     orig_min=min_holiday,
#     orig_max=max_holiday
# )
data_validation['Beban'], _, _ = scale_array(
    data_validation['Beban'].values, 
    new_min=-1, 
    new_max=1,
    orig_min=min_beban,
    orig_max=max_beban
)

# %%
data_training
# Out:
#                         Beban
# Date
# 2022-01-02 00:00:00 -0.538157
# 2022-01-02 00:30:00 -0.581925
# 2022-01-02 01:00:00 -0.604016
# 2022-01-02 01:30:00 -0.623204
# 2022-01-02 02:00:00 -0.647265
# ...                       ...
# 2024-10-30 21:30:00  0.684572
# 2024-10-30 22:00:00  0.612153
# 2024-10-30 22:30:00  0.554764
# 2024-10-30 23:00:00  0.481128
# 2024-10-30 23:30:00  0.431526
#
# [49584 rows x 1 columns]

# %%
data_validation
# Out:
#                         Beban
# Date
# 2024-10-31 00:00:00  0.377584
# 2024-10-31 00:30:00  0.346834
# 2024-10-31 01:00:00  0.318210
# 2024-10-31 01:30:00  0.296612
# 2024-10-31 02:00:00  0.272606
# ...                       ...
# 2025-10-29 21:30:00  0.610185
# 2025-10-29 22:00:00  0.537869
# 2025-10-29 22:30:00  0.481280
# 2025-10-29 23:00:00  0.411479
# 2025-10-29 23:30:00  0.365787
#
# [17472 rows x 1 columns]

# %%
input_make_windows      =   data_training.to_numpy()
output_make_windows     =   data_training['Beban'].to_numpy()
input_make_windows_validation   = data_validation.to_numpy()
output_make_windows_validation  = data_validation['Beban'].to_numpy()

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import time
from tensorflow.keras import layers, models, initializers
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense
def tensorflow_dense(X_train_scaled, Y_train_scaled, X_validation_scaled, Y_validation_scaled, 
                       learning_rate, target_MAE, jumlah_epochs, jumlah_sampel_batch,
                       jumlah_epoch_terbelakang, save_best_model_path, validation_data=False, load_model=None):
    global model

    class MAEStopCallback(tf.keras.callbacks.Callback):
        def __init__(self, threshold):
            super(MAEStopCallback, self).__init__()
            self.threshold = threshold

        def on_epoch_end(self, epoch, logs=None):
            # Print logs every 50 epochs (epoch is 0-indexed)
            if (epoch + 1) % 50 == 0:
                mae = logs.get('mae')
                val_mae = logs.get('val_mae', 'N/A')
                print(f"Epoch {epoch + 1}: MAE = {mae:.4f}, Val MAE = {val_mae}")

            # Your existing stop logic
            if logs['mae'] < self.threshold:
                print(f"\nMAE reached below {self.threshold}. Stopping training.")
                self.model.stop_training = True

    # Mendapatkan dimensi input
    input_width = X_train_scaled.shape[1]   #  timestep input
    num_features = X_train_scaled.shape[2]    # jumlah fitur 
    forecast_horizon = Y_train_scaled.shape[1]  # 1 timestep output

    model = tf.keras.models.Sequential()
    if load_model is None:
        model.add(Input(shape=(input_width, num_features)))
        model.add(layers.Conv1D(
            filters=96, 
            kernel_size=3, 
            activation='tanh', # Menggunakan tanh karena data -1 hingga 1
            padding='causal', 
            dilation_rate=1,
            kernel_initializer=initializers.GlorotUniform(seed=10), # Inisialisasi dengan seed=10
            bias_initializer=initializers.Zeros() # Bias dimulai dari nol untuk stabilitas
        ))
        model.add(layers.Conv1D(
            filters=96, 
            kernel_size=input_width, 
            activation='tanh', # Menggunakan tanh karena data -1 hingga 1
            dilation_rate=1,
            kernel_initializer=initializers.GlorotUniform(seed=11), # Inisialisasi dengan seed=10
            bias_initializer=initializers.Zeros() # Bias dimulai dari nol untuk stabilitas
        ))
        model.add(Flatten())
        model.add(layers.Dense(
            units=forecast_horizon,
            activation='linear',
            kernel_initializer=initializers.GlorotUniform(seed=10),
            bias_initializer=initializers.Zeros()
        ))



    else:
        model = tf.keras.models.load_model(load_model)
    
    model.summary()
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mse', 'mae', tf.keras.metrics.MeanAbsolutePercentageError(name='mape')])
    mae_stop_callback = MAEStopCallback(threshold=target_MAE)

    checkpoint_callback = ModelCheckpoint(
        save_best_model_path,
        monitor='val_mse',
        mode='min',
        save_best_only=True,
        verbose=False
    )

    early_stopping_callback = EarlyStopping(
        monitor='val_mse',
        mode='min',
        patience=jumlah_epoch_terbelakang,
        restore_best_weights=True,
        verbose=False
    )

    time_start = time.time()
    if validation_data:
        model.fit(X_train_scaled, Y_train_scaled, epochs=jumlah_epochs, batch_size=jumlah_sampel_batch,  
                  callbacks=[mae_stop_callback, checkpoint_callback, early_stopping_callback],
                  validation_data=(X_validation_scaled, Y_validation_scaled), validation_batch_size=jumlah_sampel_batch,
                  verbose=False)
    else:
        model.fit(X_train_scaled, Y_train_scaled, epochs=jumlah_epochs, batch_size=jumlah_sampel_batch, 
                  callbacks=[mae_stop_callback, checkpoint_callback, early_stopping_callback],
                  verbose=False)
    
    print("Time computation seconds: ", time.time() - time_start)
    
    loss, MSE, MAE, MAPE = model.evaluate(X_train_scaled, Y_train_scaled)
    print("Loss:", loss, "MSE:", MSE, "MAE:", MAE, "MAPE:", MAPE)
    
    return model, loss, MSE, MAE,  MAPE

# %%
import json
import tensorflow as tf

# Ambil daftar GPU yang terdeteksi
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    try:
        # Atur agar TensorFlow hanya mengambil memori sesuai kebutuhan
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU Memory Growth Berhasil Diaktifkan")
    except RuntimeError as e:
        # Pengaturan ini harus dilakukan sebelum GPU digunakan
        print(f"Error: {e}")
        
models = []
metric_dict={"MSE_train":[], "MAE_train": [],  "MAPE_train": [], "MSE_val":[], "MAE_val": [],  "MAPE_val": []}
start_step=24
step_slice=24
end_step=672
loss_val_before=1000000
for step in range(start_step,1+end_step, step_slice):
    model=None
    print("step: ", step)
    input_width = step
    label_width = 48
    shift = label_width
    total_window_size = input_width + shift
    OUT_STEPS = label_width
    # Definisikan irisan untuk input dan label
    input_slice = slice(0, input_width)
    label_start = total_window_size - label_width
    labels_slice = slice(label_start, None)
    x_train,    y_train     =  make_windows_autoregressive(input_make_windows, output_make_windows, input_width, label_width)
    x_val,  y_val                   = make_windows_autoregressive(input_make_windows_validation, output_make_windows_validation, input_width, label_width)
    print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
    save_weight_path="DATA_3\\CNN%s.h5"%step
    model, loss, MSE, MAE, MAPE= tensorflow_dense(x_train, y_train, x_val, y_val, learning_rate=0.0001, target_MAE=0.0001,  jumlah_epochs=200, jumlah_sampel_batch=24, 
                                                    jumlah_epoch_terbelakang=20,  save_best_model_path = save_weight_path, 
                                                    validation_data=True, load_model=None)
  
    model.load_weights(save_weight_path)
    loss_val, MSE_val, MAE_val, MAPE_val = model.evaluate(x_val, y_val)
    print("Loss_val:", loss_val, "MSE_val:", MSE_val, "MAE_val:", MAE_val, "MAPE_val:", MAPE_val)
    metric_dict["MSE_train"].append(MSE)
    metric_dict["MAE_train"].append(MAE)
    metric_dict["MAPE_train"].append(MAPE)
    metric_dict["MSE_val"].append(MSE_val)
    metric_dict["MAE_val"].append(MAE_val)
    metric_dict["MAPE_val"].append(MAPE_val)

    # Simpan json dictinary ke file
    json_file_path = f"DATA_3\\CNN_metrics_eval{step}.json"
    with open(json_file_path, 'w+') as json_file:
        json.dump(metric_dict, json_file)
    if loss_val< loss_val_before:
        loss_val_before=loss_val
        model.save("DATA_3\\CNN_best_model.h5")
        print("Model saved as best_model.h5")
    print()
# Out:
# GPU Memory Growth Berhasil Diaktifkan
# step:  24
# (49513, 24, 1) (49513, 48) (17401, 24, 1) (17401, 48)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 24, 96)            384
#
#  conv1d_1 (Conv1D)           (None, 1, 96)             221280
#
#  flatten (Flatten)           (None, 96)                0
#
#  dense (Dense)               (None, 48)                4656
#
# =================================================================
# Total params: 226,320
# Trainable params: 226,320
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0827, Val MAE = 0.10044901818037033
# Epoch 100: MAE = 0.0718, Val MAE = 0.08797711133956909
# Epoch 150: MAE = 0.0679, Val MAE = 0.08788787573575974
# Epoch 200: MAE = 0.0654, Val MAE = 0.08512187004089355
# Time computation seconds:  1171.5733501911163
# 1548/1548 [==============================] - 3s 2ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0663 - mape: 138.1303
# Loss: 0.009884621016681194 MSE: 0.009884621016681194 MAE: 0.06626971811056137 MAPE: 138.13031005859375
# 544/544 [==============================] - 1s 2ms/step - loss: 0.0157 - mse: 0.0157 - mae: 0.0831 - mape: 163.0997
# Loss_val: 0.015695225447416306 MSE_val: 0.015695225447416306 MAE_val: 0.08313054591417313 MAPE_val: 163.0997314453125
# Model saved as best_model.h5
#
# step:  48
# (49489, 48, 1) (49489, 48) (17377, 48, 1) (17377, 48)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 48, 96)            384
#
#  conv1d_3 (Conv1D)           (None, 1, 96)             442464
#
#  flatten_1 (Flatten)         (None, 96)                0
#
#  dense_1 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 447,504
# Trainable params: 447,504
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0628, Val MAE = 0.0765000507235527
# Epoch 100: MAE = 0.0558, Val MAE = 0.06996909528970718
# Time computation seconds:  710.3531491756439
# 1547/1547 [==============================] - 3s 2ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0556 - mape: 111.1818
# Loss: 0.00754544185474515 MSE: 0.00754544185474515 MAE: 0.05557955801486969 MAPE: 111.18177795410156
# 544/544 [==============================] - 1s 2ms/step - loss: 0.0115 - mse: 0.0115 - mae: 0.0695 - mape: 130.8473
# Loss_val: 0.011480767279863358 MSE_val: 0.011480767279863358 MAE_val: 0.0694781169295311 MAPE_val: 130.8473358154297
# Model saved as best_model.h5
#
# step:  72
# (49465, 72, 1) (49465, 48) (17353, 72, 1) (17353, 48)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 72, 96)            384
#
#  conv1d_5 (Conv1D)           (None, 1, 96)             663648
#
#  flatten_2 (Flatten)         (None, 96)                0
#
#  dense_2 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 668,688
# Trainable params: 668,688
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0588, Val MAE = 0.07176414132118225
# Epoch 100: MAE = 0.0528, Val MAE = 0.0673397034406662
# Time computation seconds:  675.5815551280975
# 1546/1546 [==============================] - 3s 2ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0535 - mape: 108.8387
# Loss: 0.006761798169463873 MSE: 0.006761798169463873 MAE: 0.05348309502005577 MAPE: 108.83867645263672
# 543/543 [==============================] - 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0668 - mape: 119.4137
# Loss_val: 0.010548054240643978 MSE_val: 0.010548054240643978 MAE_val: 0.0668221041560173 MAPE_val: 119.41368103027344
# Model saved as best_model.h5
#
# step:  96
# (49441, 96, 1) (49441, 48) (17329, 96, 1) (17329, 48)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 96, 96)            384
#
#  conv1d_7 (Conv1D)           (None, 1, 96)             884832
#
#  flatten_3 (Flatten)         (None, 96)                0
#
#  dense_3 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 889,872
# Trainable params: 889,872
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0584, Val MAE = 0.07107015699148178
# Epoch 100: MAE = 0.0516, Val MAE = 0.06891904026269913
# Epoch 150: MAE = 0.0493, Val MAE = 0.06615781784057617
# Time computation seconds:  869.5274760723114
# 1546/1546 [==============================] - 3s 2ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0516 - mape: 101.3728
# Loss: 0.006325182504951954 MSE: 0.006325182504951954 MAE: 0.051648132503032684 MAPE: 101.37281799316406
# 542/542 [==============================] - 1s 2ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0651 - mape: 125.1458
# Loss_val: 0.01027626171708107 MSE_val: 0.01027626171708107 MAE_val: 0.06510335952043533 MAPE_val: 125.14583587646484
# Model saved as best_model.h5
#
# step:  120
# (49417, 120, 1) (49417, 48) (17305, 120, 1) (17305, 48)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 120, 96)           384
#
#  conv1d_9 (Conv1D)           (None, 1, 96)             1106016
#
#  flatten_4 (Flatten)         (None, 96)                0
#
#  dense_4 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 1,111,056
# Trainable params: 1,111,056
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0580, Val MAE = 0.06963573396205902
# Epoch 100: MAE = 0.0523, Val MAE = 0.06683160364627838
# Epoch 150: MAE = 0.0496, Val MAE = 0.06662961840629578
# Epoch 200: MAE = 0.0483, Val MAE = 0.06658504158258438
# Time computation seconds:  1168.0105328559875
# 1545/1545 [==============================] - 3s 2ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0480 - mape: 99.2731
# Loss: 0.005625799298286438 MSE: 0.005625799298286438 MAE: 0.04803816229104996 MAPE: 99.27311706542969
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0654 - mape: 143.7020
# Loss_val: 0.010449531488120556 MSE_val: 0.010449531488120556 MAE_val: 0.06540337949991226 MAPE_val: 143.7019500732422
#
# step:  144
# (49393, 144, 1) (49393, 48) (17281, 144, 1) (17281, 48)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 144, 96)           384
#
#  conv1d_11 (Conv1D)          (None, 1, 96)             1327200
#
#  flatten_5 (Flatten)         (None, 96)                0
#
#  dense_5 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 1,332,240
# Trainable params: 1,332,240
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0562, Val MAE = 0.06959878653287888
# Epoch 100: MAE = 0.0504, Val MAE = 0.06659215688705444
# Time computation seconds:  755.1551110744476
# 1544/1544 [==============================] - 3s 2ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0495 - mape: 101.1595
# Loss: 0.006007372867316008 MSE: 0.006007372867316008 MAE: 0.049492690712213516 MAPE: 101.15953826904297
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0653 - mape: 136.8094
# Loss_val: 0.01052104402333498 MSE_val: 0.01052104402333498 MAE_val: 0.06529562920331955 MAPE_val: 136.8093719482422
#
# step:  168
# (49369, 168, 1) (49369, 48) (17257, 168, 1) (17257, 48)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 168, 96)           384
#
#  conv1d_13 (Conv1D)          (None, 1, 96)             1548384
#
#  flatten_6 (Flatten)         (None, 96)                0
#
#  dense_6 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 1,553,424
# Trainable params: 1,553,424
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0557, Val MAE = 0.06881698220968246
# Epoch 100: MAE = 0.0496, Val MAE = 0.0653158649802208
# Epoch 150: MAE = 0.0473, Val MAE = 0.06461645662784576
# Epoch 200: MAE = 0.0461, Val MAE = 0.06374762952327728
# Time computation seconds:  1162.0299808979034
# 1543/1543 [==============================] - 3s 2ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0461 - mape: 94.8769
# Loss: 0.005103788338601589 MSE: 0.005103788338601589 MAE: 0.0460686981678009 MAPE: 94.87688446044922
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0638 - mape: 142.5986
# Loss_val: 0.010048477910459042 MSE_val: 0.010048477910459042 MAE_val: 0.06377995014190674 MAPE_val: 142.59864807128906
# Model saved as best_model.h5
#
# step:  192
# (49345, 192, 1) (49345, 48) (17233, 192, 1) (17233, 48)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_14 (Conv1D)          (None, 192, 96)           384
#
#  conv1d_15 (Conv1D)          (None, 1, 96)             1769568
#
#  flatten_7 (Flatten)         (None, 96)                0
#
#  dense_7 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 1,774,608
# Trainable params: 1,774,608
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0536, Val MAE = 0.069767065346241
# Epoch 100: MAE = 0.0494, Val MAE = 0.06556688994169235
# Time computation seconds:  744.6873302459717
# 1543/1543 [==============================] - 3s 2ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0475 - mape: 98.2444
# Loss: 0.00574133824557066 MSE: 0.00574133824557066 MAE: 0.04754010960459709 MAPE: 98.24436950683594
# 539/539 [==============================] - 1s 2ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0635 - mape: 142.7868
# Loss_val: 0.010133989155292511 MSE_val: 0.010133989155292511 MAE_val: 0.06345272809267044 MAPE_val: 142.78683471679688
#
# step:  216
# (49321, 216, 1) (49321, 48) (17209, 216, 1) (17209, 48)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_16 (Conv1D)          (None, 216, 96)           384
#
#  conv1d_17 (Conv1D)          (None, 1, 96)             1990752
#
#  flatten_8 (Flatten)         (None, 96)                0
#
#  dense_8 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 1,995,792
# Trainable params: 1,995,792
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0516, Val MAE = 0.06755699962377548
# Epoch 100: MAE = 0.0472, Val MAE = 0.06345048546791077
# Time computation seconds:  731.8830926418304
# 1542/1542 [==============================] - 3s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0456 - mape: 93.7328
# Loss: 0.005364380776882172 MSE: 0.005364380776882172 MAE: 0.04561663046479225 MAPE: 93.73278045654297
# 538/538 [==============================] - 1s 2ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0614 - mape: 119.8378
# Loss_val: 0.009852534160017967 MSE_val: 0.009852534160017967 MAE_val: 0.06140324845910072 MAPE_val: 119.8377685546875
# Model saved as best_model.h5
#
# step:  240
# (49297, 240, 1) (49297, 48) (17185, 240, 1) (17185, 48)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 240, 96)           384
#
#  conv1d_19 (Conv1D)          (None, 1, 96)             2211936
#
#  flatten_9 (Flatten)         (None, 96)                0
#
#  dense_9 (Dense)             (None, 48)                4656
#
# =================================================================
# Total params: 2,216,976
# Trainable params: 2,216,976
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0510, Val MAE = 0.06534302234649658
# Epoch 100: MAE = 0.0468, Val MAE = 0.06424368172883987
# Time computation seconds:  594.4799091815948
# 1541/1541 [==============================] - 3s 2ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0465 - mape: 96.5189
# Loss: 0.005575606599450111 MSE: 0.005575606599450111 MAE: 0.04650646820664406 MAPE: 96.5188980102539
# 538/538 [==============================] - 1s 2ms/step - loss: 0.0098 - mse: 0.0098 - mae: 0.0610 - mape: 119.2353
# Loss_val: 0.009821020998060703 MSE_val: 0.009821020998060703 MAE_val: 0.060970280319452286 MAPE_val: 119.23532104492188
# Model saved as best_model.h5
#
# step:  264
# (49273, 264, 1) (49273, 48) (17161, 264, 1) (17161, 48)
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 264, 96)           384
#
#  conv1d_21 (Conv1D)          (None, 1, 96)             2433120
#
#  flatten_10 (Flatten)        (None, 96)                0
#
#  dense_10 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 2,438,160
# Trainable params: 2,438,160
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0494, Val MAE = 0.06346800178289413
# Epoch 100: MAE = 0.0452, Val MAE = 0.060888394713401794
# Time computation seconds:  746.547039270401
# 1540/1540 [==============================] - 3s 2ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0432 - mape: 89.2670
# Loss: 0.004971276968717575 MSE: 0.004971276968717575 MAE: 0.04317639395594597 MAPE: 89.26703643798828
# 537/537 [==============================] - 1s 2ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0585 - mape: 107.7762
# Loss_val: 0.009427936747670174 MSE_val: 0.009427936747670174 MAE_val: 0.05853230133652687 MAPE_val: 107.77616882324219
# Model saved as best_model.h5
#
# step:  288
# (49249, 288, 1) (49249, 48) (17137, 288, 1) (17137, 48)
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_22 (Conv1D)          (None, 288, 96)           384
#
#  conv1d_23 (Conv1D)          (None, 1, 96)             2654304
#
#  flatten_11 (Flatten)        (None, 96)                0
#
#  dense_11 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 2,659,344
# Trainable params: 2,659,344
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0481, Val MAE = 0.06210079416632652
# Epoch 100: MAE = 0.0450, Val MAE = 0.06050620973110199
# Time computation seconds:  783.816734790802
# 1540/1540 [==============================] - 3s 2ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0429 - mape: 88.2769
# Loss: 0.004902818705886602 MSE: 0.004902818705886602 MAE: 0.04286811128258705 MAPE: 88.2768783569336
# 536/536 [==============================] - 1s 2ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0584 - mape: 126.2583
# Loss_val: 0.009093085303902626 MSE_val: 0.009093085303902626 MAE_val: 0.05843326449394226 MAPE_val: 126.25828552246094
# Model saved as best_model.h5
#
# step:  312
# (49225, 312, 1) (49225, 48) (17113, 312, 1) (17113, 48)
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_24 (Conv1D)          (None, 312, 96)           384
#
#  conv1d_25 (Conv1D)          (None, 1, 96)             2875488
#
#  flatten_12 (Flatten)        (None, 96)                0
#
#  dense_12 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 2,880,528
# Trainable params: 2,880,528
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0475, Val MAE = 0.060115233063697815
# Epoch 100: MAE = 0.0445, Val MAE = 0.05828696861863136
# Time computation seconds:  656.1198740005493
# 1539/1539 [==============================] - 3s 2ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0445 - mape: 90.2892
# Loss: 0.005192606709897518 MSE: 0.005192606709897518 MAE: 0.04451024904847145 MAPE: 90.2891616821289
# 535/535 [==============================] - 1s 2ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0582 - mape: 116.7840
# Loss_val: 0.008840692229568958 MSE_val: 0.008840692229568958 MAE_val: 0.05821789801120758 MAPE_val: 116.78398895263672
# Model saved as best_model.h5
#
# step:  336
# (49201, 336, 1) (49201, 48) (17089, 336, 1) (17089, 48)
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_26 (Conv1D)          (None, 336, 96)           384
#
#  conv1d_27 (Conv1D)          (None, 1, 96)             3096672
#
#  flatten_13 (Flatten)        (None, 96)                0
#
#  dense_13 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 3,101,712
# Trainable params: 3,101,712
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0463, Val MAE = 0.057670146226882935
# Time computation seconds:  400.9371383190155
# 1538/1538 [==============================] - 3s 2ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0453 - mape: 94.7368
# Loss: 0.005985202267765999 MSE: 0.005985202267765999 MAE: 0.04529585316777229 MAPE: 94.73678588867188
# 535/535 [==============================] - 1s 2ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0570 - mape: 106.9090
# Loss_val: 0.008856984786689281 MSE_val: 0.008856984786689281 MAE_val: 0.056971728801727295 MAPE_val: 106.90898132324219
#
# step:  360
# (49177, 360, 1) (49177, 48) (17065, 360, 1) (17065, 48)
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_28 (Conv1D)          (None, 360, 96)           384
#
#  conv1d_29 (Conv1D)          (None, 1, 96)             3317856
#
#  flatten_14 (Flatten)        (None, 96)                0
#
#  dense_14 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 3,322,896
# Trainable params: 3,322,896
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0468, Val MAE = 0.0625985786318779
# Time computation seconds:  450.2133684158325
# 1537/1537 [==============================] - 3s 2ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0453 - mape: 93.9264
# Loss: 0.0057035209611058235 MSE: 0.0057035209611058235 MAE: 0.04529218748211861 MAPE: 93.9263687133789
# 534/534 [==============================] - 1s 2ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0577 - mape: 105.6807
# Loss_val: 0.008957142941653728 MSE_val: 0.008957142941653728 MAE_val: 0.057733193039894104 MAPE_val: 105.68072509765625
#
# step:  384
# (49153, 384, 1) (49153, 48) (17041, 384, 1) (17041, 48)
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_30 (Conv1D)          (None, 384, 96)           384
#
#  conv1d_31 (Conv1D)          (None, 1, 96)             3539040
#
#  flatten_15 (Flatten)        (None, 96)                0
#
#  dense_15 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 3,544,080
# Trainable params: 3,544,080
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0464, Val MAE = 0.05903016775846481
# Time computation seconds:  567.801274061203
# 1537/1537 [==============================] - 3s 2ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0432 - mape: 89.7388
# Loss: 0.005298611707985401 MSE: 0.005298611707985401 MAE: 0.04316648468375206 MAPE: 89.73878479003906
# 533/533 [==============================] - 1s 2ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0574 - mape: 117.2901
# Loss_val: 0.00871006865054369 MSE_val: 0.00871006865054369 MAE_val: 0.05741129070520401 MAPE_val: 117.29009246826172
# Model saved as best_model.h5
#
# step:  408
# (49129, 408, 1) (49129, 48) (17017, 408, 1) (17017, 48)
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_32 (Conv1D)          (None, 408, 96)           384
#
#  conv1d_33 (Conv1D)          (None, 1, 96)             3760224
#
#  flatten_16 (Flatten)        (None, 96)                0
#
#  dense_16 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 3,765,264
# Trainable params: 3,765,264
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0463, Val MAE = 0.05909531190991402
# Epoch 100: MAE = 0.0432, Val MAE = 0.058945707976818085
# Time computation seconds:  584.97305727005
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0423 - mape: 89.1892
# Loss: 0.005107197444885969 MSE: 0.005107197444885969 MAE: 0.0423198863863945 MAPE: 89.18923950195312
# 532/532 [==============================] - 1s 2ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0575 - mape: 127.6230
# Loss_val: 0.008920030668377876 MSE_val: 0.008920030668377876 MAE_val: 0.057509809732437134 MAPE_val: 127.62303924560547
#
# step:  432
# (49105, 432, 1) (49105, 48) (16993, 432, 1) (16993, 48)
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_34 (Conv1D)          (None, 432, 96)           384
#
#  conv1d_35 (Conv1D)          (None, 1, 96)             3981408
#
#  flatten_17 (Flatten)        (None, 96)                0
#
#  dense_17 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 3,986,448
# Trainable params: 3,986,448
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0459, Val MAE = 0.06250421702861786
# Epoch 100: MAE = 0.0429, Val MAE = 0.05915617197751999
# Time computation seconds:  672.3918852806091
# 1535/1535 [==============================] - 3s 2ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0419 - mape: 88.8972
# Loss: 0.004807188641279936 MSE: 0.004807188641279936 MAE: 0.041924893856048584 MAPE: 88.89720916748047
# 532/532 [==============================] - 1s 2ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0582 - mape: 122.0791
# Loss_val: 0.009085048921406269 MSE_val: 0.009085048921406269 MAE_val: 0.05821064114570618 MAPE_val: 122.0790786743164
#
# step:  456
# (49081, 456, 1) (49081, 48) (16969, 456, 1) (16969, 48)
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_36 (Conv1D)          (None, 456, 96)           384
#
#  conv1d_37 (Conv1D)          (None, 1, 96)             4202592
#
#  flatten_18 (Flatten)        (None, 96)                0
#
#  dense_18 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 4,207,632
# Trainable params: 4,207,632
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0462, Val MAE = 0.059054184705019
# Time computation seconds:  397.68825602531433
# 1534/1534 [==============================] - 3s 2ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0445 - mape: 95.3443
# Loss: 0.005769962910562754 MSE: 0.005769962910562754 MAE: 0.044515013694763184 MAPE: 95.3442611694336
# 531/531 [==============================] - 1s 2ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0574 - mape: 113.9777
# Loss_val: 0.009060551412403584 MSE_val: 0.009060551412403584 MAE_val: 0.05735380947589874 MAPE_val: 113.97770690917969
#
# step:  480
# (49057, 480, 1) (49057, 48) (16945, 480, 1) (16945, 48)
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_38 (Conv1D)          (None, 480, 96)           384
#
#  conv1d_39 (Conv1D)          (None, 1, 96)             4423776
#
#  flatten_19 (Flatten)        (None, 96)                0
#
#  dense_19 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 4,428,816
# Trainable params: 4,428,816
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0466, Val MAE = 0.05865052342414856
# Time computation seconds:  377.5099813938141
# 1534/1534 [==============================] - 3s 2ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0451 - mape: 93.2316
# Loss: 0.005815786775201559 MSE: 0.005815786775201559 MAE: 0.04509392008185387 MAPE: 93.23162841796875
# 530/530 [==============================] - 1s 2ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0586 - mape: 116.7836
# Loss_val: 0.009130274876952171 MSE_val: 0.009130274876952171 MAE_val: 0.058627206832170486 MAPE_val: 116.78358459472656
#
# step:  504
# (49033, 504, 1) (49033, 48) (16921, 504, 1) (16921, 48)
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_40 (Conv1D)          (None, 504, 96)           384
#
#  conv1d_41 (Conv1D)          (None, 1, 96)             4644960
#
#  flatten_20 (Flatten)        (None, 96)                0
#
#  dense_20 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 4,650,000
# Trainable params: 4,650,000
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0460, Val MAE = 0.06296117603778839
# Time computation seconds:  430.8809857368469
# 1533/1533 [==============================] - 3s 2ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0455 - mape: 92.8968
# Loss: 0.005685558542609215 MSE: 0.005685558542609215 MAE: 0.04554213583469391 MAPE: 92.89677429199219
# 529/529 [==============================] - 1s 2ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0593 - mape: 122.3670
# Loss_val: 0.009236885234713554 MSE_val: 0.009236885234713554 MAE_val: 0.05930997058749199 MAPE_val: 122.36701965332031
#
# step:  528
# (49009, 528, 1) (49009, 48) (16897, 528, 1) (16897, 48)
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_42 (Conv1D)          (None, 528, 96)           384
#
#  conv1d_43 (Conv1D)          (None, 1, 96)             4866144
#
#  flatten_21 (Flatten)        (None, 96)                0
#
#  dense_21 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 4,871,184
# Trainable params: 4,871,184
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0461, Val MAE = 0.0589771531522274
# Time computation seconds:  442.730441570282
# 1532/1532 [==============================] - 3s 2ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0457 - mape: 95.2671
# Loss: 0.00577960442751646 MSE: 0.00577960442751646 MAE: 0.045702796429395676 MAPE: 95.26707458496094
# 529/529 [==============================] - 1s 2ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0590 - mape: 115.7528
# Loss_val: 0.009385230019688606 MSE_val: 0.009385230019688606 MAE_val: 0.058977097272872925 MAPE_val: 115.7528305053711
#
# step:  552
# (48985, 552, 1) (48985, 48) (16873, 552, 1) (16873, 48)
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_44 (Conv1D)          (None, 552, 96)           384
#
#  conv1d_45 (Conv1D)          (None, 1, 96)             5087328
#
#  flatten_22 (Flatten)        (None, 96)                0
#
#  dense_22 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 5,092,368
# Trainable params: 5,092,368
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0461, Val MAE = 0.05891302600502968
# Time computation seconds:  550.3503143787384
# 1531/1531 [==============================] - 3s 2ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0437 - mape: 89.0416
# Loss: 0.005200003273785114 MSE: 0.005200003273785114 MAE: 0.043730609118938446 MAPE: 89.04161834716797
# 528/528 [==============================] - 1s 2ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0592 - mape: 119.2289
# Loss_val: 0.009090094827115536 MSE_val: 0.009090094827115536 MAE_val: 0.05922822281718254 MAPE_val: 119.2288818359375
#
# step:  576
# (48961, 576, 1) (48961, 48) (16849, 576, 1) (16849, 48)
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_46 (Conv1D)          (None, 576, 96)           384
#
#  conv1d_47 (Conv1D)          (None, 1, 96)             5308512
#
#  flatten_23 (Flatten)        (None, 96)                0
#
#  dense_23 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 5,313,552
# Trainable params: 5,313,552
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0451, Val MAE = 0.06505654007196426
# Epoch 100: MAE = 0.0412, Val MAE = 0.0603087954223156
# Time computation seconds:  753.220362663269
# 1531/1531 [==============================] - 3s 2ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0401 - mape: 85.2425
# Loss: 0.0043391278013587 MSE: 0.0043391278013587 MAE: 0.04011698067188263 MAPE: 85.24254608154297
# 527/527 [==============================] - 1s 2ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0591 - mape: 126.9833
# Loss_val: 0.009332218207418919 MSE_val: 0.009332218207418919 MAE_val: 0.05912698432803154 MAPE_val: 126.98332214355469
#
# step:  600
# (48937, 600, 1) (48937, 48) (16825, 600, 1) (16825, 48)
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_48 (Conv1D)          (None, 600, 96)           384
#
#  conv1d_49 (Conv1D)          (None, 1, 96)             5529696
#
#  flatten_24 (Flatten)        (None, 96)                0
#
#  dense_24 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 5,534,736
# Trainable params: 5,534,736
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 50: MAE = 0.0448, Val MAE = 0.06762829422950745
# Time computation seconds:  371.0268363952637
# 1530/1530 [==============================] - 3s 2ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0453 - mape: 94.2627
# Loss: 0.005650013219565153 MSE: 0.005650013219565153 MAE: 0.04532964155077934 MAPE: 94.26274871826172
# 526/526 [==============================] - 1s 2ms/step - loss: 0.0095 - mse: 0.0095 - mae: 0.0614 - mape: 122.6213
# Loss_val: 0.009461943991482258 MSE_val: 0.009461943991482258 MAE_val: 0.0614454448223114 MAPE_val: 122.62129211425781
#
# step:  624
# (48913, 624, 1) (48913, 48) (16801, 624, 1) (16801, 48)
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_50 (Conv1D)          (None, 624, 96)           384
#
#  conv1d_51 (Conv1D)          (None, 1, 96)             5750880
#
#  flatten_25 (Flatten)        (None, 96)                0
#
#  dense_25 (Dense)            (None, 48)                4656
#
# =================================================================
# Total params: 5,755,920
# Trainable params: 5,755,920
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker 
# Extract data
data_train = metric_dict["MSE_train"]
data_val = metric_dict["MSE_val"]

# Generate x-values dynamically
x_values = np.arange(start_step, end_step+1, step_slice)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(x_values, data_train, marker='o', linestyle='-', color='b', label="MSE Train")
plt.plot(x_values, data_val, marker='s', linestyle='--', color='r', label="MSE Validation")
plt.axvline(x=(np.argmin(data_val)+1)*step_slice, color='g', linestyle='--', linewidth=2, label="Lowest MSE Validation")
# Labels
plt.xlabel("window size (timestep)")
plt.ylabel("MSE Value")
plt.title("MSE Train vs Validation Over Steps")
plt.xticks(np.arange(start_step,end_step+999, step_slice),fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, end_step+1)
plt.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract data
data_train = metric_dict["MAE_train"]
data_val = metric_dict["MAE_val"]

# Generate x-values dynamically
x_values = np.arange(start_step, end_step+1, step_slice)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(x_values, data_train, marker='o', linestyle='-', color='b', label="MAE Train")
plt.plot(x_values, data_val, marker='s', linestyle='--', color='r', label="MAE Validation")
plt.axvline(x=(np.argmin(data_val)+1)*step_slice, color='g', linestyle='--', linewidth=2, label="Lowest MSE Validation")
# Labels
plt.xlabel("window size (timestep)")
plt.ylabel("MAE Value")
plt.title("MAE Train vs Validation Over Steps")
plt.xticks(np.arange(start_step,end_step+999, step_slice),fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, end_step+1)
plt.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract data
data_train = metric_dict["MAPE_train"]
data_val = metric_dict["MAPE_val"]

x_values = np.arange(start_step, end_step+1, step_slice)
# Plot
plt.figure(figsize=(12, 5))
plt.plot(x_values, data_train, marker='o', linestyle='-', color='b', label="MAPE Train")
plt.plot(x_values, data_val, marker='s', linestyle='--', color='r', label="MAPE Validation")
plt.axvline(x=(np.argmin(data_val)+1)*step_slice, color='g', linestyle='--', linewidth=2, label="Lowest MSE Validation")
# Labels
plt.xlabel("Index (every 12 steps)")
plt.ylabel("MAPE Value")
plt.title("MAPE Train vs Validation Over Steps")
plt.xticks(np.arange(504,end_step+999, step_slice),fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, end_step+1)
plt.legend()

# Show plot
plt.show()
